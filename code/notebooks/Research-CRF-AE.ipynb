# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-30tymo4s
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-30tymo4s
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4mt5nyay/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
# !chmod 777 install
# !./install
# Out:
# --2019-06-23 13:52:59--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3281527 (3.1M) [text/plain]
# Saving to: ‘eng.train’
#
# eng.train           100%[===================>]   3.13M  --.-KB/s    in 0.08s
#
# 2019-06-23 13:53:00 (37.4 MB/s) - ‘eng.train’ saved [3281527/3281527]
#
# --2019-06-23 13:53:00--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827009 (808K) [text/plain]
# Saving to: ‘eng.testa’
#
# eng.testa           100%[===================>] 807.63K  --.-KB/s    in 0.06s
#
# 2019-06-23 13:53:00 (12.9 MB/s) - ‘eng.testa’ saved [827009/827009]
#
# --2019-06-23 13:53:00--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 748094 (731K) [text/plain]
# Saving to: ‘eng.testb’
#
# eng.testb           100%[===================>] 730.56K  --.-KB/s    in 0.05s
#
# 2019-06-23 13:53:00 (13.6 MB/s) - ‘eng.testb’ saved [748094/748094]
#
# --2019-06-23 13:53:00--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-06-23 13:53:00--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2019-06-23 13:53:00--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  65.5MB/s    in 13s
#
# 2019-06-23 13:53:13 (63.7 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
# Cloning into 'gdown.pl'...
# remote: Enumerating objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:37--  https://docs.google.com/uc?id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.129.113, 74.125.129.102, 74.125.129.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.129.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘all_onehot.train’
#
#      0K                                     34.6M=0s
#
# 2019-06-23 13:53:37 (34.6 MB/s) - ‘all_onehot.train’ saved [3252]
#
# --2019-06-23 13:53:37--  https://docs.google.com/uc?export=download&confirm=cUnM&id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w
# Resolving docs.google.com (docs.google.com)... 172.217.214.139, 172.217.214.102, 172.217.214.101, ...
# Connecting to docs.google.com (docs.google.com)|172.217.214.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/vt6acrh4q0qouijpmcouacvoq8cptogk/1561291200000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:37--  https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/vt6acrh4q0qouijpmcouacvoq8cptogk/1561291200000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download
# Resolving doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.train’
#
#      0K ........ ........ ........ ........ 65.7M
#  32768K ........ ........ ........ ........ 66.8M
#  65536K ........ ........ ........ ........  110M
#  98304K ........ ........ ........ ........  108M
# 131072K ........ ........ ........ ........ 84.7M
# 163840K ........ ........ ........ ........ 26.2M
# 196608K ........ ........ ........ ........  104M
# 229376K ........ ........ ........ ........  136M
# 262144K ........ ........ ........ ........  220M
# 294912K ........ ........ ........ ........  305M
# 327680K ........ ........ ........ ........  229M
# 360448K ........ ........ ......             270M=4.2s
#
# 2019-06-23 13:53:42 (89.8 MB/s) - ‘all_onehot.train’ saved [392581451]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:42--  https://docs.google.com/uc?id=1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.129.113, 74.125.129.102, 74.125.129.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.129.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kiqrsbpgbao8tl4mp45tb5f4vfpjgot3/1561291200000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:43--  https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kiqrsbpgbao8tl4mp45tb5f4vfpjgot3/1561291200000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download
# Resolving doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testa’
#
#      0K ........ ........ ........ ........ 96.2M
#  32768K ........ ........ ........ ........  184M
#  65536K ........ ........ ........ ......    260M=0.6s
#
# 2019-06-23 13:53:44 (151 MB/s) - ‘all_onehot.testa’ saved [99026097]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:44--  https://docs.google.com/uc?id=1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.129.113, 74.125.129.102, 74.125.129.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.129.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hfhverfhh0j2viodhq63brvoq58hkhvm/1561291200000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:47--  https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hfhverfhh0j2viodhq63brvoq58hkhvm/1561291200000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download
# Resolving doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testb’
#
#      0K ........ ........ ........ ........  136M
#  32768K ........ ........ ........ ........  194M
#  65536K ........ ........ .....              140M=0.6s
#
# 2019-06-23 13:53:48 (155 MB/s) - ‘all_onehot.testb’ saved [89526841]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:48--  https://docs.google.com/uc?id=1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.129.113, 74.125.129.102, 74.125.129.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.129.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n9s68fcc1fvedpvic3o93rembpaalm8k/1561291200000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:48--  https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n9s68fcc1fvedpvic3o93rembpaalm8k/1561291200000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download
# Resolving doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.train’
#
#      0K ....                                93.3M=0.05s
#
# 2019-06-23 13:53:49 (93.3 MB/s) - ‘gazetteer_PERLOC.train’ saved [4887067]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:49--  https://docs.google.com/uc?id=1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn&export=download
# Resolving docs.google.com (docs.google.com)... 172.217.214.138, 172.217.214.139, 172.217.214.102, ...
# Connecting to docs.google.com (docs.google.com)|172.217.214.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t7ru4fecglca757r922s5hvr5rqtjam8/1561291200000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:49--  https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t7ru4fecglca757r922s5hvr5rqtjam8/1561291200000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download
# Resolving doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1232849 (1.2M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testa’
#
#      0K .                                  100%  128M=0.009s
#
# 2019-06-23 13:53:49 (128 MB/s) - ‘gazetteer_PERLOC.testa’ saved [1232849/1232849]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-23 13:53:50--  https://docs.google.com/uc?id=1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh&export=download
# Resolving docs.google.com (docs.google.com)... 172.217.214.139, 172.217.214.102, 172.217.214.101, ...
# Connecting to docs.google.com (docs.google.com)|172.217.214.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5f04lblltobf9v9dpccib8j2425q2tsj/1561291200000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-23 13:53:50--  https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5f04lblltobf9v9dpccib8j2425q2tsj/1561291200000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download
# Resolving doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)... 74.125.69.132, 2607:f8b0:4001:c08::84
# Connecting to doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1114601 (1.1M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testb’
#
#      0K .                                  100%  129M=0.008s
#
# 2019-06-23 13:53:50 (129 MB/s) - ‘gazetteer_PERLOC.testb’ saved [1114601/1114601]

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Adam
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 64
LSTM_DIM = 300
CHAR_EMB_DIM = 30
KERNEL_SIZE = 3
CHAR_FILTERS = 30
DROPOUT = 0.5
RECURRENT_DROPOUT = 0.5

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(3 / LSTM_DIM), maxval=math.sqrt(3 / LSTM_DIM))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    feature_input = Input(shape=(None, 198))
    gaze_input = Input(shape=(None, 4))

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings, feature_input, gaze_input])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT, implementation=2
    ))(embeddings)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(4, activation='softmax'))(output)
    shape = TimeDistributed(Dense(152, activation='softmax'))(output)
    position = TimeDistributed(Dense(46, activation='softmax'))(output)
    
    return Model(inputs=[word_input, case_input, char_input, feature_input, gaze_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy],
              optimizer=SGD(lr=0.02, decay=1e-5, momentum=0.9, clipnorm=15, nesterov=True))

# %%
import numpy as np
from sklearn.metrics import f1_score
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    pos_true, pos_pred = [], []
    shp_true, shp_pred = [], []
    true_seqs, pred_seqs = [], []
    pos_total, pos_correct = 0, 0
    shp_total, shp_correct = 0, 0

    for batch in batches:
        tag = batch['tag']
        shp = batch['shape']
        pos = batch['position']

        tag = tag.reshape((tag.shape[0], tag.shape[1]))
        shp = shp.reshape((shp.shape[0], shp.shape[1]))
        pos = pos.reshape((pos.shape[0], pos.shape[1]))

        lstm, _, shape, position = model.predict([batch['word'], batch['case'], batch['char'], batch['features'], batch['gaze']], verbose=False)
        lstm = lstm.argmax(axis=-1)
        shape = shape.argmax(axis=-1)
        position = position.argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in tag[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in lstm[seq_ind, 1: seq_len + 1]]))
            
            true_pos = np.array([ind.item() for ind in pos[seq_ind, 1: seq_len + 1]])
            pred_pos = np.array([ind.item() for ind in position[seq_ind, 1: seq_len + 1]])
            
            pos_true += list(true_pos)
            pos_pred += list(pred_pos)
            
            pos_correct += np.sum(true_pos == pred_pos)
            pos_total += len(pred_pos)
            
            true_shp = np.array([ind.item() for ind in shp[seq_ind, 1: seq_len + 1]])
            pred_shp = np.array([ind.item() for ind in shape[seq_ind, 1: seq_len + 1]])
            
            shp_true += list(true_shp)
            shp_pred += list(pred_shp)
            
            shp_correct += np.sum(true_shp == pred_shp)
            shp_total += len(pred_shp)

    f, precision, recall = evaluate(true_seqs, pred_seqs, verbose=False)
    pos_accuracy = 100 * pos_correct / pos_total
    pos_f = 100 * f1_score(pos_true, pos_pred, average='micro') 
    shp_accuracy = 100 * shp_correct / shp_total
    shp_f = 100 * f1_score(shp_true, shp_pred, average='micro') 
    
    return f, precision, recall, pos_accuracy, pos_f, shp_accuracy, shp_f

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char'], batch['features'], batch['gaze']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 37.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 52.41%, Precision = 54.34%, Recall = 53.36%
# POS F1 = 62.36%, Accuracy = 62.36%
# Shape F1 = 72.93%, Accuracy = 72.93%
# ================================== Valid Data ==================================
# F1 = 57.80%, Precision = 57.22%, Recall = 57.51%
# POS F1 = 61.18%, Accuracy = 61.18%
# Shape F1 = 72.68%, Accuracy = 72.68%
# ================================== Test  Data ==================================
# F1 = 51.73%, Precision = 55.44%, Recall = 53.52%
# POS F1 = 64.80%, Accuracy = 64.80%
# Shape F1 = 71.90%, Accuracy = 71.90%
# Time: 14.14s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 63.72%, Precision = 67.12%, Recall = 65.38%
# POS F1 = 79.11%, Accuracy = 79.11%
# Shape F1 = 85.75%, Accuracy = 85.75%
# ================================== Valid Data ==================================
# F1 = 67.88%, Precision = 69.47%, Recall = 68.67%
# POS F1 = 78.95%, Accuracy = 78.95%
# Shape F1 = 85.60%, Accuracy = 85.60%
# ================================== Test  Data ==================================
# F1 = 63.42%, Precision = 68.18%, Recall = 65.72%
# POS F1 = 80.01%, Accuracy = 80.01%
# Shape F1 = 84.51%, Accuracy = 84.51%
# Time: 13.64s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 72.72%, Precision = 74.06%, Recall = 73.39%
# POS F1 = 86.22%, Accuracy = 86.22%
# Shape F1 = 89.29%, Accuracy = 89.29%
# ================================== Valid Data ==================================
# F1 = 73.90%, Precision = 74.30%, Recall = 74.10%
# POS F1 = 86.14%, Accuracy = 86.14%
# Shape F1 = 89.20%, Accuracy = 89.20%
# ================================== Test  Data ==================================
# F1 = 70.87%, Precision = 72.79%, Recall = 71.81%
# POS F1 = 86.47%, Accuracy = 86.47%
# Shape F1 = 88.32%, Accuracy = 88.32%
# Time: 14.08s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.55s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 74.61%, Precision = 80.07%, Recall = 77.24%
# POS F1 = 89.62%, Accuracy = 89.62%
# Shape F1 = 92.07%, Accuracy = 92.07%
# ================================== Valid Data ==================================
# F1 = 75.70%, Precision = 80.48%, Recall = 78.02%
# POS F1 = 89.27%, Accuracy = 89.27%
# Shape F1 = 92.06%, Accuracy = 92.06%
# ================================== Test  Data ==================================
# F1 = 71.45%, Precision = 77.46%, Recall = 74.34%
# POS F1 = 89.76%, Accuracy = 89.76%
# Shape F1 = 90.86%, Accuracy = 90.86%
# Time: 14.00s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 79.95%, Precision = 81.33%, Recall = 80.63%
# POS F1 = 91.53%, Accuracy = 91.53%
# Shape F1 = 93.28%, Accuracy = 93.28%
# ================================== Valid Data ==================================
# F1 = 80.55%, Precision = 81.64%, Recall = 81.09%
# POS F1 = 91.05%, Accuracy = 91.05%
# Shape F1 = 93.32%, Accuracy = 93.32%
# ================================== Test  Data ==================================
# F1 = 76.92%, Precision = 78.52%, Recall = 77.71%
# POS F1 = 91.37%, Accuracy = 91.37%
# Shape F1 = 92.17%, Accuracy = 92.17%
# Time: 13.98s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.52s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 80.26%, Precision = 83.02%, Recall = 81.62%
# POS F1 = 92.81%, Accuracy = 92.81%
# Shape F1 = 93.99%, Accuracy = 93.99%
# ================================== Valid Data ==================================
# F1 = 80.52%, Precision = 83.12%, Recall = 81.80%
# POS F1 = 92.31%, Accuracy = 92.31%
# Shape F1 = 94.05%, Accuracy = 94.05%
# ================================== Test  Data ==================================
# F1 = 75.76%, Precision = 79.28%, Recall = 77.48%
# POS F1 = 92.54%, Accuracy = 92.54%
# Shape F1 = 92.87%, Accuracy = 92.87%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.44s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.31%, Precision = 80.85%, Recall = 82.54%
# POS F1 = 93.59%, Accuracy = 93.59%
# Shape F1 = 94.77%, Accuracy = 94.77%
# ================================== Valid Data ==================================
# F1 = 85.09%, Precision = 80.66%, Recall = 82.82%
# POS F1 = 93.05%, Accuracy = 93.05%
# Shape F1 = 94.84%, Accuracy = 94.84%
# ================================== Test  Data ==================================
# F1 = 80.27%, Precision = 77.53%, Recall = 78.88%
# POS F1 = 93.23%, Accuracy = 93.23%
# Shape F1 = 93.68%, Accuracy = 93.68%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.13%, Precision = 84.82%, Recall = 83.97%
# POS F1 = 94.13%, Accuracy = 94.13%
# Shape F1 = 95.28%, Accuracy = 95.28%
# ================================== Valid Data ==================================
# F1 = 83.40%, Precision = 84.70%, Recall = 84.04%
# POS F1 = 93.58%, Accuracy = 93.58%
# Shape F1 = 95.30%, Accuracy = 95.30%
# ================================== Test  Data ==================================
# F1 = 78.93%, Precision = 81.32%, Recall = 80.11%
# POS F1 = 93.71%, Accuracy = 93.71%
# Shape F1 = 94.19%, Accuracy = 94.19%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.35%, Precision = 83.69%, Recall = 84.02%
# POS F1 = 94.92%, Accuracy = 94.92%
# Shape F1 = 95.89%, Accuracy = 95.89%
# ================================== Valid Data ==================================
# F1 = 84.10%, Precision = 82.88%, Recall = 83.49%
# POS F1 = 94.40%, Accuracy = 94.40%
# Shape F1 = 95.95%, Accuracy = 95.95%
# ================================== Test  Data ==================================
# F1 = 80.17%, Precision = 80.05%, Recall = 80.11%
# POS F1 = 94.51%, Accuracy = 94.51%
# Shape F1 = 94.87%, Accuracy = 94.87%
# Time: 14.10s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.68s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.55%, Precision = 85.42%, Recall = 84.48%
# POS F1 = 95.30%, Accuracy = 95.30%
# Shape F1 = 96.37%, Accuracy = 96.37%
# ================================== Valid Data ==================================
# F1 = 83.68%, Precision = 85.24%, Recall = 84.45%
# POS F1 = 94.80%, Accuracy = 94.80%
# Shape F1 = 96.43%, Accuracy = 96.43%
# ================================== Test  Data ==================================
# F1 = 78.37%, Precision = 80.95%, Recall = 79.64%
# POS F1 = 94.87%, Accuracy = 94.87%
# Shape F1 = 95.30%, Accuracy = 95.30%
# Time: 13.95s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.20%, Precision = 86.80%, Recall = 86.50%
# POS F1 = 95.64%, Accuracy = 95.64%
# Shape F1 = 96.60%, Accuracy = 96.60%
# ================================== Valid Data ==================================
# F1 = 86.29%, Precision = 86.82%, Recall = 86.55%
# POS F1 = 95.11%, Accuracy = 95.11%
# Shape F1 = 96.65%, Accuracy = 96.65%
# ================================== Test  Data ==================================
# F1 = 82.21%, Precision = 83.39%, Recall = 82.80%
# POS F1 = 95.17%, Accuracy = 95.17%
# Shape F1 = 95.51%, Accuracy = 95.51%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.91%, Precision = 86.65%, Recall = 86.78%
# POS F1 = 95.93%, Accuracy = 95.93%
# Shape F1 = 96.58%, Accuracy = 96.58%
# ================================== Valid Data ==================================
# F1 = 86.39%, Precision = 86.08%, Recall = 86.23%
# POS F1 = 95.42%, Accuracy = 95.42%
# Shape F1 = 96.65%, Accuracy = 96.65%
# ================================== Test  Data ==================================
# F1 = 82.19%, Precision = 82.58%, Recall = 82.38%
# POS F1 = 95.44%, Accuracy = 95.44%
# Shape F1 = 95.54%, Accuracy = 95.54%
# Time: 13.91s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.53%, Precision = 87.29%, Recall = 86.91%
# POS F1 = 96.33%, Accuracy = 96.33%
# Shape F1 = 96.99%, Accuracy = 96.99%
# ================================== Valid Data ==================================
# F1 = 85.91%, Precision = 86.49%, Recall = 86.20%
# POS F1 = 95.79%, Accuracy = 95.79%
# Shape F1 = 97.03%, Accuracy = 97.03%
# ================================== Test  Data ==================================
# F1 = 81.90%, Precision = 82.99%, Recall = 82.44%
# POS F1 = 95.86%, Accuracy = 95.86%
# Shape F1 = 95.91%, Accuracy = 95.91%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.56%, Precision = 87.37%, Recall = 87.47%
# POS F1 = 96.49%, Accuracy = 96.49%
# Shape F1 = 97.13%, Accuracy = 97.13%
# ================================== Valid Data ==================================
# F1 = 86.66%, Precision = 86.55%, Recall = 86.60%
# POS F1 = 95.99%, Accuracy = 95.99%
# Shape F1 = 97.12%, Accuracy = 97.12%
# ================================== Test  Data ==================================
# F1 = 82.59%, Precision = 82.63%, Recall = 82.61%
# POS F1 = 95.96%, Accuracy = 95.96%
# Shape F1 = 96.09%, Accuracy = 96.09%
# Time: 13.88s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.46%, Precision = 86.37%, Recall = 87.40%
# POS F1 = 96.58%, Accuracy = 96.58%
# Shape F1 = 97.14%, Accuracy = 97.14%
# ================================== Valid Data ==================================
# F1 = 87.83%, Precision = 85.39%, Recall = 86.59%
# POS F1 = 96.08%, Accuracy = 96.08%
# Shape F1 = 97.14%, Accuracy = 97.14%
# ================================== Test  Data ==================================
# F1 = 84.11%, Precision = 82.01%, Recall = 83.05%
# POS F1 = 96.07%, Accuracy = 96.07%
# Shape F1 = 96.15%, Accuracy = 96.15%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.40s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.58%, Precision = 87.06%, Recall = 87.81%
# POS F1 = 96.85%, Accuracy = 96.85%
# Shape F1 = 97.42%, Accuracy = 97.42%
# ================================== Valid Data ==================================
# F1 = 87.96%, Precision = 86.17%, Recall = 87.05%
# POS F1 = 96.32%, Accuracy = 96.32%
# Shape F1 = 97.38%, Accuracy = 97.38%
# ================================== Test  Data ==================================
# F1 = 84.07%, Precision = 82.33%, Recall = 83.19%
# POS F1 = 96.28%, Accuracy = 96.28%
# Shape F1 = 96.42%, Accuracy = 96.42%
# Time: 13.95s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.80%, Precision = 87.01%, Recall = 87.40%
# POS F1 = 97.05%, Accuracy = 97.05%
# Shape F1 = 97.52%, Accuracy = 97.52%
# ================================== Valid Data ==================================
# F1 = 86.91%, Precision = 86.13%, Recall = 86.52%
# POS F1 = 96.52%, Accuracy = 96.52%
# Shape F1 = 97.56%, Accuracy = 97.56%
# ================================== Test  Data ==================================
# F1 = 82.47%, Precision = 82.22%, Recall = 82.35%
# POS F1 = 96.52%, Accuracy = 96.52%
# Shape F1 = 96.66%, Accuracy = 96.66%
# Time: 13.94s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.96%, Precision = 88.51%, Recall = 88.74%
# POS F1 = 97.16%, Accuracy = 97.16%
# Shape F1 = 97.56%, Accuracy = 97.56%
# ================================== Valid Data ==================================
# F1 = 88.21%, Precision = 87.65%, Recall = 87.93%
# POS F1 = 96.71%, Accuracy = 96.71%
# Shape F1 = 97.52%, Accuracy = 97.52%
# ================================== Test  Data ==================================
# F1 = 85.07%, Precision = 84.72%, Recall = 84.89%
# POS F1 = 96.59%, Accuracy = 96.59%
# Shape F1 = 96.83%, Accuracy = 96.83%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.56s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.64%, Precision = 88.57%, Recall = 89.10%
# POS F1 = 97.30%, Accuracy = 97.30%
# Shape F1 = 97.67%, Accuracy = 97.67%
# ================================== Valid Data ==================================
# F1 = 88.77%, Precision = 87.28%, Recall = 88.02%
# POS F1 = 96.86%, Accuracy = 96.86%
# Shape F1 = 97.66%, Accuracy = 97.66%
# ================================== Test  Data ==================================
# F1 = 85.21%, Precision = 84.26%, Recall = 84.73%
# POS F1 = 96.75%, Accuracy = 96.75%
# Shape F1 = 96.93%, Accuracy = 96.93%
# Time: 13.98s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.33%, Precision = 89.05%, Recall = 89.69%
# POS F1 = 97.31%, Accuracy = 97.31%
# Shape F1 = 97.78%, Accuracy = 97.78%
# ================================== Valid Data ==================================
# F1 = 89.73%, Precision = 88.05%, Recall = 88.88%
# POS F1 = 96.85%, Accuracy = 96.85%
# Shape F1 = 97.76%, Accuracy = 97.76%
# ================================== Test  Data ==================================
# F1 = 85.98%, Precision = 84.35%, Recall = 85.16%
# POS F1 = 96.74%, Accuracy = 96.74%
# Shape F1 = 96.79%, Accuracy = 96.79%
# Time: 13.84s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.10%, Precision = 88.48%, Recall = 89.28%
# POS F1 = 97.35%, Accuracy = 97.35%
# Shape F1 = 97.86%, Accuracy = 97.86%
# ================================== Valid Data ==================================
# F1 = 89.51%, Precision = 87.46%, Recall = 88.47%
# POS F1 = 96.91%, Accuracy = 96.91%
# Shape F1 = 97.85%, Accuracy = 97.85%
# ================================== Test  Data ==================================
# F1 = 86.01%, Precision = 83.92%, Recall = 84.95%
# POS F1 = 96.81%, Accuracy = 96.81%
# Shape F1 = 96.90%, Accuracy = 96.90%
# Time: 14.13s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.64%, Precision = 89.13%, Recall = 89.38%
# POS F1 = 97.54%, Accuracy = 97.54%
# Shape F1 = 97.95%, Accuracy = 97.95%
# ================================== Valid Data ==================================
# F1 = 89.16%, Precision = 88.30%, Recall = 88.73%
# POS F1 = 97.03%, Accuracy = 97.03%
# Shape F1 = 97.94%, Accuracy = 97.94%
# ================================== Test  Data ==================================
# F1 = 85.27%, Precision = 85.04%, Recall = 85.15%
# POS F1 = 96.99%, Accuracy = 96.99%
# Shape F1 = 97.16%, Accuracy = 97.16%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.90%, Precision = 88.04%, Recall = 89.45%
# POS F1 = 97.53%, Accuracy = 97.53%
# Shape F1 = 97.96%, Accuracy = 97.96%
# ================================== Valid Data ==================================
# F1 = 90.03%, Precision = 87.11%, Recall = 88.55%
# POS F1 = 97.08%, Accuracy = 97.08%
# Shape F1 = 97.93%, Accuracy = 97.93%
# ================================== Test  Data ==================================
# F1 = 86.39%, Precision = 83.52%, Recall = 84.93%
# POS F1 = 96.95%, Accuracy = 96.95%
# Shape F1 = 97.12%, Accuracy = 97.12%
# Time: 14.06s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.71%, Precision = 89.86%, Recall = 89.79%
# POS F1 = 97.68%, Accuracy = 97.68%
# Shape F1 = 98.07%, Accuracy = 98.07%
# ================================== Valid Data ==================================
# F1 = 88.51%, Precision = 88.69%, Recall = 88.60%
# POS F1 = 97.20%, Accuracy = 97.20%
# Shape F1 = 98.03%, Accuracy = 98.03%
# ================================== Test  Data ==================================
# F1 = 84.89%, Precision = 85.64%, Recall = 85.26%
# POS F1 = 97.13%, Accuracy = 97.13%
# Shape F1 = 97.31%, Accuracy = 97.31%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.25%, Precision = 88.74%, Recall = 89.98%
# POS F1 = 97.68%, Accuracy = 97.68%
# Shape F1 = 98.14%, Accuracy = 98.14%
# ================================== Valid Data ==================================
# F1 = 90.32%, Precision = 87.82%, Recall = 89.05%
# POS F1 = 97.23%, Accuracy = 97.23%
# Shape F1 = 98.06%, Accuracy = 98.06%
# ================================== Test  Data ==================================
# F1 = 86.88%, Precision = 84.21%, Recall = 85.52%
# POS F1 = 97.11%, Accuracy = 97.11%
# Shape F1 = 97.36%, Accuracy = 97.36%
# Time: 13.93s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.14%, Precision = 88.33%, Recall = 89.71%
# POS F1 = 97.79%, Accuracy = 97.79%
# Shape F1 = 98.15%, Accuracy = 98.15%
# ================================== Valid Data ==================================
# F1 = 90.04%, Precision = 87.06%, Recall = 88.53%
# POS F1 = 97.34%, Accuracy = 97.34%
# Shape F1 = 98.11%, Accuracy = 98.11%
# ================================== Test  Data ==================================
# F1 = 87.05%, Precision = 83.89%, Recall = 85.44%
# POS F1 = 97.28%, Accuracy = 97.28%
# Shape F1 = 97.25%, Accuracy = 97.25%
# Time: 14.02s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.49s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.09%, Precision = 88.67%, Recall = 89.86%
# POS F1 = 97.82%, Accuracy = 97.82%
# Shape F1 = 98.19%, Accuracy = 98.19%
# ================================== Valid Data ==================================
# F1 = 90.30%, Precision = 87.39%, Recall = 88.82%
# POS F1 = 97.39%, Accuracy = 97.39%
# Shape F1 = 98.12%, Accuracy = 98.12%
# ================================== Test  Data ==================================
# F1 = 86.79%, Precision = 83.60%, Recall = 85.17%
# POS F1 = 97.28%, Accuracy = 97.28%
# Shape F1 = 97.44%, Accuracy = 97.44%
# Time: 13.83s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.84%, Precision = 88.91%, Recall = 89.86%
# POS F1 = 97.90%, Accuracy = 97.90%
# Shape F1 = 98.27%, Accuracy = 98.27%
# ================================== Valid Data ==================================
# F1 = 90.02%, Precision = 87.61%, Recall = 88.80%
# POS F1 = 97.49%, Accuracy = 97.49%
# Shape F1 = 98.24%, Accuracy = 98.24%
# ================================== Test  Data ==================================
# F1 = 85.96%, Precision = 84.03%, Recall = 84.99%
# POS F1 = 97.37%, Accuracy = 97.37%
# Shape F1 = 97.54%, Accuracy = 97.54%
# Time: 13.83s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.27%, Precision = 91.17%, Recall = 91.22%
# POS F1 = 97.87%, Accuracy = 97.87%
# Shape F1 = 98.28%, Accuracy = 98.28%
# ================================== Valid Data ==================================
# F1 = 90.29%, Precision = 90.09%, Recall = 90.19%
# POS F1 = 97.48%, Accuracy = 97.48%
# Shape F1 = 98.23%, Accuracy = 98.23%
# ================================== Test  Data ==================================
# F1 = 86.92%, Precision = 87.18%, Recall = 87.05%
# POS F1 = 97.33%, Accuracy = 97.33%
# Shape F1 = 97.55%, Accuracy = 97.55%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.60s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.61%, Precision = 90.75%, Recall = 91.18%
# POS F1 = 97.95%, Accuracy = 97.95%
# Shape F1 = 98.33%, Accuracy = 98.33%
# ================================== Valid Data ==================================
# F1 = 90.54%, Precision = 89.67%, Recall = 90.10%
# POS F1 = 97.55%, Accuracy = 97.55%
# Shape F1 = 98.25%, Accuracy = 98.25%
# ================================== Test  Data ==================================
# F1 = 87.13%, Precision = 86.54%, Recall = 86.84%
# POS F1 = 97.41%, Accuracy = 97.41%
# Shape F1 = 97.64%, Accuracy = 97.64%
# Time: 13.94s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.31s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.18%, Precision = 91.07%, Recall = 91.12%
# POS F1 = 98.07%, Accuracy = 98.07%
# Shape F1 = 98.35%, Accuracy = 98.35%
# ================================== Valid Data ==================================
# F1 = 90.10%, Precision = 89.75%, Recall = 89.92%
# POS F1 = 97.66%, Accuracy = 97.66%
# Shape F1 = 98.26%, Accuracy = 98.26%
# ================================== Test  Data ==================================
# F1 = 86.66%, Precision = 86.81%, Recall = 86.73%
# POS F1 = 97.50%, Accuracy = 97.50%
# Shape F1 = 97.64%, Accuracy = 97.64%
# Time: 13.62s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.46s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.79%, Precision = 90.03%, Recall = 90.90%
# POS F1 = 98.08%, Accuracy = 98.08%
# Shape F1 = 98.39%, Accuracy = 98.39%
# ================================== Valid Data ==================================
# F1 = 90.52%, Precision = 88.67%, Recall = 89.59%
# POS F1 = 97.64%, Accuracy = 97.64%
# Shape F1 = 98.34%, Accuracy = 98.34%
# ================================== Test  Data ==================================
# F1 = 87.17%, Precision = 85.45%, Recall = 86.30%
# POS F1 = 97.50%, Accuracy = 97.50%
# Shape F1 = 97.69%, Accuracy = 97.69%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.02%, Precision = 91.24%, Recall = 91.63%
# POS F1 = 98.15%, Accuracy = 98.15%
# Shape F1 = 98.42%, Accuracy = 98.42%
# ================================== Valid Data ==================================
# F1 = 90.39%, Precision = 89.60%, Recall = 89.99%
# POS F1 = 97.74%, Accuracy = 97.74%
# Shape F1 = 98.31%, Accuracy = 98.31%
# ================================== Test  Data ==================================
# F1 = 87.39%, Precision = 86.84%, Recall = 87.11%
# POS F1 = 97.53%, Accuracy = 97.53%
# Shape F1 = 97.73%, Accuracy = 97.73%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.98%, Precision = 89.21%, Recall = 90.58%
# POS F1 = 98.19%, Accuracy = 98.19%
# Shape F1 = 98.45%, Accuracy = 98.45%
# ================================== Valid Data ==================================
# F1 = 90.57%, Precision = 87.46%, Recall = 88.99%
# POS F1 = 97.77%, Accuracy = 97.77%
# Shape F1 = 98.39%, Accuracy = 98.39%
# ================================== Test  Data ==================================
# F1 = 87.41%, Precision = 84.72%, Recall = 86.05%
# POS F1 = 97.61%, Accuracy = 97.61%
# Shape F1 = 97.78%, Accuracy = 97.78%
# Time: 14.02s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.95%, Precision = 90.62%, Recall = 91.28%
# POS F1 = 98.29%, Accuracy = 98.29%
# Shape F1 = 98.50%, Accuracy = 98.50%
# ================================== Valid Data ==================================
# F1 = 90.43%, Precision = 89.25%, Recall = 89.84%
# POS F1 = 97.93%, Accuracy = 97.93%
# Shape F1 = 98.41%, Accuracy = 98.41%
# ================================== Test  Data ==================================
# F1 = 87.43%, Precision = 86.24%, Recall = 86.83%
# POS F1 = 97.68%, Accuracy = 97.68%
# Shape F1 = 97.84%, Accuracy = 97.84%
# Time: 13.89s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.32%, Precision = 90.94%, Recall = 91.62%
# POS F1 = 98.25%, Accuracy = 98.25%
# Shape F1 = 98.53%, Accuracy = 98.53%
# ================================== Valid Data ==================================
# F1 = 91.06%, Precision = 89.43%, Recall = 90.24%
# POS F1 = 97.86%, Accuracy = 97.86%
# Shape F1 = 98.44%, Accuracy = 98.44%
# ================================== Test  Data ==================================
# F1 = 87.81%, Precision = 86.19%, Recall = 86.99%
# POS F1 = 97.65%, Accuracy = 97.65%
# Shape F1 = 97.85%, Accuracy = 97.85%
# Time: 13.97s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.48s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.66%, Precision = 90.74%, Recall = 91.20%
# POS F1 = 98.28%, Accuracy = 98.28%
# Shape F1 = 98.56%, Accuracy = 98.56%
# ================================== Valid Data ==================================
# F1 = 89.93%, Precision = 89.13%, Recall = 89.53%
# POS F1 = 97.88%, Accuracy = 97.88%
# Shape F1 = 98.47%, Accuracy = 98.47%
# ================================== Test  Data ==================================
# F1 = 86.45%, Precision = 85.96%, Recall = 86.20%
# POS F1 = 97.65%, Accuracy = 97.65%
# Shape F1 = 97.71%, Accuracy = 97.71%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.28%, Precision = 91.74%, Recall = 91.51%
# POS F1 = 98.32%, Accuracy = 98.32%
# Shape F1 = 98.56%, Accuracy = 98.56%
# ================================== Valid Data ==================================
# F1 = 90.01%, Precision = 90.41%, Recall = 90.21%
# POS F1 = 97.89%, Accuracy = 97.89%
# Shape F1 = 98.44%, Accuracy = 98.44%
# ================================== Test  Data ==================================
# F1 = 86.40%, Precision = 87.41%, Recall = 86.90%
# POS F1 = 97.70%, Accuracy = 97.70%
# Shape F1 = 97.85%, Accuracy = 97.85%
# Time: 14.30s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.42%, Precision = 91.64%, Recall = 92.03%
# POS F1 = 98.28%, Accuracy = 98.28%
# Shape F1 = 98.55%, Accuracy = 98.55%
# ================================== Valid Data ==================================
# F1 = 91.08%, Precision = 90.24%, Recall = 90.66%
# POS F1 = 97.85%, Accuracy = 97.85%
# Shape F1 = 98.43%, Accuracy = 98.43%
# ================================== Test  Data ==================================
# F1 = 88.00%, Precision = 87.36%, Recall = 87.68%
# POS F1 = 97.61%, Accuracy = 97.61%
# Shape F1 = 97.84%, Accuracy = 97.84%
# Time: 13.89s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.52%, Precision = 91.58%, Recall = 92.05%
# POS F1 = 98.28%, Accuracy = 98.28%
# Shape F1 = 98.58%, Accuracy = 98.58%
# ================================== Valid Data ==================================
# F1 = 91.29%, Precision = 90.19%, Recall = 90.74%
# POS F1 = 97.85%, Accuracy = 97.85%
# Shape F1 = 98.45%, Accuracy = 98.45%
# ================================== Test  Data ==================================
# F1 = 87.55%, Precision = 86.53%, Recall = 87.03%
# POS F1 = 97.69%, Accuracy = 97.69%
# Shape F1 = 97.89%, Accuracy = 97.89%
# Time: 13.93s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.02%, Precision = 90.55%, Recall = 91.28%
# POS F1 = 98.35%, Accuracy = 98.35%
# Shape F1 = 98.60%, Accuracy = 98.60%
# ================================== Valid Data ==================================
# F1 = 90.61%, Precision = 88.84%, Recall = 89.72%
# POS F1 = 97.93%, Accuracy = 97.93%
# Shape F1 = 98.48%, Accuracy = 98.48%
# ================================== Test  Data ==================================
# F1 = 87.54%, Precision = 85.94%, Recall = 86.73%
# POS F1 = 97.72%, Accuracy = 97.72%
# Shape F1 = 97.92%, Accuracy = 97.92%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.86%, Precision = 91.51%, Recall = 92.18%
# POS F1 = 98.34%, Accuracy = 98.34%
# Shape F1 = 98.61%, Accuracy = 98.61%
# ================================== Valid Data ==================================
# F1 = 91.38%, Precision = 89.77%, Recall = 90.57%
# POS F1 = 97.91%, Accuracy = 97.91%
# Shape F1 = 98.47%, Accuracy = 98.47%
# ================================== Test  Data ==================================
# F1 = 88.21%, Precision = 86.76%, Recall = 87.48%
# POS F1 = 97.71%, Accuracy = 97.71%
# Shape F1 = 98.01%, Accuracy = 98.01%
# Time: 13.67s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.64%, Precision = 91.55%, Recall = 92.10%
# POS F1 = 98.42%, Accuracy = 98.42%
# Shape F1 = 98.65%, Accuracy = 98.65%
# ================================== Valid Data ==================================
# F1 = 91.73%, Precision = 90.51%, Recall = 91.11%
# POS F1 = 97.98%, Accuracy = 97.98%
# Shape F1 = 98.51%, Accuracy = 98.51%
# ================================== Test  Data ==================================
# F1 = 88.09%, Precision = 86.95%, Recall = 87.52%
# POS F1 = 97.78%, Accuracy = 97.78%
# Shape F1 = 97.97%, Accuracy = 97.97%
# Time: 13.89s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.74%, Precision = 91.11%, Recall = 91.92%
# POS F1 = 98.44%, Accuracy = 98.44%
# Shape F1 = 98.69%, Accuracy = 98.69%
# ================================== Valid Data ==================================
# F1 = 91.41%, Precision = 89.58%, Recall = 90.49%
# POS F1 = 98.01%, Accuracy = 98.01%
# Shape F1 = 98.55%, Accuracy = 98.55%
# ================================== Test  Data ==================================
# F1 = 88.02%, Precision = 86.14%, Recall = 87.07%
# POS F1 = 97.84%, Accuracy = 97.84%
# Shape F1 = 98.07%, Accuracy = 98.07%
# Time: 13.64s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.08%, Precision = 90.90%, Recall = 91.98%
# POS F1 = 98.44%, Accuracy = 98.44%
# Shape F1 = 98.67%, Accuracy = 98.67%
# ================================== Valid Data ==================================
# F1 = 91.83%, Precision = 89.63%, Recall = 90.72%
# POS F1 = 97.98%, Accuracy = 97.98%
# Shape F1 = 98.54%, Accuracy = 98.54%
# ================================== Test  Data ==================================
# F1 = 88.20%, Precision = 85.66%, Recall = 86.91%
# POS F1 = 97.78%, Accuracy = 97.78%
# Shape F1 = 98.02%, Accuracy = 98.02%
# Time: 13.94s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.27s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.60%, Precision = 92.36%, Recall = 92.48%
# POS F1 = 98.47%, Accuracy = 98.47%
# Shape F1 = 98.74%, Accuracy = 98.74%
# ================================== Valid Data ==================================
# F1 = 91.25%, Precision = 90.96%, Recall = 91.11%
# POS F1 = 98.01%, Accuracy = 98.01%
# Shape F1 = 98.61%, Accuracy = 98.61%
# ================================== Test  Data ==================================
# F1 = 87.59%, Precision = 87.84%, Recall = 87.71%
# POS F1 = 97.86%, Accuracy = 97.86%
# Shape F1 = 98.13%, Accuracy = 98.13%
# Time: 13.60s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.06%, Precision = 91.44%, Recall = 92.24%
# POS F1 = 98.51%, Accuracy = 98.51%
# Shape F1 = 98.70%, Accuracy = 98.70%
# ================================== Valid Data ==================================
# F1 = 91.57%, Precision = 89.99%, Recall = 90.77%
# POS F1 = 98.04%, Accuracy = 98.04%
# Shape F1 = 98.57%, Accuracy = 98.57%
# ================================== Test  Data ==================================
# F1 = 88.74%, Precision = 86.65%, Recall = 87.68%
# POS F1 = 97.88%, Accuracy = 97.88%
# Shape F1 = 98.06%, Accuracy = 98.06%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.04%, Precision = 92.02%, Recall = 92.53%
# POS F1 = 98.58%, Accuracy = 98.58%
# Shape F1 = 98.76%, Accuracy = 98.76%
# ================================== Valid Data ==================================
# F1 = 91.50%, Precision = 90.59%, Recall = 91.04%
# POS F1 = 98.14%, Accuracy = 98.14%
# Shape F1 = 98.61%, Accuracy = 98.61%
# ================================== Test  Data ==================================
# F1 = 88.37%, Precision = 87.22%, Recall = 87.79%
# POS F1 = 97.97%, Accuracy = 97.97%
# Shape F1 = 98.20%, Accuracy = 98.20%
# Time: 13.63s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.44%, Precision = 92.23%, Recall = 92.83%
# POS F1 = 98.52%, Accuracy = 98.52%
# Shape F1 = 98.74%, Accuracy = 98.74%
# ================================== Valid Data ==================================
# F1 = 91.70%, Precision = 90.53%, Recall = 91.11%
# POS F1 = 98.05%, Accuracy = 98.05%
# Shape F1 = 98.59%, Accuracy = 98.59%
# ================================== Test  Data ==================================
# F1 = 88.42%, Precision = 87.18%, Recall = 87.80%
# POS F1 = 97.85%, Accuracy = 97.85%
# Shape F1 = 98.08%, Accuracy = 98.08%
# Time: 13.58s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.95%, Precision = 91.93%, Recall = 92.44%
# POS F1 = 98.52%, Accuracy = 98.52%
# Shape F1 = 98.75%, Accuracy = 98.75%
# ================================== Valid Data ==================================
# F1 = 91.39%, Precision = 90.36%, Recall = 90.87%
# POS F1 = 98.09%, Accuracy = 98.09%
# Shape F1 = 98.58%, Accuracy = 98.58%
# ================================== Test  Data ==================================
# F1 = 88.12%, Precision = 87.22%, Recall = 87.67%
# POS F1 = 97.84%, Accuracy = 97.84%
# Shape F1 = 98.09%, Accuracy = 98.09%
# Time: 13.63s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.28%, Precision = 91.99%, Recall = 92.63%
# POS F1 = 98.56%, Accuracy = 98.56%
# Shape F1 = 98.76%, Accuracy = 98.76%
# ================================== Valid Data ==================================
# F1 = 91.54%, Precision = 90.56%, Recall = 91.05%
# POS F1 = 98.10%, Accuracy = 98.10%
# Shape F1 = 98.59%, Accuracy = 98.59%
# ================================== Test  Data ==================================
# F1 = 88.30%, Precision = 86.84%, Recall = 87.57%
# POS F1 = 97.89%, Accuracy = 97.89%
# Shape F1 = 98.06%, Accuracy = 98.06%
# Time: 13.60s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.60%, Precision = 92.17%, Recall = 92.88%
# POS F1 = 98.54%, Accuracy = 98.54%
# Shape F1 = 98.82%, Accuracy = 98.82%
# ================================== Valid Data ==================================
# F1 = 91.78%, Precision = 90.37%, Recall = 91.07%
# POS F1 = 98.07%, Accuracy = 98.07%
# Shape F1 = 98.64%, Accuracy = 98.64%
# ================================== Test  Data ==================================
# F1 = 88.81%, Precision = 87.02%, Recall = 87.91%
# POS F1 = 97.90%, Accuracy = 97.90%
# Shape F1 = 98.12%, Accuracy = 98.12%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.21s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.07%, Precision = 92.33%, Recall = 92.70%
# POS F1 = 98.57%, Accuracy = 98.57%
# Shape F1 = 98.81%, Accuracy = 98.81%
# ================================== Valid Data ==================================
# F1 = 91.34%, Precision = 90.71%, Recall = 91.02%
# POS F1 = 98.10%, Accuracy = 98.10%
# Shape F1 = 98.65%, Accuracy = 98.65%
# ================================== Test  Data ==================================
# F1 = 87.94%, Precision = 87.06%, Recall = 87.50%
# POS F1 = 97.94%, Accuracy = 97.94%
# Shape F1 = 98.15%, Accuracy = 98.15%
# Time: 13.65s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.66%, Precision = 91.57%, Recall = 92.60%
# POS F1 = 98.62%, Accuracy = 98.62%
# Shape F1 = 98.81%, Accuracy = 98.81%
# ================================== Valid Data ==================================
# F1 = 92.11%, Precision = 90.02%, Recall = 91.05%
# POS F1 = 98.14%, Accuracy = 98.14%
# Shape F1 = 98.63%, Accuracy = 98.63%
# ================================== Test  Data ==================================
# F1 = 89.01%, Precision = 86.63%, Recall = 87.81%
# POS F1 = 97.97%, Accuracy = 97.97%
# Shape F1 = 98.16%, Accuracy = 98.16%
# Time: 13.81s
#
# ----------------------------------- EPOCH: 55 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.18%, Precision = 91.76%, Recall = 92.95%
# ...
# F1 = 98.81%, Precision = 98.35%, Recall = 98.58%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.76%, Precision = 93.15%, Recall = 93.95%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.47%, Accuracy = 99.47%
# ================================== Test  Data ==================================
# F1 = 91.11%, Precision = 89.25%, Recall = 90.17%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.02%, Accuracy = 99.02%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 975 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.83%, Precision = 98.53%, Recall = 98.68%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.43%, Precision = 93.25%, Recall = 93.84%
# POS F1 = 98.95%, Accuracy = 98.95%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.99%, Precision = 89.55%, Recall = 90.27%
# POS F1 = 98.90%, Accuracy = 98.90%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.49s
#
# ----------------------------------- EPOCH: 976 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.84%, Precision = 98.62%, Recall = 98.73%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 93.17%, Recall = 93.70%
# POS F1 = 98.95%, Accuracy = 98.95%
# Shape F1 = 99.49%, Accuracy = 99.49%
# ================================== Test  Data ==================================
# F1 = 90.92%, Precision = 89.52%, Recall = 90.21%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.54s
#
# ----------------------------------- EPOCH: 977 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.21s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 98.53%, Recall = 98.71%
# POS F1 = 99.68%, Accuracy = 99.68%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 93.44%, Recall = 94.03%
# POS F1 = 98.95%, Accuracy = 98.95%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 91.12%, Precision = 89.59%, Recall = 90.35%
# POS F1 = 98.90%, Accuracy = 98.90%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.55s
#
# ----------------------------------- EPOCH: 978 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.83%, Precision = 98.71%, Recall = 98.77%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.53%, Precision = 93.59%, Recall = 94.05%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.88%, Precision = 89.85%, Recall = 90.37%
# POS F1 = 98.90%, Accuracy = 98.90%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.55s
#
# ----------------------------------- EPOCH: 979 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.41%, Precision = 97.84%, Recall = 98.12%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.86%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.06%, Precision = 92.49%, Recall = 93.27%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.56%, Precision = 88.79%, Recall = 89.67%
# POS F1 = 98.88%, Accuracy = 98.88%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 980 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.79%, Precision = 98.72%, Recall = 98.75%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.36%, Precision = 93.71%, Recall = 94.03%
# POS F1 = 98.97%, Accuracy = 98.97%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.36%, Precision = 89.96%, Recall = 90.16%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 981 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.83%, Precision = 98.66%, Recall = 98.75%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.46%, Precision = 93.91%, Recall = 94.19%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.47%, Accuracy = 99.47%
# ================================== Test  Data ==================================
# F1 = 90.29%, Precision = 90.01%, Recall = 90.15%
# POS F1 = 98.90%, Accuracy = 98.90%
# Shape F1 = 99.02%, Accuracy = 99.02%
# Time: 13.58s
#
# ----------------------------------- EPOCH: 982 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.12s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.73%, Precision = 98.58%, Recall = 98.66%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.22%, Precision = 93.29%, Recall = 93.75%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.47%, Accuracy = 99.47%
# ================================== Test  Data ==================================
# F1 = 90.47%, Precision = 89.41%, Recall = 89.94%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 983 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.29s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.79%, Precision = 98.60%, Recall = 98.69%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.32%, Precision = 93.60%, Recall = 93.96%
# POS F1 = 98.97%, Accuracy = 98.97%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.65%, Precision = 89.77%, Recall = 90.21%
# POS F1 = 98.91%, Accuracy = 98.91%
# Shape F1 = 99.02%, Accuracy = 99.02%
# Time: 13.54s
#
# ----------------------------------- EPOCH: 984 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.17s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.82%, Precision = 98.66%, Recall = 98.74%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 93.45%, Recall = 93.85%
# POS F1 = 98.95%, Accuracy = 98.95%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.76%, Precision = 89.73%, Recall = 90.24%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.54s
#
# ----------------------------------- EPOCH: 985 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.08s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.82%, Precision = 98.70%, Recall = 98.76%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.46%, Precision = 93.52%, Recall = 93.99%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.77%, Precision = 89.82%, Recall = 90.29%
# POS F1 = 98.91%, Accuracy = 98.91%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.47s
#
# ----------------------------------- EPOCH: 986 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.71%, Precision = 98.46%, Recall = 98.59%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.86%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.37%, Precision = 93.17%, Recall = 93.77%
# POS F1 = 98.94%, Accuracy = 98.94%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.88%, Precision = 89.27%, Recall = 90.07%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.56s
#
# ----------------------------------- EPOCH: 987 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.08s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.83%, Precision = 98.55%, Recall = 98.69%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.42%, Precision = 93.34%, Recall = 93.87%
# POS F1 = 98.97%, Accuracy = 98.97%
# Shape F1 = 99.47%, Accuracy = 99.47%
# ================================== Test  Data ==================================
# F1 = 90.85%, Precision = 89.43%, Recall = 90.13%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.46s
#
# ----------------------------------- EPOCH: 988 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.13s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.71%, Precision = 98.57%, Recall = 98.64%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.22%, Precision = 93.74%, Recall = 93.98%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 90.20%, Precision = 89.91%, Recall = 90.05%
# POS F1 = 98.88%, Accuracy = 98.88%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 989 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.81%, Precision = 98.50%, Recall = 98.66%
# POS F1 = 99.66%, Accuracy = 99.66%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.40%, Precision = 93.25%, Recall = 93.82%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.48%, Accuracy = 99.48%
# ================================== Test  Data ==================================
# F1 = 91.08%, Precision = 89.54%, Recall = 90.30%
# POS F1 = 98.90%, Accuracy = 98.90%
# Shape F1 = 99.03%, Accuracy = 99.03%
# Time: 13.52s
#
# ----------------------------------- EPOCH: 990 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 98.61%, Recall = 98.75%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.57%, Precision = 93.45%, Recall = 94.01%
# POS F1 = 98.96%, Accuracy = 98.96%
# Shape F1 = 99.49%, Accuracy = 99.49%
# ================================== Test  Data ==================================
# F1 = 91.12%, Precision = 89.73%, Recall = 90.42%
# POS F1 = 98.89%, Accuracy = 98.89%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.64s
#
# ----------------------------------- EPOCH: 991 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.86%, Precision = 98.62%, Recall = 98.74%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.43%, Precision = 93.34%, Recall = 93.88%
# POS F1 = 98.95%, Accuracy = 98.95%
# Shape F1 = 99.49%, Accuracy = 99.49%
# ================================== Test  Data ==================================
# F1 = 90.97%, Precision = 89.75%, Recall = 90.36%
# POS F1 = 98.88%, Accuracy = 98.88%
# Shape F1 = 99.04%, Accuracy = 99.04%
# Time: 13.73s
#
# ----------------------------------- EPOCH: 992 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.87%, Precision = 98.69%, Recall = 98.78%
# POS F1 = 99.67%, Accuracy = 99.67%
# Shape F1 = 99.87%, Accuracy = 99.87%

# %%
# 91.40
