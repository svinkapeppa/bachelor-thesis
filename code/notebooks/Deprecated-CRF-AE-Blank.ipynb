# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %%
# !chmod 777 install
# !./install

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 32
LSTM_DIM = 300
CHAR_EMB_DIM = 20
KERNEL_SIZE = 3
CHAR_FILTERS = 20
DROPOUT = 0.4
RECURRENT_DROPOUT = 0.4

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(0.1), maxval=math.sqrt(0.1))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT
    ))(embeddings)
    output = Dropout(DROPOUT)(output)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(3, activation='elu'))(output)
    shape = TimeDistributed(Dense(151, activation='elu'))(output)
    position = TimeDistributed(Dense(45, activation='elu'))(output)
    
    return Model(inputs=[word_input, case_input, char_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy],
              optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    true_seqs, pred_seqs = [], []

    for batch in batches:
        target = batch['tag']
        target = target.reshape((target.shape[0], target.shape[1]))
        logits = model.predict([batch['word'], batch['case'], batch['char']], verbose=False)[0].argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in target[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in logits[seq_ind, 1: seq_len + 1]]))

    return evaluate(true_seqs, pred_seqs, verbose=False)

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:107: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 66.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 58.02%, Precision = 23.10%, Recall = 33.04%
# ================================== Valid Data ==================================
# F1 = 67.55%, Precision = 24.52%, Recall = 35.98%
# ================================== Test  Data ==================================
# F1 = 58.48%, Precision = 24.66%, Recall = 34.69%
# Time: 14.14s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.93s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 64.53%, Precision = 55.29%, Recall = 59.55%
# ================================== Valid Data ==================================
# F1 = 68.09%, Precision = 56.01%, Recall = 61.46%
# ================================== Test  Data ==================================
# F1 = 64.42%, Precision = 56.44%, Recall = 60.17%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.16s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 69.11%, Precision = 64.19%, Recall = 66.56%
# ================================== Valid Data ==================================
# F1 = 72.01%, Precision = 65.20%, Recall = 68.43%
# ================================== Test  Data ==================================
# F1 = 68.68%, Precision = 63.83%, Recall = 66.16%
# Time: 14.23s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.49s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 72.10%, Precision = 72.39%, Recall = 72.24%
# ================================== Valid Data ==================================
# F1 = 74.96%, Precision = 74.27%, Recall = 74.61%
# ================================== Test  Data ==================================
# F1 = 70.79%, Precision = 71.14%, Recall = 70.96%
# Time: 13.59s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 75.52%, Precision = 76.17%, Recall = 75.84%
# ================================== Valid Data ==================================
# F1 = 77.54%, Precision = 77.40%, Recall = 77.47%
# ================================== Test  Data ==================================
# F1 = 73.32%, Precision = 74.04%, Recall = 73.68%
# Time: 13.59s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.78s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 78.73%, Precision = 78.05%, Recall = 78.39%
# ================================== Valid Data ==================================
# F1 = 79.97%, Precision = 79.00%, Recall = 79.48%
# ================================== Test  Data ==================================
# F1 = 76.61%, Precision = 75.81%, Recall = 76.21%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 79.25%, Precision = 80.20%, Recall = 79.72%
# ================================== Valid Data ==================================
# F1 = 80.49%, Precision = 81.17%, Recall = 80.83%
# ================================== Test  Data ==================================
# F1 = 77.23%, Precision = 78.03%, Recall = 77.63%
# Time: 13.67s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.03s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 80.35%, Precision = 80.99%, Recall = 80.67%
# ================================== Valid Data ==================================
# F1 = 81.70%, Precision = 81.87%, Recall = 81.79%
# ================================== Test  Data ==================================
# F1 = 78.13%, Precision = 78.63%, Recall = 78.38%
# Time: 14.39s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.08%, Precision = 81.20%, Recall = 81.64%
# ================================== Valid Data ==================================
# F1 = 82.92%, Precision = 82.30%, Recall = 82.61%
# ================================== Test  Data ==================================
# F1 = 79.87%, Precision = 78.88%, Recall = 79.37%
# Time: 13.64s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 80.86%, Precision = 83.12%, Recall = 81.97%
# ================================== Valid Data ==================================
# F1 = 82.04%, Precision = 84.18%, Recall = 83.10%
# ================================== Test  Data ==================================
# F1 = 77.80%, Precision = 80.24%, Recall = 79.00%
# Time: 13.65s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.80s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.83%, Precision = 82.59%, Recall = 82.71%
# ================================== Valid Data ==================================
# F1 = 83.92%, Precision = 83.25%, Recall = 83.59%
# ================================== Test  Data ==================================
# F1 = 80.40%, Precision = 79.89%, Recall = 80.14%
# Time: 14.24s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.73s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.20%, Precision = 83.55%, Recall = 82.87%
# ================================== Valid Data ==================================
# F1 = 83.18%, Precision = 84.42%, Recall = 83.80%
# ================================== Test  Data ==================================
# F1 = 79.44%, Precision = 80.77%, Recall = 80.10%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.55%, Precision = 84.71%, Recall = 84.13%
# ================================== Valid Data ==================================
# F1 = 83.91%, Precision = 85.02%, Recall = 84.46%
# ================================== Test  Data ==================================
# F1 = 80.59%, Precision = 81.73%, Recall = 81.15%
# Time: 14.54s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.13s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.68%, Precision = 84.23%, Recall = 84.46%
# ================================== Valid Data ==================================
# F1 = 85.19%, Precision = 84.38%, Recall = 84.78%
# ================================== Test  Data ==================================
# F1 = 81.60%, Precision = 80.86%, Recall = 81.23%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.73%, Precision = 84.88%, Recall = 84.81%
# ================================== Valid Data ==================================
# F1 = 85.20%, Precision = 84.97%, Recall = 85.09%
# ================================== Test  Data ==================================
# F1 = 81.99%, Precision = 81.98%, Recall = 81.98%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.37%, Precision = 85.71%, Recall = 85.54%
# ================================== Valid Data ==================================
# F1 = 85.46%, Precision = 85.56%, Recall = 85.51%
# ================================== Test  Data ==================================
# F1 = 82.33%, Precision = 82.65%, Recall = 82.49%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.94s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.07%, Precision = 85.08%, Recall = 85.57%
# ================================== Valid Data ==================================
# F1 = 85.72%, Precision = 84.55%, Recall = 85.13%
# ================================== Test  Data ==================================
# F1 = 83.33%, Precision = 82.05%, Recall = 82.68%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.77%, Precision = 85.78%, Recall = 85.78%
# ================================== Valid Data ==================================
# F1 = 85.69%, Precision = 85.63%, Recall = 85.66%
# ================================== Test  Data ==================================
# F1 = 82.39%, Precision = 82.37%, Recall = 82.38%
# Time: 14.75s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.69%, Precision = 87.04%, Recall = 86.36%
# ================================== Valid Data ==================================
# F1 = 85.67%, Precision = 86.60%, Recall = 86.13%
# ================================== Test  Data ==================================
# F1 = 82.26%, Precision = 83.92%, Recall = 83.09%
# Time: 14.86s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.42%, Precision = 86.53%, Recall = 86.48%
# ================================== Valid Data ==================================
# F1 = 86.44%, Precision = 86.23%, Recall = 86.34%
# ================================== Test  Data ==================================
# F1 = 83.26%, Precision = 83.11%, Recall = 83.18%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.04s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.34%, Precision = 87.24%, Recall = 86.79%
# ================================== Valid Data ==================================
# F1 = 85.98%, Precision = 86.87%, Recall = 86.42%
# ================================== Test  Data ==================================
# F1 = 82.71%, Precision = 84.28%, Recall = 83.49%
# Time: 13.74s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.06s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.67%, Precision = 86.98%, Recall = 87.33%
# ================================== Valid Data ==================================
# F1 = 87.29%, Precision = 86.44%, Recall = 86.86%
# ================================== Test  Data ==================================
# F1 = 84.03%, Precision = 83.46%, Recall = 83.74%
# Time: 13.63s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.29s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.14%, Precision = 87.47%, Recall = 87.30%
# ================================== Valid Data ==================================
# F1 = 86.44%, Precision = 86.81%, Recall = 86.62%
# ================================== Test  Data ==================================
# F1 = 83.09%, Precision = 83.68%, Recall = 83.38%
# Time: 14.74s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.12%, Precision = 88.27%, Recall = 87.69%
# ================================== Valid Data ==================================
# F1 = 87.18%, Precision = 87.65%, Recall = 87.41%
# ================================== Test  Data ==================================
# F1 = 83.50%, Precision = 84.58%, Recall = 84.04%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.66%, Precision = 88.34%, Recall = 88.00%
# ================================== Valid Data ==================================
# F1 = 87.19%, Precision = 87.60%, Recall = 87.39%
# ================================== Test  Data ==================================
# F1 = 83.54%, Precision = 84.49%, Recall = 84.01%
# Time: 13.73s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.45s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.29%, Precision = 88.47%, Recall = 88.38%
# ================================== Valid Data ==================================
# F1 = 88.02%, Precision = 87.65%, Recall = 87.83%
# ================================== Test  Data ==================================
# F1 = 84.72%, Precision = 84.83%, Recall = 84.77%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.08s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.31%, Precision = 88.31%, Recall = 87.81%
# ================================== Valid Data ==================================
# F1 = 87.30%, Precision = 87.82%, Recall = 87.56%
# ================================== Test  Data ==================================
# F1 = 83.62%, Precision = 84.63%, Recall = 84.13%
# Time: 13.74s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.77%, Precision = 88.85%, Recall = 88.31%
# ================================== Valid Data ==================================
# F1 = 87.70%, Precision = 88.29%, Recall = 87.99%
# ================================== Test  Data ==================================
# F1 = 83.66%, Precision = 84.97%, Recall = 84.31%
# Time: 14.72s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.14%, Precision = 88.80%, Recall = 88.47%
# ================================== Valid Data ==================================
# F1 = 87.88%, Precision = 88.02%, Recall = 87.95%
# ================================== Test  Data ==================================
# F1 = 83.98%, Precision = 84.90%, Recall = 84.43%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.89%, Precision = 88.80%, Recall = 88.84%
# ================================== Valid Data ==================================
# F1 = 88.71%, Precision = 88.07%, Recall = 88.39%
# ================================== Test  Data ==================================
# F1 = 84.72%, Precision = 84.70%, Recall = 84.71%
# Time: 13.90s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.06s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.43%, Precision = 89.21%, Recall = 88.81%
# ================================== Valid Data ==================================
# F1 = 88.57%, Precision = 88.67%, Recall = 88.62%
# ================================== Test  Data ==================================
# F1 = 84.52%, Precision = 85.53%, Recall = 85.02%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.13s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.34%, Precision = 89.17%, Recall = 89.26%
# ================================== Valid Data ==================================
# F1 = 89.11%, Precision = 88.44%, Recall = 88.77%
# ================================== Test  Data ==================================
# F1 = 85.20%, Precision = 85.09%, Recall = 85.14%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.78%, Precision = 89.87%, Recall = 89.32%
# ================================== Valid Data ==================================
# F1 = 88.46%, Precision = 89.15%, Recall = 88.80%
# ================================== Test  Data ==================================
# F1 = 84.39%, Precision = 85.96%, Recall = 85.17%
# Time: 14.43s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.47%, Precision = 89.28%, Recall = 89.37%
# ================================== Valid Data ==================================
# F1 = 89.20%, Precision = 88.54%, Recall = 88.87%
# ================================== Test  Data ==================================
# F1 = 85.39%, Precision = 85.29%, Recall = 85.34%
# Time: 13.85s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.22%, Precision = 88.91%, Recall = 89.56%
# ================================== Valid Data ==================================
# F1 = 89.70%, Precision = 88.19%, Recall = 88.93%
# ================================== Test  Data ==================================
# F1 = 85.90%, Precision = 84.56%, Recall = 85.22%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.91%, Precision = 89.80%, Recall = 89.36%
# ================================== Valid Data ==================================
# F1 = 88.35%, Precision = 88.98%, Recall = 88.66%
# ================================== Test  Data ==================================
# F1 = 84.69%, Precision = 85.69%, Recall = 85.19%
# Time: 13.74s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.95%, Precision = 89.75%, Recall = 89.85%
# ================================== Valid Data ==================================
# F1 = 89.94%, Precision = 89.11%, Recall = 89.53%
# ================================== Test  Data ==================================
# F1 = 85.70%, Precision = 85.61%, Recall = 85.65%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.82%, Precision = 89.90%, Recall = 89.86%
# ================================== Valid Data ==================================
# F1 = 89.51%, Precision = 89.01%, Recall = 89.26%
# ================================== Test  Data ==================================
# F1 = 85.78%, Precision = 85.96%, Recall = 85.87%
# Time: 15.13s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.70s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.38%, Precision = 90.11%, Recall = 90.24%
# ================================== Valid Data ==================================
# F1 = 90.18%, Precision = 89.18%, Recall = 89.68%
# ================================== Test  Data ==================================
# F1 = 85.96%, Precision = 85.87%, Recall = 85.92%
# Time: 14.22s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.19%, Precision = 89.96%, Recall = 90.08%
# ================================== Valid Data ==================================
# F1 = 89.83%, Precision = 89.08%, Recall = 89.45%
# ================================== Test  Data ==================================
# F1 = 85.79%, Precision = 85.64%, Recall = 85.72%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.11s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.28%, Precision = 90.43%, Recall = 90.35%
# ================================== Valid Data ==================================
# F1 = 89.89%, Precision = 89.35%, Recall = 89.62%
# ================================== Test  Data ==================================
# F1 = 85.82%, Precision = 86.05%, Recall = 85.93%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.12s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.51%, Precision = 90.22%, Recall = 90.37%
# ================================== Valid Data ==================================
# F1 = 90.14%, Precision = 89.11%, Recall = 89.62%
# ================================== Test  Data ==================================
# F1 = 85.88%, Precision = 85.53%, Recall = 85.71%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.50%, Precision = 90.30%, Recall = 90.40%
# ================================== Valid Data ==================================
# F1 = 89.99%, Precision = 89.09%, Recall = 89.54%
# ================================== Test  Data ==================================
# F1 = 86.12%, Precision = 85.91%, Recall = 86.01%
# Time: 14.08s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.73s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.31%, Precision = 90.73%, Recall = 90.52%
# ================================== Valid Data ==================================
# F1 = 90.26%, Precision = 90.04%, Recall = 90.15%
# ================================== Test  Data ==================================
# F1 = 86.02%, Precision = 86.61%, Recall = 86.32%
# Time: 14.99s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.51%, Precision = 90.72%, Recall = 90.62%
# ================================== Valid Data ==================================
# F1 = 90.10%, Precision = 89.78%, Recall = 89.94%
# ================================== Test  Data ==================================
# F1 = 86.03%, Precision = 86.47%, Recall = 86.25%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.94%, Precision = 89.85%, Recall = 90.39%
# ================================== Valid Data ==================================
# F1 = 90.33%, Precision = 88.83%, Recall = 89.57%
# ================================== Test  Data ==================================
# F1 = 86.47%, Precision = 85.34%, Recall = 85.90%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.17%, Precision = 90.93%, Recall = 90.55%
# ================================== Valid Data ==================================
# F1 = 89.76%, Precision = 89.97%, Recall = 89.86%
# ================================== Test  Data ==================================
# F1 = 85.71%, Precision = 86.74%, Recall = 86.22%
# Time: 13.77s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 52.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.49%, Precision = 90.39%, Recall = 90.44%
# ================================== Valid Data ==================================
# F1 = 89.91%, Precision = 89.40%, Recall = 89.65%
# ================================== Test  Data ==================================
# F1 = 86.09%, Precision = 85.91%, Recall = 86.00%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.03%, Precision = 90.94%, Recall = 90.99%
# ================================== Valid Data ==================================
# F1 = 90.62%, Precision = 89.87%, Recall = 90.24%
# ================================== Test  Data ==================================
# F1 = 86.51%, Precision = 86.60%, Recall = 86.55%
# Time: 14.77s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.76%, Precision = 91.13%, Recall = 90.94%
# ================================== Valid Data ==================================
# F1 = 90.14%, Precision = 90.14%, Recall = 90.14%
# ================================== Test  Data ==================================
# F1 = 86.10%, Precision = 86.83%, Recall = 86.46%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.99s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.62%, Precision = 90.82%, Recall = 90.72%
# ================================== Valid Data ==================================
# F1 = 89.79%, Precision = 89.65%, Recall = 89.72%
# ================================== Test  Data ==================================
# F1 = 85.80%, Precision = 86.12%, Recall = 85.96%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.01s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.88%, Precision = 91.03%, Recall = 90.96%
# ================================== Valid Data ==================================
# F1 = 90.44%, Precision = 90.07%, Recall = 90.25%
# ================================== Test  Data ==================================
# F1 = 86.54%, Precision = 86.86%, Recall = 86.70%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.92s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.94%, Precision = 90.85%, Recall = 91.39%
# ================================== Valid Data ==================================
# F1 = 91.17%, Precision = 89.65%, Recall = 90.40%
# ================================== Test  Data ==================================
# F1 = 87.41%, Precision = 86.03%, Recall = 86.71%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.14%, Precision = 91.11%, Recall = 91.13%
# ================================== Valid Data ==================================
# F1 = 90.74%, Precision = 90.34%, Recall = 90.54%
# ================================== Test  Data ==================================
# F1 = 86.83%, Precision = 86.99%, Recall = 86.91%
# Time: 14.73s
#
# ----------------------------------- EPOCH: 55 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.37%, Precision = 91.27%, Recall = 91.32%
# ================================== Valid Data ==================================
# F1 = 90.87%, Precision = 90.26%, Recall = 90.56%
# ================================== Test  Data ==================================
# F1 = 86.86%, Precision = 86.88%, Recall = 86.87%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 56 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.98s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.17%, Precision = 91.31%, Recall = 91.24%
# ================================== Valid Data ==================================
# F1 = 90.43%, Precision = 90.37%, Recall = 90.40%
# ================================== Test  Data ==================================
# F1 = 86.43%, Precision = 86.83%, Recall = 86.63%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 57 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.16s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.74%, Precision = 91.47%, Recall = 91.60%
# ================================== Valid Data ==================================
# F1 = 91.20%, Precision = 90.19%, Recall = 90.69%
# ================================== Test  Data ==================================
# F1 = 87.23%, Precision = 87.06%, Recall = 87.14%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 58 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.75%, Precision = 91.15%, Recall = 91.45%
# ================================== Valid Data ==================================
# F1 = 90.86%, Precision = 90.04%, Recall = 90.45%
# ================================== Test  Data ==================================
# F1 = 87.28%, Precision = 86.76%, Recall = 87.02%
# Time: 14.36s
#
# ----------------------------------- EPOCH: 59 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.52s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.65%, Precision = 91.62%, Recall = 91.63%
# ================================== Valid Data ==================================
# F1 = 90.90%, Precision = 90.46%, Recall = 90.68%
# ================================== Test  Data ==================================
# F1 = 86.69%, Precision = 87.18%, Recall = 86.94%
# Time: 14.47s
#
# ----------------------------------- EPOCH: 60 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.72%, Precision = 91.25%, Recall = 91.48%
# ================================== Valid Data ==================================
# F1 = 90.87%, Precision = 90.10%, Recall = 90.49%
# ================================== Test  Data ==================================
# F1 = 87.35%, Precision = 86.93%, Recall = 87.14%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 61 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.04%, Precision = 91.79%, Recall = 91.41%
# ================================== Valid Data ==================================
# F1 = 90.49%, Precision = 90.76%, Recall = 90.62%
# ================================== Test  Data ==================================
# F1 = 86.40%, Precision = 87.82%, Recall = 87.10%
# Time: 13.69s
#
# ----------------------------------- EPOCH: 62 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.08s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.45%, Precision = 91.82%, Recall = 91.64%
# ================================== Valid Data ==================================
# F1 = 90.80%, Precision = 90.81%, Recall = 90.80%
# ================================== Test  Data ==================================
# F1 = 86.42%, Precision = 87.32%, Recall = 86.87%
# Time: 14.94s
#
# ----------------------------------- EPOCH: 63 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.82%, Precision = 91.54%, Recall = 91.68%
# ================================== Valid Data ==================================
# F1 = 90.92%, Precision = 90.34%, Recall = 90.63%
# ================================== Test  Data ==================================
# F1 = 87.06%, Precision = 87.11%, Recall = 87.09%
# Time: 13.67s
#
# ----------------------------------- EPOCH: 64 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.24%, Precision = 91.55%, Recall = 91.89%
# ================================== Valid Data ==================================
# F1 = 91.28%, Precision = 90.21%, Recall = 90.74%
# ================================== Test  Data ==================================
# F1 = 87.83%, Precision = 87.25%, Recall = 87.54%
# Time: 14.26s
#
# ----------------------------------- EPOCH: 65 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.78s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.28%, Precision = 91.73%, Recall = 92.01%
# ================================== Valid Data ==================================
# F1 = 91.05%, Precision = 90.24%, Recall = 90.64%
# ================================== Test  Data ==================================
# F1 = 87.77%, Precision = 87.41%, Recall = 87.59%
# Time: 14.19s
#
# ----------------------------------- EPOCH: 66 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.40%, Precision = 91.88%, Recall = 92.14%
# ================================== Valid Data ==================================
# F1 = 91.43%, Precision = 90.71%, Recall = 91.07%
# ================================== Test  Data ==================================
# F1 = 87.48%, Precision = 87.48%, Recall = 87.48%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 67 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.75s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.26%, Precision = 91.73%, Recall = 92.00%
# ================================== Valid Data ==================================
# F1 = 91.32%, Precision = 90.51%, Recall = 90.91%
# ================================== Test  Data ==================================
# F1 = 87.49%, Precision = 87.18%, Recall = 87.34%
# Time: 13.73s
#
# ----------------------------------- EPOCH: 68 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.29%, Precision = 91.99%, Recall = 92.14%
# ================================== Valid Data ==================================
# F1 = 91.45%, Precision = 90.91%, Recall = 91.18%
# ================================== Test  Data ==================================
# F1 = 87.20%, Precision = 87.32%, Recall = 87.26%
# Time: 13.73s
#
# ----------------------------------- EPOCH: 69 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.39%, Precision = 91.91%, Recall = 92.15%
# ================================== Valid Data ==================================
# F1 = 91.36%, Precision = 90.58%, Recall = 90.97%
# ================================== Test  Data ==================================
# F1 = 87.63%, Precision = 87.45%, Recall = 87.54%
# Time: 13.90s
#
# ----------------------------------- EPOCH: 70 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.40s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.55%, Precision = 92.03%, Recall = 92.29%
# ================================== Valid Data ==================================
# F1 = 91.63%, Precision = 90.81%, Recall = 91.22%
# ================================== Test  Data ==================================
# F1 = 87.62%, Precision = 87.55%, Recall = 87.58%
# Time: 14.42s
#
# ----------------------------------- EPOCH: 71 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.99%, Precision = 92.35%, Recall = 92.17%
# ================================== Valid Data ==================================
# F1 = 91.36%, Precision = 91.30%, Recall = 91.33%
# ================================== Test  Data ==================================
# F1 = 86.73%, Precision = 87.71%, Recall = 87.22%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 72 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 52.06s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.58%, Precision = 91.98%, Recall = 92.28%
# ================================== Valid Data ==================================
# F1 = 91.41%, Precision = 90.64%, Recall = 91.03%
# ...
# ----------------------------------- Training -----------------------------------
# Time: 51.10s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.51%, Precision = 98.54%, Recall = 98.53%
# ================================== Valid Data ==================================
# F1 = 93.94%, Precision = 93.98%, Recall = 93.96%
# ================================== Test  Data ==================================
# F1 = 89.82%, Precision = 90.14%, Recall = 89.98%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 636 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.66s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.50%, Precision = 98.51%, Recall = 98.51%
# ================================== Valid Data ==================================
# F1 = 94.13%, Precision = 94.24%, Recall = 94.19%
# ================================== Test  Data ==================================
# F1 = 89.81%, Precision = 90.32%, Recall = 90.06%
# Time: 14.81s
#
# ----------------------------------- EPOCH: 637 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.60s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.60%, Precision = 98.51%, Recall = 98.56%
# ================================== Valid Data ==================================
# F1 = 94.20%, Precision = 93.98%, Recall = 94.09%
# ================================== Test  Data ==================================
# F1 = 90.34%, Precision = 90.24%, Recall = 90.29%
# Time: 13.77s
#
# ----------------------------------- EPOCH: 638 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 52.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.40%, Precision = 98.55%, Recall = 98.48%
# ================================== Valid Data ==================================
# F1 = 93.73%, Precision = 94.16%, Recall = 93.95%
# ================================== Test  Data ==================================
# F1 = 89.29%, Precision = 90.23%, Recall = 89.76%
# Time: 14.31s
#
# ----------------------------------- EPOCH: 639 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.21s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.57%, Precision = 98.56%, Recall = 98.56%
# ================================== Valid Data ==================================
# F1 = 94.04%, Precision = 94.03%, Recall = 94.03%
# ================================== Test  Data ==================================
# F1 = 90.19%, Precision = 90.49%, Recall = 90.34%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 640 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.27s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.62%, Precision = 98.47%, Recall = 98.55%
# ================================== Valid Data ==================================
# F1 = 94.28%, Precision = 94.06%, Recall = 94.17%
# ================================== Test  Data ==================================
# F1 = 90.24%, Precision = 90.32%, Recall = 90.28%
# Time: 13.81s
#
# ----------------------------------- EPOCH: 641 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.55%, Precision = 98.57%, Recall = 98.56%
# ================================== Valid Data ==================================
# F1 = 93.89%, Precision = 94.06%, Recall = 93.97%
# ================================== Test  Data ==================================
# F1 = 89.72%, Precision = 90.42%, Recall = 90.07%
# Time: 14.71s
#
# ----------------------------------- EPOCH: 642 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.59%, Precision = 98.47%, Recall = 98.53%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 94.04%, Recall = 94.15%
# ================================== Test  Data ==================================
# F1 = 90.30%, Precision = 90.37%, Recall = 90.34%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 643 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.57%, Precision = 98.46%, Recall = 98.51%
# ================================== Valid Data ==================================
# F1 = 94.28%, Precision = 93.96%, Recall = 94.12%
# ================================== Test  Data ==================================
# F1 = 90.04%, Precision = 90.12%, Recall = 90.08%
# Time: 13.83s
#
# ----------------------------------- EPOCH: 644 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.58%, Precision = 98.58%, Recall = 98.58%
# ================================== Valid Data ==================================
# F1 = 94.08%, Precision = 94.09%, Recall = 94.08%
# ================================== Test  Data ==================================
# F1 = 90.09%, Precision = 90.46%, Recall = 90.27%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 645 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.53%, Precision = 98.46%, Recall = 98.50%
# ================================== Valid Data ==================================
# F1 = 94.13%, Precision = 93.96%, Recall = 94.05%
# ================================== Test  Data ==================================
# F1 = 90.16%, Precision = 90.32%, Recall = 90.24%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 646 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.79s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.52%, Precision = 98.58%, Recall = 98.55%
# ================================== Valid Data ==================================
# F1 = 93.85%, Precision = 94.04%, Recall = 93.95%
# ================================== Test  Data ==================================
# F1 = 89.97%, Precision = 90.51%, Recall = 90.24%
# Time: 14.35s
#
# ----------------------------------- EPOCH: 647 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.60%, Precision = 98.43%, Recall = 98.51%
# ================================== Valid Data ==================================
# F1 = 94.14%, Precision = 93.84%, Recall = 93.99%
# ================================== Test  Data ==================================
# F1 = 90.28%, Precision = 90.12%, Recall = 90.20%
# Time: 15.38s
#
# ----------------------------------- EPOCH: 648 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.55%, Precision = 98.63%, Recall = 98.59%
# ================================== Valid Data ==================================
# F1 = 94.04%, Precision = 94.24%, Recall = 94.14%
# ================================== Test  Data ==================================
# F1 = 89.99%, Precision = 90.56%, Recall = 90.28%
# Time: 13.85s
#
# ----------------------------------- EPOCH: 649 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.55%, Precision = 98.55%, Recall = 98.55%
# ================================== Valid Data ==================================
# F1 = 93.95%, Precision = 94.08%, Recall = 94.01%
# ================================== Test  Data ==================================
# F1 = 90.05%, Precision = 90.51%, Recall = 90.28%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 650 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.60%, Precision = 98.62%, Recall = 98.61%
# ================================== Valid Data ==================================
# F1 = 94.11%, Precision = 94.16%, Recall = 94.14%
# ================================== Test  Data ==================================
# F1 = 90.13%, Precision = 90.58%, Recall = 90.36%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 651 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.24s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.53%, Precision = 98.51%, Recall = 98.52%
# ================================== Valid Data ==================================
# F1 = 94.00%, Precision = 94.09%, Recall = 94.05%
# ================================== Test  Data ==================================
# F1 = 90.11%, Precision = 90.47%, Recall = 90.29%
# Time: 13.84s
#
# ----------------------------------- EPOCH: 652 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.51%, Precision = 98.67%, Recall = 98.59%
# ================================== Valid Data ==================================
# F1 = 93.80%, Precision = 94.24%, Recall = 94.02%
# ================================== Test  Data ==================================
# F1 = 89.83%, Precision = 90.60%, Recall = 90.22%
# Time: 14.74s
#
# ----------------------------------- EPOCH: 653 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.49%, Precision = 98.50%, Recall = 98.50%
# ================================== Valid Data ==================================
# F1 = 93.97%, Precision = 93.94%, Recall = 93.96%
# ================================== Test  Data ==================================
# F1 = 89.99%, Precision = 90.30%, Recall = 90.15%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 654 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.62%, Precision = 98.63%, Recall = 98.62%
# ================================== Valid Data ==================================
# F1 = 93.98%, Precision = 94.03%, Recall = 94.00%
# ================================== Test  Data ==================================
# F1 = 90.05%, Precision = 90.33%, Recall = 90.19%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 655 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.63%, Precision = 98.57%, Recall = 98.60%
# ================================== Valid Data ==================================
# F1 = 94.20%, Precision = 94.09%, Recall = 94.15%
# ================================== Test  Data ==================================
# F1 = 90.34%, Precision = 90.40%, Recall = 90.37%
# Time: 13.83s
#
# ----------------------------------- EPOCH: 656 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.18s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.53%, Precision = 98.59%, Recall = 98.56%
# ================================== Valid Data ==================================
# F1 = 93.91%, Precision = 94.03%, Recall = 93.97%
# ================================== Test  Data ==================================
# F1 = 89.99%, Precision = 90.44%, Recall = 90.22%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 657 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 51.73s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.57%, Precision = 98.73%, Recall = 98.65%
# ================================== Valid Data ==================================
# F1 = 93.90%, Precision = 94.31%, Recall = 94.11%
# ================================== Test  Data ==================================
# F1 = 89.84%, Precision = 90.53%, Recall = 90.18%
# Time: 14.80s
#
# ----------------------------------- EPOCH: 658 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.67%, Precision = 98.64%, Recall = 98.65%
# ================================== Valid Data ==================================
# F1 = 94.09%, Precision = 94.03%, Recall = 94.06%
# ================================== Test  Data ==================================
# F1 = 90.19%, Precision = 90.47%, Recall = 90.33%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 659 -----------------------------------
# ----------------------------------- Training -----------------------------------
