# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-miadajas
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-miadajas
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.3.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-acopbsfu/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
# !chmod 777 install
# !./install
# Out:
# --2019-06-25 19:18:27--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3281527 (3.1M) [text/plain]
# Saving to: ‘eng.train’
#
# eng.train           100%[===================>]   3.13M  --.-KB/s    in 0.1s
#
# 2019-06-25 19:18:28 (31.2 MB/s) - ‘eng.train’ saved [3281527/3281527]
#
# --2019-06-25 19:18:28--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827009 (808K) [text/plain]
# Saving to: ‘eng.testa’
#
# eng.testa           100%[===================>] 807.63K  --.-KB/s    in 0.06s
#
# 2019-06-25 19:18:28 (12.1 MB/s) - ‘eng.testa’ saved [827009/827009]
#
# --2019-06-25 19:18:28--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 748094 (731K) [text/plain]
# Saving to: ‘eng.testb’
#
# eng.testb           100%[===================>] 730.56K  --.-KB/s    in 0.06s
#
# 2019-06-25 19:18:28 (11.0 MB/s) - ‘eng.testb’ saved [748094/748094]
#
# --2019-06-25 19:18:28--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-06-25 19:18:28--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2019-06-25 19:18:29--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  37.4MB/s    in 23s
#
# 2019-06-25 19:18:51 (36.4 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
# Cloning into 'gdown.pl'...
# remote: Enumerating objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:13--  https://docs.google.com/uc?id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.101, 74.125.141.139, 74.125.141.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘all_onehot.train’
#
#      0K                                     47.3M=0s
#
# 2019-06-25 19:19:14 (47.3 MB/s) - ‘all_onehot.train’ saved [3252]
#
# --2019-06-25 19:19:14--  https://docs.google.com/uc?export=download&confirm=9Skk&id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w
# Resolving docs.google.com (docs.google.com)... 74.125.141.100, 74.125.141.138, 74.125.141.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jdlq6h93oqfbc694godn46r49slu2ngu/1561485600000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:14--  https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jdlq6h93oqfbc694godn46r49slu2ngu/1561485600000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download
# Resolving doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.train’
#
#      0K ........ ........ ........ ........  103M
#  32768K ........ ........ ........ ........  348M
#  65536K ........ ........ ........ ........  248M
#  98304K ........ ........ ........ ........  311M
# 131072K ........ ........ ........ ........  263M
# 163840K ........ ........ ........ ........  293M
# 196608K ........ ........ ........ ........  114M
# 229376K ........ ........ ........ ........  287M
# 262144K ........ ........ ........ ........  296M
# 294912K ........ ........ ........ ........  128M
# 327680K ........ ........ ........ ........  114M
# 360448K ........ ........ ......             110M=2.1s
#
# 2019-06-25 19:19:16 (178 MB/s) - ‘all_onehot.train’ saved [392581451]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:17--  https://docs.google.com/uc?id=1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.138, 74.125.141.139, 74.125.141.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0f6ebi7d4h9v9r1cjm0iit7c9ffltr3k/1561485600000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:20--  https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0f6ebi7d4h9v9r1cjm0iit7c9ffltr3k/1561485600000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download
# Resolving doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testa’
#
#      0K ........ ........ ........ ........  179M
#  32768K ........ ........ ........ ........  353M
#  65536K ........ ........ ........ ......    351M=0.4s
#
# 2019-06-25 19:19:20 (265 MB/s) - ‘all_onehot.testa’ saved [99026097]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:20--  https://docs.google.com/uc?id=1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.100, 74.125.141.102, 74.125.141.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/12nedfh4u9oca0t4qghbpshfseeklmuk/1561485600000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:23--  https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/12nedfh4u9oca0t4qghbpshfseeklmuk/1561485600000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download
# Resolving doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testb’
#
#      0K ........ ........ ........ ........ 79.4M
#  32768K ........ ........ ........ ........  314M
#  65536K ........ ........ .....              292M=0.6s
#
# 2019-06-25 19:19:24 (148 MB/s) - ‘all_onehot.testb’ saved [89526841]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:24--  https://docs.google.com/uc?id=1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.100, 74.125.141.138, 74.125.141.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/81mlkk0q4funucnt60tf1nb9388bcnrl/1561485600000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:25--  https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/81mlkk0q4funucnt60tf1nb9388bcnrl/1561485600000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download
# Resolving doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.train’
#
#      0K ....                                 202M=0.02s
#
# 2019-06-25 19:19:25 (202 MB/s) - ‘gazetteer_PERLOC.train’ saved [4887067]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:25--  https://docs.google.com/uc?id=1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.102, 74.125.141.101, 74.125.141.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m3ihti53kcgau4p4ib1l9bm2k5413krj/1561485600000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:25--  https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m3ihti53kcgau4p4ib1l9bm2k5413krj/1561485600000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download
# Resolving doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1232849 (1.2M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testa’
#
#      0K .                                  100%  129M=0.009s
#
# 2019-06-25 19:19:25 (129 MB/s) - ‘gazetteer_PERLOC.testa’ saved [1232849/1232849]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-25 19:19:25--  https://docs.google.com/uc?id=1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.141.138, 74.125.141.139, 74.125.141.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f3fthlihtqbmh03r0lg2isek6it5c2v5/1561485600000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-25 19:19:26--  https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f3fthlihtqbmh03r0lg2isek6it5c2v5/1561485600000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download
# Resolving doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1114601 (1.1M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testb’
#
#      0K .                                  100%  133M=0.008s
#
# 2019-06-25 19:19:26 (133 MB/s) - ‘gazetteer_PERLOC.testb’ saved [1114601/1114601]

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Adam
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 64
LSTM_DIM = 400
CHAR_EMB_DIM = 25
KERNEL_SIZE = 4
CHAR_FILTERS = 25
DROPOUT = 0.4
RECURRENT_DROPOUT = 0.5

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(3 / LSTM_DIM), maxval=math.sqrt(3 / LSTM_DIM))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    gaze_input = Input(shape=(None, 4))

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings, gaze_input])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT, implementation=1
    ))(embeddings)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(4, activation='softmax'))(output)
    shape = TimeDistributed(Dense(152, activation='softmax'))(output)
    position = TimeDistributed(Dense(46, activation='softmax'))(output)
    
    return Model(inputs=[word_input, case_input, char_input, gaze_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy],
              optimizer=SGD(lr=0.03, decay=1e-5, momentum=0.9, clipnorm=5, nesterov=True))

# %%
import numpy as np
from sklearn.metrics import f1_score
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    pos_true, pos_pred = [], []
    shp_true, shp_pred = [], []
    true_seqs, pred_seqs = [], []
    pos_total, pos_correct = 0, 0
    shp_total, shp_correct = 0, 0

    for batch in batches:
        tag = batch['tag']
        shp = batch['shape']
        pos = batch['position']

        tag = tag.reshape((tag.shape[0], tag.shape[1]))
        shp = shp.reshape((shp.shape[0], shp.shape[1]))
        pos = pos.reshape((pos.shape[0], pos.shape[1]))

        lstm, _, shape, position = model.predict([batch['word'], batch['case'], batch['char'], batch['gaze']], verbose=False)
        lstm = lstm.argmax(axis=-1)
        shape = shape.argmax(axis=-1)
        position = position.argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in tag[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in lstm[seq_ind, 1: seq_len + 1]]))
            
            true_pos = np.array([ind.item() for ind in pos[seq_ind, 1: seq_len + 1]])
            pred_pos = np.array([ind.item() for ind in position[seq_ind, 1: seq_len + 1]])
            
            pos_true += list(true_pos)
            pos_pred += list(pred_pos)
            
            pos_correct += np.sum(true_pos == pred_pos)
            pos_total += len(pred_pos)
            
            true_shp = np.array([ind.item() for ind in shp[seq_ind, 1: seq_len + 1]])
            pred_shp = np.array([ind.item() for ind in shape[seq_ind, 1: seq_len + 1]])
            
            shp_true += list(true_shp)
            shp_pred += list(pred_shp)
            
            shp_correct += np.sum(true_shp == pred_shp)
            shp_total += len(pred_shp)

    f, precision, recall = evaluate(true_seqs, pred_seqs, verbose=False)
    pos_accuracy = 100 * pos_correct / pos_total
    pos_f = 100 * f1_score(pos_true, pos_pred, average='macro') 
    shp_accuracy = 100 * shp_correct / shp_total
    shp_f = 100 * f1_score(shp_true, shp_pred, average='macro') 
    
    return f, precision, recall, pos_accuracy, pos_f, shp_accuracy, shp_f

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char'], batch['gaze']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 44.53s
# ---------------------------------- Evaluating ----------------------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# ================================== Train Data ==================================
# F1 = 63.25%, Precision = 65.56%, Recall = 64.39%
# POS F1 = 23.98%, Accuracy = 63.39%
# Shape F1 = 8.07%, Accuracy = 76.41%
# ================================== Valid Data ==================================
# F1 = 65.72%, Precision = 66.88%, Recall = 66.29%
# POS F1 = 23.94%, Accuracy = 62.30%
# Shape F1 = 9.34%, Accuracy = 75.91%
# ================================== Test  Data ==================================
# F1 = 62.28%, Precision = 65.69%, Recall = 63.94%
# POS F1 = 24.12%, Accuracy = 65.61%
# Shape F1 = 9.16%, Accuracy = 75.61%
# Time: 17.60s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 74.62%, Precision = 76.52%, Recall = 75.56%
# POS F1 = 38.01%, Accuracy = 76.42%
# Shape F1 = 14.22%, Accuracy = 85.77%
# ================================== Valid Data ==================================
# F1 = 76.28%, Precision = 77.84%, Recall = 77.05%
# POS F1 = 38.46%, Accuracy = 76.18%
# Shape F1 = 16.39%, Accuracy = 85.54%
# ================================== Test  Data ==================================
# F1 = 72.68%, Precision = 75.07%, Recall = 73.85%
# POS F1 = 39.20%, Accuracy = 77.51%
# Shape F1 = 16.32%, Accuracy = 85.07%
# Time: 15.73s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 80.71%, Precision = 80.05%, Recall = 80.38%
# POS F1 = 47.74%, Accuracy = 81.97%
# Shape F1 = 19.84%, Accuracy = 89.89%
# ================================== Valid Data ==================================
# F1 = 81.91%, Precision = 80.48%, Recall = 81.19%
# POS F1 = 47.70%, Accuracy = 81.45%
# Shape F1 = 23.15%, Accuracy = 89.76%
# ================================== Test  Data ==================================
# F1 = 78.04%, Precision = 77.21%, Recall = 77.63%
# POS F1 = 49.96%, Accuracy = 82.79%
# Shape F1 = 22.29%, Accuracy = 89.08%
# Time: 15.57s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 81.22%, Precision = 83.28%, Recall = 82.24%
# POS F1 = 51.31%, Accuracy = 84.37%
# Shape F1 = 21.76%, Accuracy = 91.79%
# ================================== Valid Data ==================================
# F1 = 82.61%, Precision = 84.01%, Recall = 83.30%
# POS F1 = 52.14%, Accuracy = 83.69%
# Shape F1 = 25.64%, Accuracy = 91.59%
# ================================== Test  Data ==================================
# F1 = 78.15%, Precision = 81.00%, Recall = 79.55%
# POS F1 = 53.19%, Accuracy = 84.80%
# Shape F1 = 25.47%, Accuracy = 90.88%
# Time: 15.62s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.29s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.17%, Precision = 85.19%, Recall = 84.16%
# POS F1 = 54.44%, Accuracy = 86.20%
# Shape F1 = 23.97%, Accuracy = 92.96%
# ================================== Valid Data ==================================
# F1 = 83.87%, Precision = 85.32%, Recall = 84.59%
# POS F1 = 55.33%, Accuracy = 85.56%
# Shape F1 = 27.95%, Accuracy = 92.85%
# ================================== Test  Data ==================================
# F1 = 79.40%, Precision = 81.55%, Recall = 80.46%
# POS F1 = 56.19%, Accuracy = 86.47%
# Shape F1 = 27.93%, Accuracy = 92.05%
# Time: 15.59s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.44s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.91%, Precision = 85.82%, Recall = 85.36%
# POS F1 = 56.74%, Accuracy = 87.09%
# Shape F1 = 25.96%, Accuracy = 94.06%
# ================================== Valid Data ==================================
# F1 = 85.96%, Precision = 86.45%, Recall = 86.21%
# POS F1 = 57.65%, Accuracy = 86.38%
# Shape F1 = 29.90%, Accuracy = 93.88%
# ================================== Test  Data ==================================
# F1 = 81.78%, Precision = 83.14%, Recall = 82.46%
# POS F1 = 58.45%, Accuracy = 87.28%
# Shape F1 = 29.69%, Accuracy = 92.96%
# Time: 15.66s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.18%, Precision = 87.50%, Recall = 86.83%
# POS F1 = 60.83%, Accuracy = 87.97%
# Shape F1 = 27.63%, Accuracy = 94.54%
# ================================== Valid Data ==================================
# F1 = 86.53%, Precision = 87.24%, Recall = 86.89%
# POS F1 = 60.24%, Accuracy = 87.34%
# Shape F1 = 30.28%, Accuracy = 94.24%
# ================================== Test  Data ==================================
# F1 = 82.76%, Precision = 84.74%, Recall = 83.74%
# POS F1 = 61.31%, Accuracy = 88.16%
# Shape F1 = 29.82%, Accuracy = 93.31%
# Time: 15.57s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.06%, Precision = 87.26%, Recall = 87.16%
# POS F1 = 62.92%, Accuracy = 88.66%
# Shape F1 = 28.47%, Accuracy = 95.31%
# ================================== Valid Data ==================================
# F1 = 87.33%, Precision = 87.14%, Recall = 87.24%
# POS F1 = 62.76%, Accuracy = 87.96%
# Shape F1 = 31.11%, Accuracy = 95.16%
# ================================== Test  Data ==================================
# F1 = 83.88%, Precision = 84.56%, Recall = 84.22%
# POS F1 = 63.78%, Accuracy = 88.85%
# Shape F1 = 30.91%, Accuracy = 94.19%
# Time: 15.72s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.27s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.46%, Precision = 88.87%, Recall = 88.16%
# POS F1 = 64.30%, Accuracy = 89.09%
# Shape F1 = 30.25%, Accuracy = 95.67%
# ================================== Valid Data ==================================
# F1 = 87.54%, Precision = 88.19%, Recall = 87.86%
# POS F1 = 63.90%, Accuracy = 88.35%
# Shape F1 = 32.18%, Accuracy = 95.54%
# ================================== Test  Data ==================================
# F1 = 83.26%, Precision = 85.25%, Recall = 84.24%
# POS F1 = 65.17%, Accuracy = 89.15%
# Shape F1 = 32.50%, Accuracy = 94.35%
# Time: 15.59s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.27s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.04%, Precision = 88.94%, Recall = 88.49%
# POS F1 = 65.88%, Accuracy = 89.51%
# Shape F1 = 31.35%, Accuracy = 96.35%
# ================================== Valid Data ==================================
# F1 = 87.84%, Precision = 88.15%, Recall = 88.00%
# POS F1 = 65.32%, Accuracy = 88.77%
# Shape F1 = 33.49%, Accuracy = 96.28%
# ================================== Test  Data ==================================
# F1 = 83.82%, Precision = 84.92%, Recall = 84.36%
# POS F1 = 66.46%, Accuracy = 89.44%
# Shape F1 = 34.16%, Accuracy = 95.03%
# Time: 15.66s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.25%, Precision = 89.73%, Recall = 88.99%
# POS F1 = 67.02%, Accuracy = 89.80%
# Shape F1 = 33.00%, Accuracy = 96.54%
# ================================== Valid Data ==================================
# F1 = 87.49%, Precision = 88.51%, Recall = 87.99%
# POS F1 = 66.19%, Accuracy = 88.93%
# Shape F1 = 34.76%, Accuracy = 96.44%
# ================================== Test  Data ==================================
# F1 = 83.54%, Precision = 85.80%, Recall = 84.65%
# POS F1 = 67.47%, Accuracy = 89.64%
# Shape F1 = 35.40%, Accuracy = 95.26%
# Time: 15.56s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.11%, Precision = 89.98%, Recall = 89.55%
# POS F1 = 68.42%, Accuracy = 90.32%
# Shape F1 = 34.86%, Accuracy = 96.91%
# ================================== Valid Data ==================================
# F1 = 88.39%, Precision = 89.08%, Recall = 88.73%
# POS F1 = 67.69%, Accuracy = 89.46%
# Shape F1 = 36.13%, Accuracy = 96.85%
# ================================== Test  Data ==================================
# F1 = 84.26%, Precision = 85.69%, Recall = 84.97%
# POS F1 = 69.33%, Accuracy = 90.19%
# Shape F1 = 35.82%, Accuracy = 95.63%
# Time: 15.75s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.07%, Precision = 90.00%, Recall = 90.03%
# POS F1 = 70.19%, Accuracy = 90.33%
# Shape F1 = 35.97%, Accuracy = 97.19%
# ================================== Valid Data ==================================
# F1 = 89.59%, Precision = 88.94%, Recall = 89.27%
# POS F1 = 69.22%, Accuracy = 89.50%
# Shape F1 = 36.51%, Accuracy = 97.09%
# ================================== Test  Data ==================================
# F1 = 86.06%, Precision = 85.82%, Recall = 85.94%
# POS F1 = 71.15%, Accuracy = 90.12%
# Shape F1 = 38.02%, Accuracy = 96.11%
# Time: 15.72s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.96%, Precision = 90.20%, Recall = 90.08%
# POS F1 = 71.10%, Accuracy = 91.00%
# Shape F1 = 36.82%, Accuracy = 97.31%
# ================================== Valid Data ==================================
# F1 = 89.40%, Precision = 89.18%, Recall = 89.29%
# POS F1 = 70.07%, Accuracy = 90.11%
# Shape F1 = 37.88%, Accuracy = 97.25%
# ================================== Test  Data ==================================
# F1 = 85.44%, Precision = 86.33%, Recall = 85.88%
# POS F1 = 72.09%, Accuracy = 90.76%
# Shape F1 = 38.19%, Accuracy = 96.15%
# Time: 15.65s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.66%, Precision = 90.60%, Recall = 90.63%
# POS F1 = 71.06%, Accuracy = 90.99%
# Shape F1 = 38.05%, Accuracy = 97.41%
# ================================== Valid Data ==================================
# F1 = 90.04%, Precision = 89.50%, Recall = 89.77%
# POS F1 = 70.40%, Accuracy = 90.13%
# Shape F1 = 38.17%, Accuracy = 97.34%
# ================================== Test  Data ==================================
# F1 = 86.31%, Precision = 86.63%, Recall = 86.47%
# POS F1 = 71.97%, Accuracy = 90.78%
# Shape F1 = 39.31%, Accuracy = 96.30%
# Time: 15.62s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.36%, Precision = 91.26%, Recall = 90.81%
# POS F1 = 72.04%, Accuracy = 91.37%
# Shape F1 = 38.76%, Accuracy = 97.55%
# ================================== Valid Data ==================================
# F1 = 89.24%, Precision = 89.87%, Recall = 89.55%
# POS F1 = 71.33%, Accuracy = 90.57%
# Shape F1 = 38.86%, Accuracy = 97.47%
# ================================== Test  Data ==================================
# F1 = 85.09%, Precision = 86.56%, Recall = 85.82%
# POS F1 = 72.76%, Accuracy = 91.00%
# Shape F1 = 40.29%, Accuracy = 96.45%
# Time: 15.69s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.63%, Precision = 91.40%, Recall = 91.51%
# POS F1 = 71.91%, Accuracy = 91.42%
# Shape F1 = 39.66%, Accuracy = 97.58%
# ================================== Valid Data ==================================
# F1 = 90.60%, Precision = 89.87%, Recall = 90.23%
# POS F1 = 71.30%, Accuracy = 90.56%
# Shape F1 = 40.22%, Accuracy = 97.53%
# ================================== Test  Data ==================================
# F1 = 87.19%, Precision = 87.15%, Recall = 87.17%
# POS F1 = 72.76%, Accuracy = 91.05%
# Shape F1 = 39.83%, Accuracy = 96.37%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.55%, Precision = 91.99%, Recall = 91.26%
# POS F1 = 72.38%, Accuracy = 91.51%
# Shape F1 = 40.68%, Accuracy = 97.72%
# ================================== Valid Data ==================================
# F1 = 89.72%, Precision = 90.66%, Recall = 90.19%
# POS F1 = 71.44%, Accuracy = 90.56%
# Shape F1 = 40.88%, Accuracy = 97.61%
# ================================== Test  Data ==================================
# F1 = 85.38%, Precision = 87.78%, Recall = 86.56%
# POS F1 = 72.90%, Accuracy = 91.07%
# Shape F1 = 40.72%, Accuracy = 96.63%
# Time: 15.68s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.31s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.53%, Precision = 91.97%, Recall = 91.75%
# POS F1 = 73.05%, Accuracy = 91.90%
# Shape F1 = 42.08%, Accuracy = 97.80%
# ================================== Valid Data ==================================
# F1 = 90.78%, Precision = 90.51%, Recall = 90.65%
# POS F1 = 71.99%, Accuracy = 90.97%
# Shape F1 = 41.25%, Accuracy = 97.66%
# ================================== Test  Data ==================================
# F1 = 86.75%, Precision = 87.61%, Recall = 87.17%
# POS F1 = 73.48%, Accuracy = 91.42%
# Shape F1 = 41.14%, Accuracy = 96.70%
# Time: 15.57s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.28s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.94%, Precision = 92.20%, Recall = 91.57%
# POS F1 = 73.37%, Accuracy = 92.08%
# Shape F1 = 42.02%, Accuracy = 97.78%
# ================================== Valid Data ==================================
# F1 = 90.13%, Precision = 90.98%, Recall = 90.55%
# POS F1 = 72.32%, Accuracy = 91.08%
# Shape F1 = 40.75%, Accuracy = 97.65%
# ================================== Test  Data ==================================
# F1 = 85.89%, Precision = 87.77%, Recall = 86.82%
# POS F1 = 73.81%, Accuracy = 91.65%
# Shape F1 = 41.27%, Accuracy = 96.71%
# Time: 15.66s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.04%, Precision = 92.20%, Recall = 92.12%
# POS F1 = 74.00%, Accuracy = 92.23%
# Shape F1 = 42.80%, Accuracy = 97.81%
# ================================== Valid Data ==================================
# F1 = 90.77%, Precision = 90.73%, Recall = 90.75%
# POS F1 = 72.87%, Accuracy = 91.17%
# Shape F1 = 41.12%, Accuracy = 97.70%
# ================================== Test  Data ==================================
# F1 = 87.10%, Precision = 87.71%, Recall = 87.40%
# POS F1 = 74.32%, Accuracy = 91.82%
# Shape F1 = 41.21%, Accuracy = 96.76%
# Time: 15.57s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.13%, Precision = 91.97%, Recall = 92.05%
# POS F1 = 73.66%, Accuracy = 92.24%
# Shape F1 = 43.56%, Accuracy = 97.91%
# ================================== Valid Data ==================================
# F1 = 91.12%, Precision = 90.61%, Recall = 90.86%
# POS F1 = 72.84%, Accuracy = 91.19%
# Shape F1 = 42.48%, Accuracy = 97.77%
# ================================== Test  Data ==================================
# F1 = 87.56%, Precision = 87.71%, Recall = 87.63%
# POS F1 = 73.90%, Accuracy = 91.68%
# Shape F1 = 42.51%, Accuracy = 96.89%
# Time: 15.75s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.17%, Precision = 92.05%, Recall = 92.11%
# POS F1 = 74.40%, Accuracy = 92.56%
# Shape F1 = 44.18%, Accuracy = 97.94%
# ================================== Valid Data ==================================
# F1 = 90.97%, Precision = 90.58%, Recall = 90.77%
# POS F1 = 73.20%, Accuracy = 91.48%
# Shape F1 = 42.68%, Accuracy = 97.82%
# ================================== Test  Data ==================================
# F1 = 87.49%, Precision = 87.45%, Recall = 87.47%
# POS F1 = 74.77%, Accuracy = 92.02%
# Shape F1 = 43.42%, Accuracy = 96.94%
# Time: 15.58s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.20%, Precision = 92.83%, Recall = 92.51%
# POS F1 = 74.68%, Accuracy = 92.64%
# Shape F1 = 44.53%, Accuracy = 97.98%
# ================================== Valid Data ==================================
# F1 = 91.20%, Precision = 91.25%, Recall = 91.23%
# POS F1 = 73.44%, Accuracy = 91.62%
# Shape F1 = 42.66%, Accuracy = 97.84%
# ================================== Test  Data ==================================
# F1 = 86.93%, Precision = 88.08%, Recall = 87.50%
# POS F1 = 74.92%, Accuracy = 92.03%
# Shape F1 = 43.14%, Accuracy = 96.92%
# Time: 15.69s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.69%, Precision = 92.17%, Recall = 92.43%
# POS F1 = 74.72%, Accuracy = 92.74%
# Shape F1 = 45.40%, Accuracy = 98.02%
# ================================== Valid Data ==================================
# F1 = 91.54%, Precision = 90.69%, Recall = 91.12%
# POS F1 = 73.68%, Accuracy = 91.71%
# Shape F1 = 43.63%, Accuracy = 97.88%
# ================================== Test  Data ==================================
# F1 = 87.70%, Precision = 87.23%, Recall = 87.47%
# POS F1 = 74.89%, Accuracy = 92.19%
# Shape F1 = 43.65%, Accuracy = 96.94%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.40s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.53%, Precision = 93.20%, Recall = 92.86%
# POS F1 = 74.78%, Accuracy = 92.74%
# Shape F1 = 45.76%, Accuracy = 98.04%
# ================================== Valid Data ==================================
# F1 = 91.48%, Precision = 91.64%, Recall = 91.56%
# POS F1 = 73.77%, Accuracy = 91.75%
# Shape F1 = 43.99%, Accuracy = 97.91%
# ================================== Test  Data ==================================
# F1 = 87.16%, Precision = 88.19%, Recall = 87.67%
# POS F1 = 75.05%, Accuracy = 92.21%
# Shape F1 = 43.61%, Accuracy = 97.02%
# Time: 15.71s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.40s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.50%, Precision = 93.02%, Recall = 92.76%
# POS F1 = 75.42%, Accuracy = 92.97%
# Shape F1 = 46.00%, Accuracy = 98.12%
# ================================== Valid Data ==================================
# F1 = 91.40%, Precision = 91.42%, Recall = 91.41%
# POS F1 = 74.30%, Accuracy = 92.01%
# Shape F1 = 44.09%, Accuracy = 97.95%
# ================================== Test  Data ==================================
# F1 = 86.89%, Precision = 87.91%, Recall = 87.40%
# POS F1 = 75.53%, Accuracy = 92.37%
# Shape F1 = 43.96%, Accuracy = 97.06%
# Time: 15.67s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.25%, Precision = 93.53%, Recall = 93.39%
# POS F1 = 75.57%, Accuracy = 93.07%
# Shape F1 = 47.50%, Accuracy = 98.14%
# ================================== Valid Data ==================================
# F1 = 91.80%, Precision = 91.55%, Recall = 91.68%
# POS F1 = 74.24%, Accuracy = 92.03%
# Shape F1 = 45.26%, Accuracy = 97.94%
# ================================== Test  Data ==================================
# F1 = 87.69%, Precision = 88.69%, Recall = 88.19%
# POS F1 = 75.67%, Accuracy = 92.41%
# Shape F1 = 46.38%, Accuracy = 97.17%
# Time: 15.93s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.21%, Precision = 93.51%, Recall = 93.36%
# POS F1 = 75.91%, Accuracy = 93.18%
# Shape F1 = 47.32%, Accuracy = 98.15%
# ================================== Valid Data ==================================
# F1 = 91.72%, Precision = 91.67%, Recall = 91.69%
# POS F1 = 74.66%, Accuracy = 92.17%
# Shape F1 = 45.54%, Accuracy = 97.98%
# ================================== Test  Data ==================================
# F1 = 88.11%, Precision = 88.85%, Recall = 88.48%
# POS F1 = 76.01%, Accuracy = 92.53%
# Shape F1 = 45.85%, Accuracy = 97.19%
# Time: 15.64s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.37%, Precision = 93.37%, Recall = 93.37%
# POS F1 = 76.07%, Accuracy = 93.31%
# Shape F1 = 48.50%, Accuracy = 98.20%
# ================================== Valid Data ==================================
# F1 = 91.55%, Precision = 91.30%, Recall = 91.42%
# POS F1 = 74.64%, Accuracy = 92.28%
# Shape F1 = 46.14%, Accuracy = 98.03%
# ================================== Test  Data ==================================
# F1 = 87.59%, Precision = 87.89%, Recall = 87.74%
# POS F1 = 76.15%, Accuracy = 92.68%
# Shape F1 = 46.54%, Accuracy = 97.26%
# Time: 15.58s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.17s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.03%, Precision = 93.63%, Recall = 93.33%
# POS F1 = 76.21%, Accuracy = 93.38%
# Shape F1 = 49.50%, Accuracy = 98.22%
# ================================== Valid Data ==================================
# F1 = 91.50%, Precision = 91.69%, Recall = 91.59%
# POS F1 = 74.85%, Accuracy = 92.32%
# Shape F1 = 46.25%, Accuracy = 98.02%
# ================================== Test  Data ==================================
# F1 = 87.08%, Precision = 88.28%, Recall = 87.67%
# POS F1 = 76.44%, Accuracy = 92.69%
# Shape F1 = 47.23%, Accuracy = 97.26%
# Time: 15.54s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.83%, Precision = 93.66%, Recall = 93.74%
# POS F1 = 76.86%, Accuracy = 93.52%
# Shape F1 = 48.89%, Accuracy = 98.23%
# ================================== Valid Data ==================================
# F1 = 92.19%, Precision = 91.72%, Recall = 91.95%
# POS F1 = 75.08%, Accuracy = 92.30%
# Shape F1 = 46.18%, Accuracy = 98.04%
# ================================== Test  Data ==================================
# F1 = 88.23%, Precision = 88.42%, Recall = 88.33%
# POS F1 = 76.89%, Accuracy = 92.74%
# Shape F1 = 47.03%, Accuracy = 97.30%
# Time: 15.62s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.82%, Precision = 93.34%, Recall = 93.58%
# POS F1 = 77.02%, Accuracy = 93.61%
# Shape F1 = 50.25%, Accuracy = 98.26%
# ================================== Valid Data ==================================
# F1 = 92.26%, Precision = 91.45%, Recall = 91.85%
# POS F1 = 75.12%, Accuracy = 92.51%
# Shape F1 = 46.78%, Accuracy = 98.05%
# ================================== Test  Data ==================================
# F1 = 88.39%, Precision = 88.00%, Recall = 88.19%
# POS F1 = 76.94%, Accuracy = 92.80%
# Shape F1 = 47.55%, Accuracy = 97.27%
# Time: 15.58s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.29s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.83%, Precision = 93.58%, Recall = 93.71%
# POS F1 = 76.98%, Accuracy = 93.65%
# Shape F1 = 49.78%, Accuracy = 98.28%
# ================================== Valid Data ==================================
# F1 = 91.99%, Precision = 91.57%, Recall = 91.78%
# POS F1 = 75.53%, Accuracy = 92.53%
# Shape F1 = 47.23%, Accuracy = 98.08%
# ================================== Test  Data ==================================
# F1 = 88.09%, Precision = 88.14%, Recall = 88.11%
# POS F1 = 76.96%, Accuracy = 92.90%
# Shape F1 = 47.60%, Accuracy = 97.30%
# Time: 15.53s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.01%, Precision = 93.98%, Recall = 93.99%
# POS F1 = 77.03%, Accuracy = 93.72%
# Shape F1 = 52.44%, Accuracy = 98.31%
# ================================== Valid Data ==================================
# F1 = 91.91%, Precision = 91.79%, Recall = 91.85%
# POS F1 = 75.17%, Accuracy = 92.58%
# Shape F1 = 47.50%, Accuracy = 98.09%
# ================================== Test  Data ==================================
# F1 = 88.14%, Precision = 88.69%, Recall = 88.41%
# POS F1 = 77.10%, Accuracy = 92.94%
# Shape F1 = 47.66%, Accuracy = 97.22%
# Time: 15.59s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.96%, Precision = 94.08%, Recall = 94.02%
# POS F1 = 77.32%, Accuracy = 93.81%
# Shape F1 = 53.43%, Accuracy = 98.35%
# ================================== Valid Data ==================================
# F1 = 92.25%, Precision = 92.11%, Recall = 92.18%
# POS F1 = 75.57%, Accuracy = 92.66%
# Shape F1 = 48.04%, Accuracy = 98.09%
# ================================== Test  Data ==================================
# F1 = 88.14%, Precision = 88.65%, Recall = 88.39%
# POS F1 = 77.29%, Accuracy = 93.01%
# Shape F1 = 50.07%, Accuracy = 97.38%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.24s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.90%, Precision = 93.80%, Recall = 93.85%
# POS F1 = 77.31%, Accuracy = 93.90%
# Shape F1 = 54.62%, Accuracy = 98.40%
# ================================== Valid Data ==================================
# F1 = 92.31%, Precision = 91.77%, Recall = 92.04%
# POS F1 = 75.50%, Accuracy = 92.76%
# Shape F1 = 48.42%, Accuracy = 98.13%
# ================================== Test  Data ==================================
# F1 = 88.13%, Precision = 88.46%, Recall = 88.29%
# POS F1 = 77.17%, Accuracy = 93.02%
# Shape F1 = 49.62%, Accuracy = 97.20%
# Time: 15.53s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.48s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.45%, Precision = 94.45%, Recall = 93.95%
# POS F1 = 77.33%, Accuracy = 93.93%
# Shape F1 = 54.34%, Accuracy = 98.39%
# ================================== Valid Data ==================================
# F1 = 91.62%, Precision = 92.36%, Recall = 91.99%
# POS F1 = 75.58%, Accuracy = 92.79%
# Shape F1 = 48.22%, Accuracy = 98.15%
# ================================== Test  Data ==================================
# F1 = 86.91%, Precision = 88.97%, Recall = 87.93%
# POS F1 = 77.24%, Accuracy = 93.12%
# Shape F1 = 48.83%, Accuracy = 97.37%
# Time: 15.60s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.20%, Precision = 93.91%, Recall = 94.05%
# POS F1 = 77.43%, Accuracy = 94.04%
# Shape F1 = 54.73%, Accuracy = 98.40%
# ================================== Valid Data ==================================
# F1 = 92.60%, Precision = 91.84%, Recall = 92.22%
# POS F1 = 75.68%, Accuracy = 92.91%
# Shape F1 = 49.20%, Accuracy = 98.16%
# ================================== Test  Data ==================================
# F1 = 88.40%, Precision = 88.12%, Recall = 88.26%
# POS F1 = 77.38%, Accuracy = 93.17%
# Shape F1 = 49.93%, Accuracy = 97.24%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.74%, Precision = 94.08%, Recall = 94.41%
# POS F1 = 77.87%, Accuracy = 94.10%
# Shape F1 = 55.88%, Accuracy = 98.44%
# ================================== Valid Data ==================================
# F1 = 93.03%, Precision = 91.92%, Recall = 92.47%
# POS F1 = 76.20%, Accuracy = 92.87%
# Shape F1 = 49.98%, Accuracy = 98.19%
# ================================== Test  Data ==================================
# F1 = 89.32%, Precision = 88.53%, Recall = 88.92%
# POS F1 = 77.55%, Accuracy = 93.20%
# Shape F1 = 49.60%, Accuracy = 97.26%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.24s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.66%, Precision = 94.29%, Recall = 94.48%
# POS F1 = 78.04%, Accuracy = 94.14%
# Shape F1 = 56.58%, Accuracy = 98.47%
# ================================== Valid Data ==================================
# F1 = 92.73%, Precision = 92.14%, Recall = 92.44%
# POS F1 = 76.33%, Accuracy = 92.94%
# Shape F1 = 50.39%, Accuracy = 98.20%
# ================================== Test  Data ==================================
# F1 = 89.00%, Precision = 88.49%, Recall = 88.74%
# POS F1 = 77.56%, Accuracy = 93.17%
# Shape F1 = 49.58%, Accuracy = 97.33%
# Time: 15.54s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.99%, Precision = 94.46%, Recall = 94.72%
# POS F1 = 78.02%, Accuracy = 94.11%
# Shape F1 = 56.82%, Accuracy = 98.50%
# ================================== Valid Data ==================================
# F1 = 93.33%, Precision = 92.28%, Recall = 92.80%
# POS F1 = 76.36%, Accuracy = 92.93%
# Shape F1 = 49.80%, Accuracy = 98.21%
# ================================== Test  Data ==================================
# F1 = 89.27%, Precision = 88.56%, Recall = 88.92%
# POS F1 = 77.55%, Accuracy = 93.21%
# Shape F1 = 50.50%, Accuracy = 97.37%
# Time: 15.62s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.18s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.62%, Precision = 94.65%, Recall = 94.63%
# POS F1 = 78.05%, Accuracy = 94.25%
# Shape F1 = 55.86%, Accuracy = 98.48%
# ================================== Valid Data ==================================
# F1 = 92.49%, Precision = 92.19%, Recall = 92.34%
# POS F1 = 76.37%, Accuracy = 93.03%
# Shape F1 = 49.97%, Accuracy = 98.21%
# ================================== Test  Data ==================================
# F1 = 88.42%, Precision = 88.86%, Recall = 88.64%
# POS F1 = 77.61%, Accuracy = 93.26%
# Shape F1 = 50.74%, Accuracy = 97.33%
# Time: 15.74s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.53%, Precision = 94.87%, Recall = 94.70%
# POS F1 = 78.79%, Accuracy = 94.29%
# Shape F1 = 58.35%, Accuracy = 98.51%
# ================================== Valid Data ==================================
# F1 = 92.36%, Precision = 92.36%, Recall = 92.36%
# POS F1 = 76.61%, Accuracy = 93.11%
# Shape F1 = 50.22%, Accuracy = 98.21%
# ================================== Test  Data ==================================
# F1 = 88.10%, Precision = 89.11%, Recall = 88.60%
# POS F1 = 78.25%, Accuracy = 93.27%
# Shape F1 = 51.22%, Accuracy = 97.47%
# Time: 15.65s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.73%, Precision = 94.92%, Recall = 94.83%
# POS F1 = 78.58%, Accuracy = 94.34%
# Shape F1 = 57.56%, Accuracy = 98.52%
# ================================== Valid Data ==================================
# F1 = 92.72%, Precision = 92.58%, Recall = 92.65%
# POS F1 = 76.60%, Accuracy = 93.13%
# Shape F1 = 51.02%, Accuracy = 98.23%
# ================================== Test  Data ==================================
# F1 = 88.54%, Precision = 89.47%, Recall = 89.00%
# POS F1 = 77.70%, Accuracy = 93.29%
# Shape F1 = 52.26%, Accuracy = 97.51%
# Time: 15.55s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.25%, Precision = 94.47%, Recall = 94.86%
# POS F1 = 78.86%, Accuracy = 94.39%
# Shape F1 = 58.80%, Accuracy = 98.55%
# ================================== Valid Data ==================================
# F1 = 93.35%, Precision = 92.17%, Recall = 92.76%
# POS F1 = 76.53%, Accuracy = 93.17%
# Shape F1 = 51.39%, Accuracy = 98.22%
# ================================== Test  Data ==================================
# F1 = 89.28%, Precision = 88.37%, Recall = 88.82%
# POS F1 = 77.82%, Accuracy = 93.37%
# Shape F1 = 51.73%, Accuracy = 97.52%
# Time: 15.60s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.79%, Precision = 95.06%, Recall = 94.93%
# POS F1 = 80.21%, Accuracy = 94.50%
# Shape F1 = 58.92%, Accuracy = 98.55%
# ================================== Valid Data ==================================
# F1 = 92.66%, Precision = 92.63%, Recall = 92.64%
# POS F1 = 76.72%, Accuracy = 93.21%
# Shape F1 = 50.58%, Accuracy = 98.20%
# ================================== Test  Data ==================================
# F1 = 88.15%, Precision = 89.06%, Recall = 88.60%
# POS F1 = 78.75%, Accuracy = 93.45%
# Shape F1 = 52.22%, Accuracy = 97.52%
# Time: 15.59s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.14%, Precision = 94.83%, Recall = 94.99%
# POS F1 = 79.43%, Accuracy = 94.55%
# Shape F1 = 59.48%, Accuracy = 98.58%
# ================================== Valid Data ==================================
# F1 = 92.91%, Precision = 92.16%, Recall = 92.53%
# POS F1 = 77.20%, Accuracy = 93.29%
# Shape F1 = 51.13%, Accuracy = 98.26%
# ================================== Test  Data ==================================
# F1 = 88.99%, Precision = 88.86%, Recall = 88.93%
# POS F1 = 79.21%, Accuracy = 93.49%
# Shape F1 = 52.39%, Accuracy = 97.53%
# Time: 15.63s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.43%, Precision = 94.95%, Recall = 95.19%
# POS F1 = 79.62%, Accuracy = 94.56%
# Shape F1 = 60.77%, Accuracy = 98.59%
# ================================== Valid Data ==================================
# F1 = 93.06%, Precision = 92.33%, Recall = 92.69%
# POS F1 = 77.22%, Accuracy = 93.28%
# Shape F1 = 51.46%, Accuracy = 98.27%
# ================================== Test  Data ==================================
# F1 = 89.41%, Precision = 88.92%, Recall = 89.16%
# POS F1 = 79.26%, Accuracy = 93.48%
# Shape F1 = 52.45%, Accuracy = 97.55%
# Time: 15.61s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.14%, Precision = 95.29%, Recall = 95.22%
# POS F1 = 81.02%, Accuracy = 94.59%
# Shape F1 = 61.10%, Accuracy = 98.60%
# ================================== Valid Data ==================================
# F1 = 92.75%, Precision = 92.60%, Recall = 92.67%
# POS F1 = 77.42%, Accuracy = 93.25%
# Shape F1 = 52.62%, Accuracy = 98.29%
# ================================== Test  Data ==================================
# F1 = 88.50%, Precision = 89.39%, Recall = 88.95%
# POS F1 = 79.64%, Accuracy = 93.49%
# Shape F1 = 52.79%, Accuracy = 97.60%
# Time: 15.52s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.31s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.10%, Precision = 95.11%, Recall = 95.10%
# POS F1 = 80.01%, Accuracy = 94.65%
# Shape F1 = 61.66%, Accuracy = 98.62%
# ================================== Valid Data ==================================
# F1 = 92.48%, Precision = 92.28%, Recall = 92.38%
# POS F1 = 77.60%, Accuracy = 93.29%
# Shape F1 = 51.79%, Accuracy = 98.27%
# ================================== Test  Data ==================================
# F1 = 88.32%, Precision = 88.90%, Recall = 88.61%
# POS F1 = 79.50%, Accuracy = 93.53%
# Shape F1 = 52.64%, Accuracy = 97.50%
# Time: 15.70s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.22%, Precision = 94.87%, Recall = 95.04%
# POS F1 = 81.55%, Accuracy = 94.75%
# Shape F1 = 62.25%, Accuracy = 98.62%
# ================================== Valid Data ==================================
# F1 = 92.75%, Precision = 92.09%, Recall = 92.42%
# POS F1 = 77.89%, Accuracy = 93.37%
# Shape F1 = 51.63%, Accuracy = 98.26%
# ================================== Test  Data ==================================
# F1 = 88.61%, Precision = 88.74%, Recall = 88.68%
# POS F1 = 80.19%, Accuracy = 93.55%
# Shape F1 = 53.22%, Accuracy = 97.52%
# Time: 15.57s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.04%, Precision = 95.35%, Recall = 95.20%
# POS F1 = 81.20%, Accuracy = 94.73%
# Shape F1 = 62.35%, Accuracy = 98.64%
# ================================== Valid Data ==================================
# F1 = 92.47%, Precision = 92.56%, Recall = 92.51%
# POS F1 = 77.93%, Accuracy = 93.40%
# Shape F1 = 52.14%, Accuracy = 98.28%
# ================================== Test  Data ==================================
# F1 = 88.56%, Precision = 89.62%, Recall = 89.09%
# POS F1 = 80.28%, Accuracy = 93.65%
# Shape F1 = 54.07%, Accuracy = 97.56%
# Time: 15.56s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.30%, Precision = 94.93%, Recall = 95.12%
# POS F1 = 81.77%, Accuracy = 94.73%
# Shape F1 = 63.23%, Accuracy = 98.64%
# ================================== Valid Data ==================================
# F1 = 92.97%, Precision = 92.17%, Recall = 92.57%
# POS F1 = 78.57%, Accuracy = 93.42%
# Shape F1 = 54.25%, Accuracy = 98.29%
# ================================== Test  Data ==================================
# F1 = 88.88%, Precision = 88.47%, Recall = 88.68%
# POS F1 = 80.77%, Accuracy = 93.56%
# ...
# F1 = 99.78%, Precision = 99.82%, Recall = 99.80%
# POS F1 = 97.70%, Accuracy = 99.17%
# Shape F1 = 96.80%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.41%, Precision = 94.28%, Recall = 94.34%
# POS F1 = 86.83%, Accuracy = 95.50%
# Shape F1 = 72.37%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.03%, Precision = 90.53%, Recall = 90.28%
# POS F1 = 89.84%, Accuracy = 95.14%
# Shape F1 = 66.51%, Accuracy = 98.27%
# Time: 16.39s
#
# ----------------------------------- EPOCH: 878 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.92s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.77%, Precision = 99.81%, Recall = 99.79%
# POS F1 = 97.68%, Accuracy = 99.16%
# Shape F1 = 96.77%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.51%, Precision = 94.38%, Recall = 94.44%
# POS F1 = 86.88%, Accuracy = 95.51%
# Shape F1 = 72.38%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.18%, Precision = 90.70%, Recall = 90.44%
# POS F1 = 89.85%, Accuracy = 95.16%
# Shape F1 = 66.48%, Accuracy = 98.27%
# Time: 16.26s
#
# ----------------------------------- EPOCH: 879 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.78%, Precision = 99.81%, Recall = 99.79%
# POS F1 = 97.71%, Accuracy = 99.17%
# Shape F1 = 96.71%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.55%, Precision = 94.38%, Recall = 94.47%
# POS F1 = 86.91%, Accuracy = 95.54%
# Shape F1 = 71.83%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.20%, Precision = 90.72%, Recall = 90.46%
# POS F1 = 89.80%, Accuracy = 95.16%
# Shape F1 = 66.83%, Accuracy = 98.28%
# Time: 16.45s
#
# ----------------------------------- EPOCH: 880 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.24s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.81%, Precision = 99.77%, Recall = 99.79%
# POS F1 = 97.43%, Accuracy = 99.16%
# Shape F1 = 96.77%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.71%, Precision = 94.28%, Recall = 94.49%
# POS F1 = 86.97%, Accuracy = 95.52%
# Shape F1 = 71.70%, Accuracy = 98.97%
# ================================== Test  Data ==================================
# F1 = 90.37%, Precision = 90.56%, Recall = 90.47%
# POS F1 = 89.79%, Accuracy = 95.16%
# Shape F1 = 66.80%, Accuracy = 98.26%
# Time: 16.44s
#
# ----------------------------------- EPOCH: 881 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.90s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.79%, Precision = 99.81%, Recall = 99.80%
# POS F1 = 97.71%, Accuracy = 99.17%
# Shape F1 = 96.75%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.65%, Precision = 94.40%, Recall = 94.52%
# POS F1 = 86.95%, Accuracy = 95.56%
# Shape F1 = 72.17%, Accuracy = 98.97%
# ================================== Test  Data ==================================
# F1 = 90.26%, Precision = 90.62%, Recall = 90.44%
# POS F1 = 89.78%, Accuracy = 95.19%
# Shape F1 = 66.51%, Accuracy = 98.26%
# Time: 16.47s
#
# ----------------------------------- EPOCH: 882 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.80%, Recall = 99.80%
# POS F1 = 97.70%, Accuracy = 99.17%
# Shape F1 = 96.75%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 94.26%, Recall = 94.44%
# POS F1 = 86.88%, Accuracy = 95.51%
# Shape F1 = 71.84%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.31%, Precision = 90.58%, Recall = 90.44%
# POS F1 = 89.79%, Accuracy = 95.16%
# Shape F1 = 66.61%, Accuracy = 98.27%
# Time: 16.37s
#
# ----------------------------------- EPOCH: 883 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.83%, Recall = 99.81%
# POS F1 = 97.65%, Accuracy = 99.16%
# Shape F1 = 96.76%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.59%, Precision = 94.24%, Recall = 94.42%
# POS F1 = 86.88%, Accuracy = 95.55%
# Shape F1 = 72.55%, Accuracy = 98.97%
# ================================== Test  Data ==================================
# F1 = 90.50%, Precision = 90.58%, Recall = 90.54%
# POS F1 = 89.87%, Accuracy = 95.21%
# Shape F1 = 66.55%, Accuracy = 98.28%
# Time: 16.54s
#
# ----------------------------------- EPOCH: 884 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.01s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.82%, Recall = 99.81%
# POS F1 = 97.47%, Accuracy = 99.15%
# Shape F1 = 96.81%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 94.23%, Recall = 94.43%
# POS F1 = 86.84%, Accuracy = 95.51%
# Shape F1 = 72.50%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.28%, Precision = 90.56%, Recall = 90.42%
# POS F1 = 89.83%, Accuracy = 95.16%
# Shape F1 = 66.73%, Accuracy = 98.28%
# Time: 16.40s
#
# ----------------------------------- EPOCH: 885 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.78%, Precision = 99.82%, Recall = 99.80%
# POS F1 = 97.47%, Accuracy = 99.16%
# Shape F1 = 96.86%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.41%, Precision = 94.28%, Recall = 94.34%
# POS F1 = 86.80%, Accuracy = 95.47%
# Shape F1 = 71.92%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.04%, Precision = 90.58%, Recall = 90.31%
# POS F1 = 89.79%, Accuracy = 95.10%
# Shape F1 = 66.93%, Accuracy = 98.26%
# Time: 16.33s
#
# ----------------------------------- EPOCH: 886 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.92s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.79%, Precision = 99.82%, Recall = 99.81%
# POS F1 = 97.45%, Accuracy = 99.15%
# Shape F1 = 96.74%, Accuracy = 99.85%
# ================================== Valid Data ==================================
# F1 = 94.52%, Precision = 94.29%, Recall = 94.41%
# POS F1 = 86.90%, Accuracy = 95.53%
# Shape F1 = 72.06%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.16%, Precision = 90.51%, Recall = 90.33%
# POS F1 = 89.78%, Accuracy = 95.14%
# Shape F1 = 66.63%, Accuracy = 98.27%
# Time: 16.35s
#
# ----------------------------------- EPOCH: 887 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.25s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.79%, Precision = 99.82%, Recall = 99.80%
# POS F1 = 97.72%, Accuracy = 99.17%
# Shape F1 = 96.80%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.65%, Precision = 94.31%, Recall = 94.48%
# POS F1 = 86.82%, Accuracy = 95.53%
# Shape F1 = 71.92%, Accuracy = 98.97%
# ================================== Test  Data ==================================
# F1 = 90.39%, Precision = 90.55%, Recall = 90.47%
# POS F1 = 89.82%, Accuracy = 95.15%
# Shape F1 = 66.89%, Accuracy = 98.29%
# Time: 16.44s
#
# ----------------------------------- EPOCH: 888 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.81%, Precision = 99.80%, Recall = 99.81%
# POS F1 = 97.68%, Accuracy = 99.18%
# Shape F1 = 96.78%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.61%, Precision = 94.16%, Recall = 94.38%
# POS F1 = 86.90%, Accuracy = 95.55%
# Shape F1 = 72.09%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.38%, Precision = 90.44%, Recall = 90.41%
# POS F1 = 89.84%, Accuracy = 95.15%
# Shape F1 = 66.82%, Accuracy = 98.31%
# Time: 16.37s
#
# ----------------------------------- EPOCH: 889 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.78%, Precision = 99.80%, Recall = 99.79%
# POS F1 = 97.69%, Accuracy = 99.18%
# Shape F1 = 96.82%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.54%, Precision = 94.13%, Recall = 94.33%
# POS F1 = 86.91%, Accuracy = 95.52%
# Shape F1 = 71.85%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.73%, Precision = 90.62%, Recall = 90.67%
# POS F1 = 89.86%, Accuracy = 95.15%
# Shape F1 = 66.94%, Accuracy = 98.30%
# Time: 16.41s
#
# ----------------------------------- EPOCH: 890 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.93s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.78%, Precision = 99.81%, Recall = 99.80%
# POS F1 = 97.46%, Accuracy = 99.17%
# Shape F1 = 96.74%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.56%, Precision = 94.41%, Recall = 94.48%
# POS F1 = 86.82%, Accuracy = 95.52%
# Shape F1 = 72.05%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.20%, Precision = 90.58%, Recall = 90.39%
# POS F1 = 89.81%, Accuracy = 95.12%
# Shape F1 = 66.75%, Accuracy = 98.29%
# Time: 16.37s
#
# ----------------------------------- EPOCH: 891 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.11s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.82%, Recall = 99.81%
# POS F1 = 97.66%, Accuracy = 99.17%
# Shape F1 = 96.86%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.65%, Precision = 94.36%, Recall = 94.51%
# POS F1 = 87.36%, Accuracy = 95.56%
# Shape F1 = 71.24%, Accuracy = 98.97%
# ================================== Test  Data ==================================
# F1 = 90.32%, Precision = 90.56%, Recall = 90.44%
# POS F1 = 89.88%, Accuracy = 95.14%
# Shape F1 = 66.88%, Accuracy = 98.29%
# Time: 16.34s
#
# ----------------------------------- EPOCH: 892 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 25.92s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.79%, Precision = 99.81%, Recall = 99.80%
# POS F1 = 97.68%, Accuracy = 99.17%
# Shape F1 = 96.87%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.59%, Precision = 94.23%, Recall = 94.41%
# POS F1 = 87.33%, Accuracy = 95.53%
# Shape F1 = 71.77%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.37%, Precision = 90.56%, Recall = 90.47%
# POS F1 = 89.85%, Accuracy = 95.14%
# Shape F1 = 66.70%, Accuracy = 98.29%
# Time: 16.44s
#
# ----------------------------------- EPOCH: 893 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.78%, Precision = 99.80%, Recall = 99.79%
# POS F1 = 97.41%, Accuracy = 99.17%
# Shape F1 = 96.75%, Accuracy = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.62%, Precision = 94.21%, Recall = 94.42%
# POS F1 = 87.31%, Accuracy = 95.50%
# Shape F1 = 72.05%, Accuracy = 98.98%
# ================================== Test  Data ==================================
# F1 = 90.47%, Precision = 90.55%, Recall = 90.51%
# POS F1 = 89.81%, Accuracy = 95.12%
# Shape F1 = 66.82%, Accuracy = 98.27%
# Time: 16.58s
#
# ----------------------------------- EPOCH: 894 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.17s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.81%, Recall = 99.81%
# POS F1 = 97.52%, Accuracy = 99.19%
# Shape F1 = 96.86%, Accuracy = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.69%, Precision = 94.29%, Recall = 94.49%
# POS F1 = 87.02%, Accuracy = 95.51%
# Shape F1 = 71.50%, Accuracy = 98.99%
# ================================== Test  Data ==================================
# F1 = 90.35%, Precision = 90.65%, Recall = 90.50%
# POS F1 = 89.79%, Accuracy = 95.13%
# Shape F1 = 66.47%, Accuracy = 98.29%
# Time: 16.77s
#
# ----------------------------------- EPOCH: 895 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 26.02s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.80%, Precision = 99.81%, Recall = 99.80%
# POS F1 = 97.72%, Accuracy = 99.19%
# Shape F1 = 96.84%, Accuracy = 99.86%

# %%
# 91.05
