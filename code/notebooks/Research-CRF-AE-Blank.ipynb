# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/bachelor-thesis/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-tayz11pf
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-tayz11pf
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.3.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hfr3kx6g/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
# !chmod 777 install
# !./install
# Out:
# --2019-06-26 13:45:40--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3281527 (3.1M) [text/plain]
# Saving to: ‘eng.train’
#
# eng.train           100%[===================>]   3.13M  --.-KB/s    in 0.04s
#
# 2019-06-26 13:45:41 (72.3 MB/s) - ‘eng.train’ saved [3281527/3281527]
#
# --2019-06-26 13:45:41--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827009 (808K) [text/plain]
# Saving to: ‘eng.testa’
#
# eng.testa           100%[===================>] 807.63K  --.-KB/s    in 0.03s
#
# 2019-06-26 13:45:41 (23.7 MB/s) - ‘eng.testa’ saved [827009/827009]
#
# --2019-06-26 13:45:41--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 748094 (731K) [text/plain]
# Saving to: ‘eng.testb’
#
# eng.testb           100%[===================>] 730.56K  --.-KB/s    in 0.03s
#
# 2019-06-26 13:45:42 (26.2 MB/s) - ‘eng.testb’ saved [748094/748094]
#
# --2019-06-26 13:45:42--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-06-26 13:45:42--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2019-06-26 13:45:43--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  19.9MB/s    in 43s
#
# 2019-06-26 13:46:26 (19.1 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
# Cloning into 'gdown.pl'...
# remote: Enumerating objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:46:50--  https://docs.google.com/uc?id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w&export=download
# Resolving docs.google.com (docs.google.com)... 108.177.15.101, 108.177.15.102, 108.177.15.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.15.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘all_onehot.train’
#
#      0K                                     33.8M=0s
#
# 2019-06-26 13:46:50 (33.8 MB/s) - ‘all_onehot.train’ saved [3252]
#
# --2019-06-26 13:46:50--  https://docs.google.com/uc?export=download&confirm=Eq_5&id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w
# Resolving docs.google.com (docs.google.com)... 66.102.1.101, 66.102.1.138, 66.102.1.100, ...
# Connecting to docs.google.com (docs.google.com)|66.102.1.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/78pa2iiktoa5mbdk64utj6lu3hmsklgb/1561550400000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:46:50--  https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/78pa2iiktoa5mbdk64utj6lu3hmsklgb/1561550400000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download
# Resolving doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.train’
#
#      0K ........ ........ ........ ........  137M
#  32768K ........ ........ ........ ........  190M
#  65536K ........ ........ ........ ........  147M
#  98304K ........ ........ ........ ........  173M
# 131072K ........ ........ ........ ........  233M
# 163840K ........ ........ ........ ........  225M
# 196608K ........ ........ ........ ........  183M
# 229376K ........ ........ ........ ........  202M
# 262144K ........ ........ ........ ........  199M
# 294912K ........ ........ ........ ........  214M
# 327680K ........ ........ ........ ........  213M
# 360448K ........ ........ ......             198M=2.0s
#
# 2019-06-26 13:46:53 (188 MB/s) - ‘all_onehot.train’ saved [392581451]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:46:53--  https://docs.google.com/uc?id=1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.133.138, 74.125.133.113, 74.125.133.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.133.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/um569b4mono8tp2ar7fae53lqleuibkt/1561550400000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:46:57--  https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/um569b4mono8tp2ar7fae53lqleuibkt/1561550400000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download
# Resolving doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testa’
#
#      0K ........ ........ ........ ........  117M
#  32768K ........ ........ ........ ........  140M
#  65536K ........ ........ ........ ......    115M=0.8s
#
# 2019-06-26 13:46:58 (123 MB/s) - ‘all_onehot.testa’ saved [99026097]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:46:58--  https://docs.google.com/uc?id=1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib&export=download
# Resolving docs.google.com (docs.google.com)... 66.102.1.101, 66.102.1.102, 66.102.1.139, ...
# Connecting to docs.google.com (docs.google.com)|66.102.1.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dfn9e7cugclsoca1fi72ai425hnvke08/1561550400000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:46:59--  https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dfn9e7cugclsoca1fi72ai425hnvke08/1561550400000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download
# Resolving doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testb’
#
#      0K ........ ........ ........ ........  176M
#  32768K ........ ........ ........ ........  222M
#  65536K ........ ........ .....              229M=0.4s
#
# 2019-06-26 13:47:00 (203 MB/s) - ‘all_onehot.testb’ saved [89526841]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:47:00--  https://docs.google.com/uc?id=1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9&export=download
# Resolving docs.google.com (docs.google.com)... 66.102.1.101, 66.102.1.138, 66.102.1.100, ...
# Connecting to docs.google.com (docs.google.com)|66.102.1.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3vrodjiqjo87ccelue5k2p2e8speruv6/1561550400000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:47:01--  https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3vrodjiqjo87ccelue5k2p2e8speruv6/1561550400000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download
# Resolving doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.train’
#
#      0K ....                                 129M=0.04s
#
# 2019-06-26 13:47:01 (129 MB/s) - ‘gazetteer_PERLOC.train’ saved [4887067]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:47:01--  https://docs.google.com/uc?id=1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn&export=download
# Resolving docs.google.com (docs.google.com)... 66.102.1.101, 66.102.1.102, 66.102.1.139, ...
# Connecting to docs.google.com (docs.google.com)|66.102.1.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q9v93j21o7fi36v6rgo3k281geivn0ob/1561550400000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:47:02--  https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q9v93j21o7fi36v6rgo3k281geivn0ob/1561550400000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download
# Resolving doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1232849 (1.2M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testa’
#
#      0K .                                  100% 65.0M=0.02s
#
# 2019-06-26 13:47:02 (65.0 MB/s) - ‘gazetteer_PERLOC.testa’ saved [1232849/1232849]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-06-26 13:47:02--  https://docs.google.com/uc?id=1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh&export=download
# Resolving docs.google.com (docs.google.com)... 108.177.15.101, 108.177.15.102, 108.177.15.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.15.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bklsv1ajcp70f0ldkv512jmf92bgf28k/1561550400000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-06-26 13:47:03--  https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bklsv1ajcp70f0ldkv512jmf92bgf28k/1561550400000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download
# Resolving doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1114601 (1.1M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testb’
#
#      0K .                                  100% 98.1M=0.01s
#
# 2019-06-26 13:47:03 (98.1 MB/s) - ‘gazetteer_PERLOC.testb’ saved [1114601/1114601]

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Adam
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 48
LSTM_DIM = 200
CHAR_EMB_DIM = 27
KERNEL_SIZE = 3
CHAR_FILTERS = 27
DROPOUT = 0.47
RECURRENT_DROPOUT = 0.47

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(3 / LSTM_DIM), maxval=math.sqrt(3 / LSTM_DIM))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    feature_input = Input(shape=(None, 198))
    gaze_input = Input(shape=(None, 4))

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings, feature_input, gaze_input])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT, implementation=2
    ))(embeddings)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(4, activation='softmax'))(output)
    shape = TimeDistributed(Dense(152, activation='softmax'))(output)
    position = TimeDistributed(Dense(46, activation='softmax'))(output)
    
    return Model(inputs=[word_input, case_input, char_input, feature_input, gaze_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy],
              optimizer=SGD(lr=0.04, decay=5e-5, momentum=0.9, clipnorm=10, nesterov=True))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0626 13:47:48.462174 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0626 13:47:48.500872 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0626 13:47:48.511817 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0626 13:47:48.526026 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0626 13:47:48.527259 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0626 13:47:52.668220 140252629301120 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0626 13:47:52.739241 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0626 13:47:54.276893 140252629301120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0626 13:47:54.378177 140252629301120 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:2403: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import numpy as np
from sklearn.metrics import f1_score
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    pos_true, pos_pred = [], []
    shp_true, shp_pred = [], []
    true_seqs, pred_seqs = [], []
    pos_total, pos_correct = 0, 0
    shp_total, shp_correct = 0, 0

    for batch in batches:
        tag = batch['tag']
        shp = batch['shape']
        pos = batch['position']

        tag = tag.reshape((tag.shape[0], tag.shape[1]))
        shp = shp.reshape((shp.shape[0], shp.shape[1]))
        pos = pos.reshape((pos.shape[0], pos.shape[1]))

        lstm, _, shape, position = model.predict([batch['word'], batch['case'], batch['char'], batch['features'], batch['gaze']], verbose=False)
        lstm = lstm.argmax(axis=-1)
        shape = shape.argmax(axis=-1)
        position = position.argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in tag[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in lstm[seq_ind, 1: seq_len + 1]]))
            
            true_pos = np.array([ind.item() for ind in pos[seq_ind, 1: seq_len + 1]])
            pred_pos = np.array([ind.item() for ind in position[seq_ind, 1: seq_len + 1]])
            
            pos_true += list(true_pos)
            pos_pred += list(pred_pos)
            
            pos_correct += np.sum(true_pos == pred_pos)
            pos_total += len(pred_pos)
            
            true_shp = np.array([ind.item() for ind in shp[seq_ind, 1: seq_len + 1]])
            pred_shp = np.array([ind.item() for ind in shape[seq_ind, 1: seq_len + 1]])
            
            shp_true += list(true_shp)
            shp_pred += list(pred_shp)
            
            shp_correct += np.sum(true_shp == pred_shp)
            shp_total += len(pred_shp)

    f, precision, recall = evaluate(true_seqs, pred_seqs, verbose=False)
    pos_accuracy = 100 * pos_correct / pos_total
    pos_f = 100 * f1_score(pos_true, pos_pred, average='macro') 
    shp_accuracy = 100 * shp_correct / shp_total
    shp_f = 100 * f1_score(shp_true, shp_pred, average='macro') 
    
    return f, precision, recall, pos_accuracy, pos_f, shp_accuracy, shp_f

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char'], batch['features'], batch['gaze']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    f, precision, recall, pos_acc, pos_f, shp_acc, shp_f = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    print('POS F1 = {:.2f}%, Accuracy = {:.2f}%'.format(pos_f, pos_acc))
    print('Shape F1 = {:.2f}%, Accuracy = {:.2f}%'.format(shp_f, shp_acc))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 69.26s
# ---------------------------------- Evaluating ----------------------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# ================================== Train Data ==================================
# F1 = 69.23%, Precision = 69.71%, Recall = 69.47%
# POS F1 = 37.08%, Accuracy = 82.09%
# Shape F1 = 11.76%, Accuracy = 87.65%
# ================================== Valid Data ==================================
# F1 = 73.40%, Precision = 72.30%, Recall = 72.84%
# POS F1 = 37.28%, Accuracy = 82.05%
# Shape F1 = 13.65%, Accuracy = 87.60%
# ================================== Test  Data ==================================
# F1 = 67.51%, Precision = 68.84%, Recall = 68.17%
# POS F1 = 37.37%, Accuracy = 82.67%
# Shape F1 = 13.44%, Accuracy = 86.33%
# Time: 27.41s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.52s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 78.58%, Precision = 78.37%, Recall = 78.47%
# POS F1 = 52.36%, Accuracy = 90.33%
# Shape F1 = 19.65%, Accuracy = 92.62%
# ================================== Valid Data ==================================
# F1 = 79.82%, Precision = 79.42%, Recall = 79.62%
# POS F1 = 53.50%, Accuracy = 90.00%
# Shape F1 = 23.31%, Accuracy = 92.78%
# ================================== Test  Data ==================================
# F1 = 75.93%, Precision = 76.24%, Recall = 76.08%
# POS F1 = 54.58%, Accuracy = 90.25%
# Shape F1 = 22.46%, Accuracy = 91.48%
# Time: 27.82s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 81.42%, Precision = 83.95%, Recall = 82.67%
# POS F1 = 58.60%, Accuracy = 93.57%
# Shape F1 = 22.69%, Accuracy = 94.79%
# ================================== Valid Data ==================================
# F1 = 82.10%, Precision = 84.37%, Recall = 83.22%
# POS F1 = 59.72%, Accuracy = 93.05%
# Shape F1 = 26.66%, Accuracy = 94.74%
# ================================== Test  Data ==================================
# F1 = 78.16%, Precision = 81.34%, Recall = 79.72%
# POS F1 = 60.60%, Accuracy = 93.18%
# Shape F1 = 26.53%, Accuracy = 93.62%
# Time: 28.12s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.86s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.22%, Precision = 84.80%, Recall = 84.00%
# POS F1 = 63.36%, Accuracy = 95.01%
# Shape F1 = 25.44%, Accuracy = 96.18%
# ================================== Valid Data ==================================
# F1 = 83.58%, Precision = 84.74%, Recall = 84.16%
# POS F1 = 63.47%, Accuracy = 94.53%
# Shape F1 = 29.65%, Accuracy = 96.22%
# ================================== Test  Data ==================================
# F1 = 78.69%, Precision = 80.79%, Recall = 79.72%
# POS F1 = 64.67%, Accuracy = 94.66%
# Shape F1 = 29.09%, Accuracy = 95.20%
# Time: 27.77s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.44s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.30%, Precision = 86.09%, Recall = 86.19%
# POS F1 = 66.60%, Accuracy = 95.82%
# Shape F1 = 28.55%, Accuracy = 96.89%
# ================================== Valid Data ==================================
# F1 = 86.39%, Precision = 85.64%, Recall = 86.01%
# POS F1 = 66.44%, Accuracy = 95.32%
# Shape F1 = 31.77%, Accuracy = 96.95%
# ================================== Test  Data ==================================
# F1 = 82.40%, Precision = 82.63%, Recall = 82.51%
# POS F1 = 66.88%, Accuracy = 95.28%
# Shape F1 = 31.51%, Accuracy = 95.90%
# Time: 27.76s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.69s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.92%, Precision = 88.23%, Recall = 87.06%
# POS F1 = 69.84%, Accuracy = 96.44%
# Shape F1 = 30.37%, Accuracy = 97.31%
# ================================== Valid Data ==================================
# F1 = 86.13%, Precision = 88.00%, Recall = 87.06%
# POS F1 = 69.70%, Accuracy = 96.00%
# Shape F1 = 33.35%, Accuracy = 97.30%
# ================================== Test  Data ==================================
# F1 = 82.18%, Precision = 84.93%, Recall = 83.54%
# POS F1 = 70.25%, Accuracy = 95.91%
# Shape F1 = 32.66%, Accuracy = 96.36%
# Time: 27.39s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.46s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.34%, Precision = 88.66%, Recall = 87.99%
# POS F1 = 72.28%, Accuracy = 96.96%
# Shape F1 = 31.05%, Accuracy = 97.34%
# ================================== Valid Data ==================================
# F1 = 87.40%, Precision = 88.10%, Recall = 87.75%
# POS F1 = 71.76%, Accuracy = 96.54%
# Shape F1 = 34.11%, Accuracy = 97.34%
# ================================== Test  Data ==================================
# F1 = 83.49%, Precision = 85.30%, Recall = 84.39%
# POS F1 = 72.88%, Accuracy = 96.45%
# Shape F1 = 33.29%, Accuracy = 96.35%
# Time: 27.60s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.27%, Precision = 88.71%, Recall = 88.49%
# POS F1 = 73.95%, Accuracy = 97.36%
# Shape F1 = 33.58%, Accuracy = 97.74%
# ================================== Valid Data ==================================
# F1 = 88.10%, Precision = 87.98%, Recall = 88.04%
# POS F1 = 73.23%, Accuracy = 96.89%
# Shape F1 = 35.76%, Accuracy = 97.77%
# ================================== Test  Data ==================================
# F1 = 83.78%, Precision = 84.68%, Recall = 84.23%
# POS F1 = 74.25%, Accuracy = 96.81%
# Shape F1 = 35.78%, Accuracy = 96.78%
# Time: 27.66s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.42s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.86%, Precision = 89.63%, Recall = 88.74%
# POS F1 = 76.01%, Accuracy = 97.51%
# Shape F1 = 34.89%, Accuracy = 97.86%
# ================================== Valid Data ==================================
# F1 = 87.83%, Precision = 89.18%, Recall = 88.50%
# POS F1 = 75.02%, Accuracy = 97.04%
# Shape F1 = 36.86%, Accuracy = 97.91%
# ================================== Test  Data ==================================
# F1 = 82.85%, Precision = 85.36%, Recall = 84.08%
# POS F1 = 76.15%, Accuracy = 96.93%
# Shape F1 = 36.87%, Accuracy = 96.93%
# Time: 27.42s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.85%, Precision = 89.89%, Recall = 89.87%
# POS F1 = 77.08%, Accuracy = 97.75%
# Shape F1 = 36.32%, Accuracy = 97.94%
# ================================== Valid Data ==================================
# F1 = 89.51%, Precision = 89.15%, Recall = 89.33%
# POS F1 = 75.92%, Accuracy = 97.31%
# Shape F1 = 38.14%, Accuracy = 97.97%
# ================================== Test  Data ==================================
# F1 = 85.45%, Precision = 85.66%, Recall = 85.55%
# POS F1 = 77.77%, Accuracy = 97.24%
# Shape F1 = 38.08%, Accuracy = 97.10%
# Time: 28.17s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.84s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.51%, Precision = 89.83%, Recall = 89.66%
# POS F1 = 78.21%, Accuracy = 97.99%
# Shape F1 = 37.03%, Accuracy = 98.06%
# ================================== Valid Data ==================================
# F1 = 89.11%, Precision = 89.08%, Recall = 89.09%
# POS F1 = 77.34%, Accuracy = 97.56%
# Shape F1 = 38.99%, Accuracy = 98.10%
# ================================== Test  Data ==================================
# F1 = 84.43%, Precision = 85.45%, Recall = 84.93%
# POS F1 = 78.84%, Accuracy = 97.49%
# Shape F1 = 39.03%, Accuracy = 97.22%
# Time: 28.52s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.66s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.72%, Precision = 90.51%, Recall = 90.11%
# POS F1 = 78.86%, Accuracy = 98.01%
# Shape F1 = 39.27%, Accuracy = 98.22%
# ================================== Valid Data ==================================
# F1 = 89.48%, Precision = 89.85%, Recall = 89.66%
# POS F1 = 78.18%, Accuracy = 97.59%
# Shape F1 = 40.30%, Accuracy = 98.25%
# ================================== Test  Data ==================================
# F1 = 84.93%, Precision = 86.24%, Recall = 85.58%
# POS F1 = 79.55%, Accuracy = 97.51%
# Shape F1 = 40.83%, Accuracy = 97.55%
# Time: 27.91s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.68s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.77%, Precision = 90.76%, Recall = 90.77%
# POS F1 = 79.08%, Accuracy = 98.18%
# Shape F1 = 40.14%, Accuracy = 98.25%
# ================================== Valid Data ==================================
# F1 = 89.95%, Precision = 89.73%, Recall = 89.84%
# POS F1 = 78.27%, Accuracy = 97.79%
# Shape F1 = 40.56%, Accuracy = 98.26%
# ================================== Test  Data ==================================
# F1 = 86.01%, Precision = 86.35%, Recall = 86.18%
# POS F1 = 79.79%, Accuracy = 97.70%
# Shape F1 = 41.29%, Accuracy = 97.59%
# Time: 27.42s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.80%, Precision = 90.80%, Recall = 90.80%
# POS F1 = 79.58%, Accuracy = 98.27%
# Shape F1 = 41.28%, Accuracy = 98.33%
# ================================== Valid Data ==================================
# F1 = 90.02%, Precision = 89.73%, Recall = 89.88%
# POS F1 = 78.78%, Accuracy = 97.87%
# Shape F1 = 41.39%, Accuracy = 98.33%
# ================================== Test  Data ==================================
# F1 = 86.06%, Precision = 86.12%, Recall = 86.09%
# POS F1 = 80.31%, Accuracy = 97.77%
# Shape F1 = 42.88%, Accuracy = 97.72%
# Time: 28.44s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.41%, Precision = 90.55%, Recall = 90.98%
# POS F1 = 79.97%, Accuracy = 98.33%
# Shape F1 = 41.78%, Accuracy = 98.36%
# ================================== Valid Data ==================================
# F1 = 90.77%, Precision = 89.55%, Recall = 90.16%
# POS F1 = 79.37%, Accuracy = 97.92%
# Shape F1 = 41.96%, Accuracy = 98.32%
# ================================== Test  Data ==================================
# F1 = 86.40%, Precision = 85.84%, Recall = 86.12%
# POS F1 = 80.64%, Accuracy = 97.76%
# Shape F1 = 42.87%, Accuracy = 97.71%
# Time: 27.81s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.87%, Precision = 90.93%, Recall = 90.90%
# POS F1 = 80.27%, Accuracy = 98.39%
# Shape F1 = 43.34%, Accuracy = 98.45%
# ================================== Valid Data ==================================
# F1 = 90.28%, Precision = 90.19%, Recall = 90.23%
# POS F1 = 79.44%, Accuracy = 97.98%
# Shape F1 = 42.10%, Accuracy = 98.39%
# ================================== Test  Data ==================================
# F1 = 85.87%, Precision = 86.28%, Recall = 86.07%
# POS F1 = 81.14%, Accuracy = 97.90%
# Shape F1 = 44.01%, Accuracy = 97.93%
# Time: 27.87s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.56s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.86%, Precision = 90.33%, Recall = 90.59%
# POS F1 = 80.53%, Accuracy = 98.43%
# Shape F1 = 44.03%, Accuracy = 98.49%
# ================================== Valid Data ==================================
# F1 = 90.05%, Precision = 89.52%, Recall = 89.78%
# POS F1 = 79.64%, Accuracy = 98.01%
# Shape F1 = 42.93%, Accuracy = 98.41%
# ================================== Test  Data ==================================
# F1 = 85.67%, Precision = 85.41%, Recall = 85.54%
# POS F1 = 81.32%, Accuracy = 97.91%
# Shape F1 = 43.79%, Accuracy = 97.82%
# Time: 27.51s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.24%, Precision = 91.94%, Recall = 91.59%
# POS F1 = 80.99%, Accuracy = 98.49%
# Shape F1 = 45.23%, Accuracy = 98.58%
# ================================== Valid Data ==================================
# F1 = 90.73%, Precision = 90.91%, Recall = 90.82%
# POS F1 = 79.97%, Accuracy = 98.10%
# Shape F1 = 44.92%, Accuracy = 98.52%
# ================================== Test  Data ==================================
# F1 = 86.46%, Precision = 87.52%, Recall = 86.99%
# POS F1 = 81.55%, Accuracy = 97.97%
# Shape F1 = 45.01%, Accuracy = 97.95%
# Time: 27.65s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.26%, Precision = 91.76%, Recall = 92.01%
# POS F1 = 81.05%, Accuracy = 98.59%
# Shape F1 = 45.76%, Accuracy = 98.60%
# ================================== Valid Data ==================================
# F1 = 91.17%, Precision = 90.41%, Recall = 90.79%
# POS F1 = 80.21%, Accuracy = 98.15%
# Shape F1 = 44.28%, Accuracy = 98.53%
# ================================== Test  Data ==================================
# F1 = 87.32%, Precision = 87.32%, Recall = 87.32%
# POS F1 = 81.66%, Accuracy = 98.09%
# Shape F1 = 45.55%, Accuracy = 98.07%
# Time: 27.73s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.70s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.82%, Precision = 92.30%, Recall = 92.06%
# POS F1 = 81.68%, Accuracy = 98.59%
# Shape F1 = 46.52%, Accuracy = 98.64%
# ================================== Valid Data ==================================
# F1 = 91.08%, Precision = 90.93%, Recall = 91.01%
# POS F1 = 80.52%, Accuracy = 98.14%
# Shape F1 = 44.91%, Accuracy = 98.55%
# ================================== Test  Data ==================================
# F1 = 86.75%, Precision = 87.89%, Recall = 87.32%
# POS F1 = 82.07%, Accuracy = 98.09%
# Shape F1 = 46.82%, Accuracy = 98.05%
# Time: 27.63s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.62%, Precision = 92.14%, Recall = 92.38%
# POS F1 = 81.67%, Accuracy = 98.65%
# Shape F1 = 47.66%, Accuracy = 98.68%
# ================================== Valid Data ==================================
# F1 = 91.52%, Precision = 90.83%, Recall = 91.17%
# POS F1 = 80.55%, Accuracy = 98.24%
# Shape F1 = 45.51%, Accuracy = 98.57%
# ================================== Test  Data ==================================
# F1 = 87.58%, Precision = 87.61%, Recall = 87.59%
# POS F1 = 82.13%, Accuracy = 98.14%
# Shape F1 = 47.39%, Accuracy = 98.13%
# Time: 27.82s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.66%, Precision = 92.18%, Recall = 92.42%
# POS F1 = 81.77%, Accuracy = 98.66%
# Shape F1 = 48.14%, Accuracy = 98.71%
# ================================== Valid Data ==================================
# F1 = 91.86%, Precision = 91.22%, Recall = 91.54%
# POS F1 = 80.72%, Accuracy = 98.25%
# Shape F1 = 45.75%, Accuracy = 98.61%
# ================================== Test  Data ==================================
# F1 = 87.99%, Precision = 87.78%, Recall = 87.88%
# POS F1 = 82.22%, Accuracy = 98.14%
# Shape F1 = 48.63%, Accuracy = 98.17%
# Time: 27.87s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.84%, Precision = 92.54%, Recall = 92.69%
# POS F1 = 82.14%, Accuracy = 98.73%
# Shape F1 = 49.91%, Accuracy = 98.76%
# ================================== Valid Data ==================================
# F1 = 91.58%, Precision = 91.16%, Recall = 91.37%
# POS F1 = 81.04%, Accuracy = 98.32%
# Shape F1 = 46.28%, Accuracy = 98.59%
# ================================== Test  Data ==================================
# F1 = 88.19%, Precision = 88.21%, Recall = 88.20%
# POS F1 = 82.74%, Accuracy = 98.25%
# Shape F1 = 48.36%, Accuracy = 98.24%
# Time: 27.72s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.02%, Precision = 92.33%, Recall = 92.67%
# POS F1 = 82.28%, Accuracy = 98.71%
# Shape F1 = 50.91%, Accuracy = 98.80%
# ================================== Valid Data ==================================
# F1 = 91.78%, Precision = 90.91%, Recall = 91.34%
# POS F1 = 81.09%, Accuracy = 98.28%
# Shape F1 = 46.20%, Accuracy = 98.65%
# ================================== Test  Data ==================================
# F1 = 87.67%, Precision = 87.62%, Recall = 87.65%
# POS F1 = 83.04%, Accuracy = 98.25%
# Shape F1 = 48.86%, Accuracy = 98.28%
# Time: 27.50s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.94%, Precision = 92.61%, Recall = 92.78%
# POS F1 = 82.71%, Accuracy = 98.83%
# Shape F1 = 51.42%, Accuracy = 98.81%
# ================================== Valid Data ==================================
# F1 = 91.91%, Precision = 91.35%, Recall = 91.63%
# POS F1 = 81.57%, Accuracy = 98.40%
# Shape F1 = 48.52%, Accuracy = 98.68%
# ================================== Test  Data ==================================
# F1 = 87.58%, Precision = 87.91%, Recall = 87.74%
# POS F1 = 83.26%, Accuracy = 98.32%
# Shape F1 = 49.48%, Accuracy = 98.21%
# Time: 27.69s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.84%, Precision = 92.52%, Recall = 92.68%
# POS F1 = 82.49%, Accuracy = 98.76%
# Shape F1 = 52.76%, Accuracy = 98.83%
# ================================== Valid Data ==================================
# F1 = 91.54%, Precision = 91.01%, Recall = 91.27%
# POS F1 = 81.29%, Accuracy = 98.32%
# Shape F1 = 48.35%, Accuracy = 98.66%
# ================================== Test  Data ==================================
# F1 = 87.46%, Precision = 87.64%, Recall = 87.55%
# POS F1 = 83.04%, Accuracy = 98.24%
# Shape F1 = 50.54%, Accuracy = 98.27%
# Time: 28.06s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.89s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.31%, Precision = 92.88%, Recall = 93.10%
# POS F1 = 82.64%, Accuracy = 98.80%
# Shape F1 = 52.75%, Accuracy = 98.85%
# ================================== Valid Data ==================================
# F1 = 92.24%, Precision = 91.65%, Recall = 91.95%
# POS F1 = 81.32%, Accuracy = 98.38%
# Shape F1 = 48.78%, Accuracy = 98.68%
# ================================== Test  Data ==================================
# F1 = 88.15%, Precision = 88.28%, Recall = 88.22%
# POS F1 = 83.13%, Accuracy = 98.30%
# Shape F1 = 50.65%, Accuracy = 98.30%
# Time: 27.80s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.88s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.28%, Precision = 93.21%, Recall = 93.25%
# POS F1 = 82.57%, Accuracy = 98.83%
# Shape F1 = 54.12%, Accuracy = 98.88%
# ================================== Valid Data ==================================
# F1 = 92.06%, Precision = 91.70%, Recall = 91.88%
# POS F1 = 81.26%, Accuracy = 98.42%
# Shape F1 = 48.88%, Accuracy = 98.72%
# ================================== Test  Data ==================================
# F1 = 87.98%, Precision = 88.51%, Recall = 88.24%
# POS F1 = 83.19%, Accuracy = 98.35%
# Shape F1 = 51.65%, Accuracy = 98.33%
# Time: 28.04s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.48%, Precision = 93.42%, Recall = 93.45%
# POS F1 = 83.07%, Accuracy = 98.87%
# Shape F1 = 55.56%, Accuracy = 98.92%
# ================================== Valid Data ==================================
# F1 = 92.12%, Precision = 91.74%, Recall = 91.93%
# POS F1 = 81.52%, Accuracy = 98.44%
# Shape F1 = 49.55%, Accuracy = 98.75%
# ================================== Test  Data ==================================
# F1 = 88.24%, Precision = 88.77%, Recall = 88.51%
# POS F1 = 83.55%, Accuracy = 98.39%
# Shape F1 = 51.68%, Accuracy = 98.40%
# Time: 27.84s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.85s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.53%, Precision = 93.31%, Recall = 93.42%
# POS F1 = 83.61%, Accuracy = 98.87%
# Shape F1 = 56.47%, Accuracy = 98.91%
# ================================== Valid Data ==================================
# F1 = 92.38%, Precision = 91.87%, Recall = 92.13%
# POS F1 = 81.82%, Accuracy = 98.43%
# Shape F1 = 49.54%, Accuracy = 98.72%
# ================================== Test  Data ==================================
# F1 = 87.75%, Precision = 88.05%, Recall = 87.90%
# POS F1 = 83.60%, Accuracy = 98.39%
# Shape F1 = 52.82%, Accuracy = 98.37%
# Time: 28.33s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.92%, Precision = 93.27%, Recall = 93.60%
# POS F1 = 83.91%, Accuracy = 98.92%
# Shape F1 = 56.48%, Accuracy = 98.95%
# ================================== Valid Data ==================================
# F1 = 92.76%, Precision = 91.82%, Recall = 92.29%
# POS F1 = 81.77%, Accuracy = 98.47%
# Shape F1 = 51.10%, Accuracy = 98.77%
# ================================== Test  Data ==================================
# F1 = 88.73%, Precision = 88.49%, Recall = 88.61%
# POS F1 = 83.86%, Accuracy = 98.44%
# Shape F1 = 53.03%, Accuracy = 98.44%
# Time: 28.58s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.44%, Precision = 93.56%, Recall = 93.50%
# POS F1 = 84.10%, Accuracy = 98.95%
# Shape F1 = 57.74%, Accuracy = 98.97%
# ================================== Valid Data ==================================
# F1 = 91.96%, Precision = 91.82%, Recall = 91.89%
# POS F1 = 81.89%, Accuracy = 98.50%
# Shape F1 = 50.25%, Accuracy = 98.76%
# ================================== Test  Data ==================================
# F1 = 87.61%, Precision = 88.24%, Recall = 87.92%
# POS F1 = 83.84%, Accuracy = 98.44%
# Shape F1 = 52.53%, Accuracy = 98.44%
# Time: 28.59s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.99s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.84%, Precision = 93.66%, Recall = 93.75%
# POS F1 = 84.00%, Accuracy = 98.93%
# Shape F1 = 57.61%, Accuracy = 98.98%
# ================================== Valid Data ==================================
# F1 = 92.56%, Precision = 92.17%, Recall = 92.37%
# POS F1 = 81.90%, Accuracy = 98.52%
# Shape F1 = 51.58%, Accuracy = 98.80%
# ================================== Test  Data ==================================
# F1 = 88.21%, Precision = 88.53%, Recall = 88.37%
# POS F1 = 83.72%, Accuracy = 98.40%
# Shape F1 = 52.32%, Accuracy = 98.45%
# Time: 27.95s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.70%, Precision = 93.37%, Recall = 93.54%
# POS F1 = 83.57%, Accuracy = 98.95%
# Shape F1 = 58.50%, Accuracy = 98.98%
# ================================== Valid Data ==================================
# F1 = 92.53%, Precision = 91.96%, Recall = 92.24%
# POS F1 = 81.72%, Accuracy = 98.50%
# Shape F1 = 51.07%, Accuracy = 98.77%
# ================================== Test  Data ==================================
# F1 = 88.15%, Precision = 88.37%, Recall = 88.26%
# POS F1 = 83.84%, Accuracy = 98.46%
# Shape F1 = 52.69%, Accuracy = 98.43%
# Time: 27.96s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.76s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.94%, Precision = 93.51%, Recall = 93.73%
# POS F1 = 83.79%, Accuracy = 98.99%
# Shape F1 = 59.53%, Accuracy = 99.02%
# ================================== Valid Data ==================================
# F1 = 92.90%, Precision = 92.09%, Recall = 92.49%
# POS F1 = 82.09%, Accuracy = 98.56%
# Shape F1 = 51.71%, Accuracy = 98.81%
# ================================== Test  Data ==================================
# F1 = 88.49%, Precision = 88.44%, Recall = 88.46%
# POS F1 = 84.06%, Accuracy = 98.51%
# Shape F1 = 53.11%, Accuracy = 98.44%
# Time: 27.72s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.22%, Precision = 93.61%, Recall = 93.91%
# POS F1 = 84.14%, Accuracy = 99.04%
# Shape F1 = 59.83%, Accuracy = 99.01%
# ================================== Valid Data ==================================
# F1 = 92.76%, Precision = 91.92%, Recall = 92.34%
# POS F1 = 82.37%, Accuracy = 98.63%
# Shape F1 = 52.83%, Accuracy = 98.79%
# ================================== Test  Data ==================================
# F1 = 88.79%, Precision = 88.49%, Recall = 88.64%
# POS F1 = 84.19%, Accuracy = 98.53%
# Shape F1 = 53.31%, Accuracy = 98.45%
# Time: 27.72s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.80s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.21%, Precision = 93.90%, Recall = 94.05%
# POS F1 = 84.32%, Accuracy = 99.00%
# Shape F1 = 60.78%, Accuracy = 99.04%
# ================================== Valid Data ==================================
# F1 = 92.86%, Precision = 92.19%, Recall = 92.53%
# POS F1 = 82.24%, Accuracy = 98.56%
# Shape F1 = 52.46%, Accuracy = 98.81%
# ================================== Test  Data ==================================
# F1 = 88.31%, Precision = 88.53%, Recall = 88.42%
# POS F1 = 84.08%, Accuracy = 98.52%
# Shape F1 = 55.16%, Accuracy = 98.49%
# Time: 27.63s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.15%, Precision = 93.90%, Recall = 94.03%
# POS F1 = 84.14%, Accuracy = 99.01%
# Shape F1 = 61.70%, Accuracy = 99.06%
# ================================== Valid Data ==================================
# F1 = 92.76%, Precision = 92.12%, Recall = 92.44%
# POS F1 = 82.35%, Accuracy = 98.57%
# Shape F1 = 54.49%, Accuracy = 98.83%
# ================================== Test  Data ==================================
# F1 = 88.22%, Precision = 88.56%, Recall = 88.39%
# POS F1 = 84.24%, Accuracy = 98.55%
# Shape F1 = 56.11%, Accuracy = 98.47%
# Time: 28.51s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.42%, Precision = 93.95%, Recall = 94.19%
# POS F1 = 84.48%, Accuracy = 99.04%
# Shape F1 = 62.11%, Accuracy = 99.08%
# ================================== Valid Data ==================================
# F1 = 93.13%, Precision = 92.38%, Recall = 92.75%
# POS F1 = 82.33%, Accuracy = 98.62%
# Shape F1 = 54.13%, Accuracy = 98.84%
# ================================== Test  Data ==================================
# F1 = 88.67%, Precision = 88.58%, Recall = 88.63%
# POS F1 = 84.12%, Accuracy = 98.51%
# Shape F1 = 57.17%, Accuracy = 98.50%
# Time: 28.14s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.38%, Precision = 93.93%, Recall = 94.16%
# POS F1 = 84.58%, Accuracy = 99.01%
# Shape F1 = 61.95%, Accuracy = 99.07%
# ================================== Valid Data ==================================
# F1 = 92.95%, Precision = 92.34%, Recall = 92.65%
# POS F1 = 81.95%, Accuracy = 98.56%
# Shape F1 = 54.12%, Accuracy = 98.84%
# ================================== Test  Data ==================================
# F1 = 88.94%, Precision = 89.13%, Recall = 89.03%
# POS F1 = 83.97%, Accuracy = 98.52%
# Shape F1 = 56.43%, Accuracy = 98.52%
# Time: 28.63s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.78s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.02%, Precision = 93.70%, Recall = 93.86%
# POS F1 = 84.44%, Accuracy = 99.03%
# Shape F1 = 62.61%, Accuracy = 99.09%
# ================================== Valid Data ==================================
# F1 = 92.82%, Precision = 92.19%, Recall = 92.50%
# POS F1 = 81.88%, Accuracy = 98.58%
# Shape F1 = 53.80%, Accuracy = 98.85%
# ================================== Test  Data ==================================
# F1 = 88.48%, Precision = 88.65%, Recall = 88.56%
# POS F1 = 84.11%, Accuracy = 98.51%
# Shape F1 = 56.05%, Accuracy = 98.51%
# Time: 27.62s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.88s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.70%, Precision = 94.03%, Recall = 94.36%
# POS F1 = 85.04%, Accuracy = 99.04%
# Shape F1 = 63.27%, Accuracy = 99.11%
# ================================== Valid Data ==================================
# F1 = 93.27%, Precision = 92.33%, Recall = 92.79%
# POS F1 = 82.30%, Accuracy = 98.64%
# Shape F1 = 53.82%, Accuracy = 98.85%
# ================================== Test  Data ==================================
# F1 = 89.07%, Precision = 88.74%, Recall = 88.90%
# POS F1 = 84.24%, Accuracy = 98.54%
# Shape F1 = 56.88%, Accuracy = 98.55%
# Time: 27.69s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.80s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.29%, Precision = 94.02%, Recall = 94.16%
# POS F1 = 84.97%, Accuracy = 99.06%
# Shape F1 = 63.78%, Accuracy = 99.11%
# ================================== Valid Data ==================================
# F1 = 92.63%, Precision = 92.26%, Recall = 92.45%
# POS F1 = 82.89%, Accuracy = 98.63%
# Shape F1 = 54.58%, Accuracy = 98.83%
# ================================== Test  Data ==================================
# F1 = 88.25%, Precision = 88.74%, Recall = 88.50%
# POS F1 = 84.29%, Accuracy = 98.54%
# Shape F1 = 56.54%, Accuracy = 98.48%
# Time: 27.84s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.94%, Precision = 94.04%, Recall = 94.49%
# POS F1 = 85.01%, Accuracy = 99.09%
# Shape F1 = 63.88%, Accuracy = 99.12%
# ================================== Valid Data ==================================
# F1 = 93.43%, Precision = 92.43%, Recall = 92.93%
# POS F1 = 82.91%, Accuracy = 98.65%
# Shape F1 = 55.02%, Accuracy = 98.86%
# ================================== Test  Data ==================================
# F1 = 89.26%, Precision = 88.74%, Recall = 89.00%
# POS F1 = 84.28%, Accuracy = 98.57%
# Shape F1 = 58.28%, Accuracy = 98.57%
# Time: 27.59s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.68s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.83%, Precision = 94.22%, Recall = 94.52%
# POS F1 = 85.75%, Accuracy = 99.09%
# Shape F1 = 64.44%, Accuracy = 99.14%
# ================================== Valid Data ==================================
# F1 = 93.36%, Precision = 92.54%, Recall = 92.95%
# POS F1 = 83.90%, Accuracy = 98.68%
# Shape F1 = 55.19%, Accuracy = 98.88%
# ================================== Test  Data ==================================
# F1 = 89.19%, Precision = 88.79%, Recall = 88.99%
# POS F1 = 85.00%, Accuracy = 98.60%
# Shape F1 = 57.92%, Accuracy = 98.54%
# Time: 27.86s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.53s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.52%, Precision = 94.31%, Recall = 94.42%
# POS F1 = 85.78%, Accuracy = 99.09%
# Shape F1 = 64.71%, Accuracy = 99.14%
# ================================== Valid Data ==================================
# F1 = 92.83%, Precision = 92.43%, Recall = 92.63%
# POS F1 = 84.17%, Accuracy = 98.65%
# Shape F1 = 55.47%, Accuracy = 98.85%
# ================================== Test  Data ==================================
# F1 = 88.64%, Precision = 88.97%, Recall = 88.80%
# POS F1 = 85.24%, Accuracy = 98.58%
# Shape F1 = 58.15%, Accuracy = 98.56%
# Time: 27.88s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.61%, Precision = 94.25%, Recall = 94.43%
# POS F1 = 85.67%, Accuracy = 99.09%
# Shape F1 = 64.99%, Accuracy = 99.16%
# ================================== Valid Data ==================================
# F1 = 93.02%, Precision = 92.34%, Recall = 92.68%
# POS F1 = 84.87%, Accuracy = 98.69%
# Shape F1 = 56.02%, Accuracy = 98.90%
# ================================== Test  Data ==================================
# F1 = 88.57%, Precision = 88.62%, Recall = 88.59%
# POS F1 = 85.65%, Accuracy = 98.59%
# Shape F1 = 58.20%, Accuracy = 98.56%
# Time: 27.82s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.40s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.70%, Precision = 94.20%, Recall = 94.45%
# POS F1 = 87.18%, Accuracy = 99.16%
# Shape F1 = 65.57%, Accuracy = 99.17%
# ================================== Valid Data ==================================
# F1 = 93.20%, Precision = 92.21%, Recall = 92.70%
# POS F1 = 85.09%, Accuracy = 98.74%
# Shape F1 = 56.65%, Accuracy = 98.93%
# ================================== Test  Data ==================================
# F1 = 88.61%, Precision = 88.33%, Recall = 88.47%
# POS F1 = 85.54%, Accuracy = 98.65%
# Shape F1 = 58.91%, Accuracy = 98.59%
# Time: 27.77s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.60s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.96%, Precision = 94.63%, Recall = 94.79%
# POS F1 = 87.11%, Accuracy = 99.15%
# Shape F1 = 65.61%, Accuracy = 99.16%
# ================================== Valid Data ==================================
# F1 = 93.24%, Precision = 92.66%, Recall = 92.95%
# POS F1 = 85.01%, Accuracy = 98.71%
# Shape F1 = 56.20%, Accuracy = 98.89%
# ================================== Test  Data ==================================
# F1 = 88.89%, Precision = 89.00%, Recall = 88.95%
# POS F1 = 85.67%, Accuracy = 98.64%
# Shape F1 = 59.21%, Accuracy = 98.60%
# Time: 27.47s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.05%, Precision = 94.48%, Recall = 94.77%
# POS F1 = 88.05%, Accuracy = 99.16%
# Shape F1 = 66.32%, Accuracy = 99.18%
# ================================== Valid Data ==================================
# F1 = 93.44%, Precision = 92.60%, Recall = 93.02%
# POS F1 = 86.37%, Accuracy = 98.73%
# Shape F1 = 56.94%, Accuracy = 98.93%
# ================================== Test  Data ==================================
# F1 = 89.03%, Precision = 88.76%, Recall = 88.89%
# POS F1 = 86.04%, Accuracy = 98.66%
# Shape F1 = 59.24%, Accuracy = 98.60%
# Time: 27.79s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.80%, Precision = 94.72%, Recall = 94.76%
# POS F1 = 88.41%, Accuracy = 99.18%
# Shape F1 = 66.63%, Accuracy = 99.18%
# ================================== Valid Data ==================================
# F1 = 93.10%, Precision = 92.68%, Recall = 92.89%
# POS F1 = 86.09%, Accuracy = 98.73%
# Shape F1 = 56.87%, Accuracy = 98.91%
# ================================== Test  Data ==================================
# F1 = 88.79%, Precision = 89.09%, Recall = 88.94%
# POS F1 = 87.50%, Accuracy = 98.69%
# Shape F1 = 59.99%, Accuracy = 98.61%
# Time: 28.07s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.91s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.93%, Precision = 94.49%, Recall = 94.71%
# POS F1 = 88.46%, Accuracy = 99.16%
# Shape F1 = 66.67%, Accuracy = 99.19%
# ================================== Valid Data ==================================
# F1 = 93.40%, Precision = 92.63%, Recall = 93.01%
# POS F1 = 86.36%, Accuracy = 98.72%
# Shape F1 = 56.74%, Accuracy = 98.91%
# ================================== Test  Data ==================================
# F1 = 89.11%, Precision = 89.29%, Recall = 89.20%
# POS F1 = 87.27%, Accuracy = 98.66%
# Shape F1 = 60.26%, Accuracy = 98.59%
# Time: 27.89s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.06%, Precision = 94.73%, Recall = 94.90%
# POS F1 = 89.16%, Accuracy = 99.17%
# Shape F1 = 67.16%, Accuracy = 99.20%
# ================================== Valid Data ==================================
# F1 = 93.16%, Precision = 92.56%, Recall = 92.86%
# POS F1 = 86.26%, Accuracy = 98.73%
# Shape F1 = 56.52%, Accuracy = 98.93%
# ================================== Test  Data ==================================
# F1 = 88.94%, Precision = 89.09%, Recall = 89.01%
# POS F1 = 87.72%, Accuracy = 98.69%
# Shape F1 = 60.85%, Accuracy = 98.63%
# Time: 27.41s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.84%, Precision = 94.54%, Recall = 94.69%
# POS F1 = 88.54%, Accuracy = 99.19%
# Shape F1 = 67.08%, Accuracy = 99.19%
# ================================== Valid Data ==================================
# F1 = 93.01%, Precision = 92.54%, Recall = 92.78%
# POS F1 = 85.79%, Accuracy = 98.75%
# Shape F1 = 57.46%, Accuracy = 98.91%
# ================================== Test  Data ==================================
# F1 = 88.58%, Precision = 88.69%, Recall = 88.63%
# POS F1 = 86.54%, Accuracy = 98.67%
# ...
# Time: 28.45s
#
# ----------------------------------- EPOCH: 531 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.10s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.21%, Precision = 98.18%, Recall = 98.20%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.02%, Accuracy = 99.82%
# ================================== Valid Data ==================================
# F1 = 94.20%, Precision = 93.81%, Recall = 94.00%
# POS F1 = 92.37%, Accuracy = 99.14%
# Shape F1 = 74.35%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.50%, Precision = 90.60%, Recall = 90.55%
# POS F1 = 95.26%, Accuracy = 99.14%
# Shape F1 = 73.03%, Accuracy = 99.19%
# Time: 28.52s
#
# ----------------------------------- EPOCH: 532 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 50.10s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.19%, Precision = 98.20%, Recall = 98.19%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.04%, Accuracy = 99.82%
# ================================== Valid Data ==================================
# F1 = 94.28%, Precision = 93.82%, Recall = 94.05%
# POS F1 = 92.25%, Accuracy = 99.14%
# Shape F1 = 74.71%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.45%, Precision = 90.51%, Recall = 90.48%
# POS F1 = 95.27%, Accuracy = 99.13%
# Shape F1 = 73.17%, Accuracy = 99.19%
# Time: 27.33s
#
# ----------------------------------- EPOCH: 533 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.18%, Precision = 98.20%, Recall = 98.19%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.08%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.19%, Precision = 93.77%, Recall = 93.98%
# POS F1 = 92.27%, Accuracy = 99.13%
# Shape F1 = 74.75%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.25%, Precision = 90.51%, Recall = 90.38%
# POS F1 = 95.30%, Accuracy = 99.15%
# Shape F1 = 73.76%, Accuracy = 99.19%
# Time: 26.49s
#
# ----------------------------------- EPOCH: 534 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.23%, Precision = 98.23%, Recall = 98.23%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.09%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.20%, Precision = 93.82%, Recall = 94.01%
# POS F1 = 92.21%, Accuracy = 99.13%
# Shape F1 = 74.16%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.48%, Precision = 90.58%, Recall = 90.53%
# POS F1 = 95.31%, Accuracy = 99.14%
# Shape F1 = 72.92%, Accuracy = 99.18%
# Time: 27.60s
#
# ----------------------------------- EPOCH: 535 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.79s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.22%, Precision = 98.19%, Recall = 98.20%
# POS F1 = 98.11%, Accuracy = 99.70%
# Shape F1 = 92.10%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 93.79%, Recall = 94.02%
# POS F1 = 92.33%, Accuracy = 99.14%
# Shape F1 = 74.46%, Accuracy = 99.52%
# ================================== Test  Data ==================================
# F1 = 90.48%, Precision = 90.49%, Recall = 90.48%
# POS F1 = 95.31%, Accuracy = 99.17%
# Shape F1 = 73.60%, Accuracy = 99.18%
# Time: 28.03s
#
# ----------------------------------- EPOCH: 536 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.19%, Precision = 98.21%, Recall = 98.20%
# POS F1 = 98.14%, Accuracy = 99.70%
# Shape F1 = 92.03%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.13%, Precision = 93.91%, Recall = 94.02%
# POS F1 = 92.55%, Accuracy = 99.14%
# Shape F1 = 74.17%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.16%, Precision = 90.51%, Recall = 90.33%
# POS F1 = 95.29%, Accuracy = 99.13%
# Shape F1 = 73.66%, Accuracy = 99.18%
# Time: 27.53s
#
# ----------------------------------- EPOCH: 537 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.21%, Precision = 98.22%, Recall = 98.21%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.01%, Accuracy = 99.82%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 93.87%, Recall = 94.06%
# POS F1 = 92.30%, Accuracy = 99.14%
# Shape F1 = 74.81%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.30%, Precision = 90.47%, Recall = 90.39%
# POS F1 = 95.29%, Accuracy = 99.15%
# Shape F1 = 73.84%, Accuracy = 99.18%
# Time: 27.67s
#
# ----------------------------------- EPOCH: 538 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.20%, Precision = 98.14%, Recall = 98.17%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.13%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.25%, Precision = 93.79%, Recall = 94.02%
# POS F1 = 92.26%, Accuracy = 99.13%
# Shape F1 = 74.74%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.29%, Precision = 90.35%, Recall = 90.32%
# POS F1 = 95.25%, Accuracy = 99.15%
# Shape F1 = 72.88%, Accuracy = 99.18%
# Time: 28.30s
#
# ----------------------------------- EPOCH: 539 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.21%, Precision = 98.22%, Recall = 98.22%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.19%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.20%, Precision = 93.81%, Recall = 94.00%
# POS F1 = 92.30%, Accuracy = 99.14%
# Shape F1 = 74.89%, Accuracy = 99.52%
# ================================== Test  Data ==================================
# F1 = 90.31%, Precision = 90.44%, Recall = 90.38%
# POS F1 = 95.26%, Accuracy = 99.14%
# Shape F1 = 73.17%, Accuracy = 99.18%
# Time: 28.14s
#
# ----------------------------------- EPOCH: 540 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.20%, Precision = 98.17%, Recall = 98.18%
# POS F1 = 98.14%, Accuracy = 99.70%
# Shape F1 = 92.22%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.27%, Precision = 93.84%, Recall = 94.05%
# POS F1 = 92.26%, Accuracy = 99.14%
# Shape F1 = 74.87%, Accuracy = 99.52%
# ================================== Test  Data ==================================
# F1 = 90.56%, Precision = 90.53%, Recall = 90.54%
# POS F1 = 95.25%, Accuracy = 99.15%
# Shape F1 = 73.32%, Accuracy = 99.18%
# Time: 27.11s
#
# ----------------------------------- EPOCH: 541 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 48.80s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.18%, Precision = 98.18%, Recall = 98.18%
# POS F1 = 98.13%, Accuracy = 99.70%
# Shape F1 = 92.20%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.32%, Precision = 93.87%, Recall = 94.10%
# POS F1 = 92.63%, Accuracy = 99.15%
# Shape F1 = 74.98%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.41%, Precision = 90.47%, Recall = 90.44%
# POS F1 = 95.36%, Accuracy = 99.16%
# Shape F1 = 73.09%, Accuracy = 99.18%
# Time: 26.99s
#
# ----------------------------------- EPOCH: 542 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.22%, Precision = 98.23%, Recall = 98.22%
# POS F1 = 98.11%, Accuracy = 99.70%
# Shape F1 = 92.25%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.23%, Precision = 93.98%, Recall = 94.10%
# POS F1 = 92.54%, Accuracy = 99.14%
# Shape F1 = 75.02%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.28%, Precision = 90.46%, Recall = 90.37%
# POS F1 = 95.21%, Accuracy = 99.14%
# Shape F1 = 73.12%, Accuracy = 99.18%
# Time: 27.95s
#
# ----------------------------------- EPOCH: 543 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.23%, Precision = 98.23%, Recall = 98.23%
# POS F1 = 98.15%, Accuracy = 99.70%
# Shape F1 = 92.20%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.21%, Precision = 93.92%, Recall = 94.07%
# POS F1 = 92.45%, Accuracy = 99.15%
# Shape F1 = 75.08%, Accuracy = 99.52%
# ================================== Test  Data ==================================
# F1 = 90.51%, Precision = 90.67%, Recall = 90.59%
# POS F1 = 95.20%, Accuracy = 99.15%
# Shape F1 = 73.34%, Accuracy = 99.18%
# Time: 26.89s
#
# ----------------------------------- EPOCH: 544 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.20%, Precision = 98.23%, Recall = 98.22%
# POS F1 = 98.13%, Accuracy = 99.70%
# Shape F1 = 92.18%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.21%, Precision = 93.91%, Recall = 94.06%
# POS F1 = 92.30%, Accuracy = 99.14%
# Shape F1 = 74.44%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.23%, Precision = 90.47%, Recall = 90.35%
# POS F1 = 95.32%, Accuracy = 99.16%
# Shape F1 = 73.35%, Accuracy = 99.18%
# Time: 27.17s
#
# ----------------------------------- EPOCH: 545 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.20%, Precision = 98.23%, Recall = 98.22%
# POS F1 = 98.13%, Accuracy = 99.70%
# Shape F1 = 92.27%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.18%, Precision = 93.87%, Recall = 94.02%
# POS F1 = 92.23%, Accuracy = 99.15%
# Shape F1 = 75.33%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.16%, Precision = 90.40%, Recall = 90.28%
# POS F1 = 95.30%, Accuracy = 99.14%
# Shape F1 = 73.43%, Accuracy = 99.18%
# Time: 27.86s
#
# ----------------------------------- EPOCH: 546 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.60s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.24%, Precision = 98.20%, Recall = 98.22%
# POS F1 = 98.12%, Accuracy = 99.70%
# Shape F1 = 92.15%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.21%, Precision = 93.89%, Recall = 94.05%
# POS F1 = 92.25%, Accuracy = 99.13%
# Shape F1 = 74.14%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.29%, Precision = 90.42%, Recall = 90.36%
# POS F1 = 95.26%, Accuracy = 99.14%
# Shape F1 = 73.05%, Accuracy = 99.18%
# Time: 27.74s
#
# ----------------------------------- EPOCH: 547 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.23%, Precision = 98.21%, Recall = 98.22%
# POS F1 = 98.14%, Accuracy = 99.70%
# Shape F1 = 92.12%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.21%, Precision = 93.89%, Recall = 94.05%
# POS F1 = 92.28%, Accuracy = 99.14%
# Shape F1 = 75.00%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.43%, Precision = 90.55%, Recall = 90.49%
# POS F1 = 95.45%, Accuracy = 99.15%
# Shape F1 = 72.93%, Accuracy = 99.18%
# Time: 27.93s
#
# ----------------------------------- EPOCH: 548 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 49.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.23%, Precision = 98.26%, Recall = 98.24%
# POS F1 = 98.13%, Accuracy = 99.70%
# Shape F1 = 92.10%, Accuracy = 99.83%
# ================================== Valid Data ==================================
# F1 = 94.13%, Precision = 93.94%, Recall = 94.04%
# POS F1 = 92.19%, Accuracy = 99.13%
# Shape F1 = 75.10%, Accuracy = 99.51%
# ================================== Test  Data ==================================
# F1 = 90.18%, Precision = 90.69%, Recall = 90.43%
# POS F1 = 95.34%, Accuracy = 99.14%
# Shape F1 = 73.02%, Accuracy = 99.18%
# Time: 27.36s
#
# ----------------------------------- EPOCH: 549 -----------------------------------
# ----------------------------------- Training -----------------------------------

# %%
# 90.78
