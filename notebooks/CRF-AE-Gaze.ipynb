# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-5wiv134n
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-5wiv134n
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.7)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.3)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wmhpmxw0/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
# !chmod 777 install
# !./install
# Out:
# --2019-05-14 15:39:38--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3281527 (3.1M) [text/plain]
# Saving to: ‘eng.train’
#
# eng.train           100%[===================>]   3.13M  --.-KB/s    in 0.06s
#
# 2019-05-14 15:39:39 (51.4 MB/s) - ‘eng.train’ saved [3281527/3281527]
#
# --2019-05-14 15:39:39--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827009 (808K) [text/plain]
# Saving to: ‘eng.testa’
#
# eng.testa           100%[===================>] 807.63K  --.-KB/s    in 0.05s
#
# 2019-05-14 15:39:39 (17.4 MB/s) - ‘eng.testa’ saved [827009/827009]
#
# --2019-05-14 15:39:39--  https://raw.githubusercontent.com/glample/tagger/master/dataset/eng.testb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 748094 (731K) [text/plain]
# Saving to: ‘eng.testb’
#
# eng.testb           100%[===================>] 730.56K  --.-KB/s    in 0.04s
#
# 2019-05-14 15:39:39 (19.7 MB/s) - ‘eng.testb’ saved [748094/748094]
#
# --2019-05-14 15:39:39--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-05-14 15:39:39--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  2.36MB/s    in 7m 21s
#
# 2019-05-14 15:47:00 (1.87 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
# Cloning into 'gdown.pl'...
# remote: Enumerating objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:22--  https://docs.google.com/uc?id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.199.113, 74.125.199.102, 74.125.199.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.199.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘all_onehot.train’
#
#      0K                                     32.0M=0s
#
# 2019-05-14 15:47:22 (32.0 MB/s) - ‘all_onehot.train’ saved [3252]
#
# --2019-05-14 15:47:22--  https://docs.google.com/uc?export=download&confirm=CRp4&id=1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w
# Resolving docs.google.com (docs.google.com)... 74.125.20.102, 74.125.20.138, 74.125.20.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.20.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/om3ki6ceg0ej00na6utsuqf5e9cuth9d/1557842400000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:22--  https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/om3ki6ceg0ej00na6utsuqf5e9cuth9d/1557842400000/05348309593456850141/*/1VAsCFRwJlR-HqC2g23L0iuTbcDRyv66w?e=download
# Resolving doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.train’
#
#      0K ........ ........ ........ ........ 91.7M
#  32768K ........ ........ ........ ........  211M
#  65536K ........ ........ ........ ........  223M
#  98304K ........ ........ ........ ........  219M
# 131072K ........ ........ ........ ........  236M
# 163840K ........ ........ ........ ........  229M
# 196608K ........ ........ ........ ........  222M
# 229376K ........ ........ ........ ........  230M
# 262144K ........ ........ ........ ........  173M
# 294912K ........ ........ ........ ........  187M
# 327680K ........ ........ ........ ........  215M
# 360448K ........ ........ ......             133M=2.0s
#
# 2019-05-14 15:47:25 (185 MB/s) - ‘all_onehot.train’ saved [392581451]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:25--  https://docs.google.com/uc?id=1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.197.100, 74.125.197.113, 74.125.197.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9v85cmr492lepbcp2i65ne788963niia/1557842400000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:28--  https://doc-10-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9v85cmr492lepbcp2i65ne788963niia/1557842400000/05348309593456850141/*/1J2NRSshE-OpCM03HzwLPNrRRAGOUdwTd?e=download
# Resolving doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-10-24-docs.googleusercontent.com (doc-10-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testa’
#
#      0K ........ ........ ........ ........  148M
#  32768K ........ ........ ........ ........  257M
#  65536K ........ ........ ........ ......    268M=0.5s
#
# 2019-05-14 15:47:28 (208 MB/s) - ‘all_onehot.testa’ saved [99026097]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:28--  https://docs.google.com/uc?id=1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.142.113, 74.125.142.101, 74.125.142.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/h717lho23unmhhrm4786qck2e0bhh7t1/1557842400000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:31--  https://doc-00-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/h717lho23unmhhrm4786qck2e0bhh7t1/1557842400000/05348309593456850141/*/1GkX86aZxy4XhbYRh-dbLEKvBxWI8zCib?e=download
# Resolving doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-00-24-docs.googleusercontent.com (doc-00-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘all_onehot.testb’
#
#      0K ........ ........ ........ ........  159M
#  32768K ........ ........ ........ ........  265M
#  65536K ........ ........ .....              263M=0.4s
#
# 2019-05-14 15:47:32 (212 MB/s) - ‘all_onehot.testb’ saved [89526841]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:32--  https://docs.google.com/uc?id=1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.197.100, 74.125.197.113, 74.125.197.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/86uptjv7rlqtcs4iagqrkneko4ur9cmf/1557842400000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:33--  https://doc-0s-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/86uptjv7rlqtcs4iagqrkneko4ur9cmf/1557842400000/05348309593456850141/*/1VdX0-3JupF2gh8e8za3hfbAc8Inl9fm9?e=download
# Resolving doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-0s-24-docs.googleusercontent.com (doc-0s-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.train’
#
#      0K ....                                 208M=0.02s
#
# 2019-05-14 15:47:33 (208 MB/s) - ‘gazetteer_PERLOC.train’ saved [4887067]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:33--  https://docs.google.com/uc?id=1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.197.100, 74.125.197.113, 74.125.197.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0868cktcjn1caeatrgqni8ukvemeat8c/1557842400000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:34--  https://doc-0c-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0868cktcjn1caeatrgqni8ukvemeat8c/1557842400000/05348309593456850141/*/1udfAcEdsePQoiuXuvn0VdvQZBMCcrYWn?e=download
# Resolving doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-0c-24-docs.googleusercontent.com (doc-0c-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1232849 (1.2M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testa’
#
#      0K .                                  100%  128M=0.009s
#
# 2019-05-14 15:47:34 (128 MB/s) - ‘gazetteer_PERLOC.testa’ saved [1232849/1232849]
#
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-05-14 15:47:34--  https://docs.google.com/uc?id=1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh&export=download
# Resolving docs.google.com (docs.google.com)... 74.125.142.113, 74.125.142.101, 74.125.142.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/28dcp1ql2qiol7gp2por01ffe53dbeqq/1557842400000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-05-14 15:47:35--  https://doc-0o-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/28dcp1ql2qiol7gp2por01ffe53dbeqq/1557842400000/05348309593456850141/*/1EaXS5deWHnQsBJ_kj0CMjVG8Ip3u76Oh?e=download
# Resolving doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)... 173.194.202.132, 2607:f8b0:400e:c00::84
# Connecting to doc-0o-24-docs.googleusercontent.com (doc-0o-24-docs.googleusercontent.com)|173.194.202.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1114601 (1.1M) [application/octet-stream]
# Saving to: ‘gazetteer_PERLOC.testb’
#
#      0K .                                  100%  111M=0.01s
#
# 2019-05-14 15:47:35 (111 MB/s) - ‘gazetteer_PERLOC.testb’ saved [1114601/1114601]

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 64
LSTM_DIM = 400
CHAR_EMB_DIM = 30
KERNEL_SIZE = 4
CHAR_FILTERS = 30
DROPOUT = 0.4
RECURRENT_DROPOUT = 0.3

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(0.1), maxval=math.sqrt(0.1))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    gaze_input = Input(shape=(None, 3))

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings, gaze_input])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT
    ))(embeddings)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(3, activation='elu'))(output)
    shape = TimeDistributed(Dense(151, activation='elu'))(output)
    position = TimeDistributed(Dense(45, activation='elu'))(output)
    
    return Model(inputs=[word_input, case_input, char_input, gaze_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy],
              optimizer=SGD(lr=0.02, decay=1e-6, momentum=0.9, clipnorm=5))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    true_seqs, pred_seqs = [], []

    for batch in batches:
        target = batch['tag']
        target = target.reshape((target.shape[0], target.shape[1]))
        logits = model.predict([batch['word'], batch['case'], batch['char'], batch['gaze']], verbose=False)[0].argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in target[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in logits[seq_ind, 1: seq_len + 1]]))

    return evaluate(true_seqs, pred_seqs, verbose=False)

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char'], batch['gaze']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:107: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 43.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 54.64%, Precision = 44.64%, Recall = 49.14%
# ================================== Valid Data ==================================
# F1 = 60.44%, Precision = 46.21%, Recall = 52.38%
# ================================== Test  Data ==================================
# F1 = 53.51%, Precision = 46.05%, Recall = 49.50%
# Time: 14.82s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.20s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 68.66%, Precision = 64.57%, Recall = 66.55%
# ================================== Valid Data ==================================
# F1 = 70.79%, Precision = 65.05%, Recall = 67.80%
# ================================== Test  Data ==================================
# F1 = 68.56%, Precision = 64.87%, Recall = 66.67%
# Time: 13.36s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.04s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 69.46%, Precision = 73.64%, Recall = 71.49%
# ================================== Valid Data ==================================
# F1 = 72.17%, Precision = 75.51%, Recall = 73.81%
# ================================== Test  Data ==================================
# F1 = 68.44%, Precision = 72.77%, Recall = 70.54%
# Time: 12.99s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.98s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 72.67%, Precision = 73.68%, Recall = 73.17%
# ================================== Valid Data ==================================
# F1 = 75.46%, Precision = 75.09%, Recall = 75.28%
# ================================== Test  Data ==================================
# F1 = 71.37%, Precision = 72.11%, Recall = 71.74%
# Time: 14.08s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.82s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 76.47%, Precision = 79.53%, Recall = 77.97%
# ================================== Valid Data ==================================
# F1 = 78.29%, Precision = 80.70%, Recall = 79.47%
# ================================== Test  Data ==================================
# F1 = 74.20%, Precision = 77.64%, Recall = 75.88%
# Time: 12.94s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 80.42%, Precision = 81.37%, Recall = 80.89%
# ================================== Valid Data ==================================
# F1 = 81.42%, Precision = 81.84%, Recall = 81.63%
# ================================== Test  Data ==================================
# F1 = 77.93%, Precision = 78.95%, Recall = 78.43%
# Time: 13.92s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.10s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 81.91%, Precision = 83.08%, Recall = 82.49%
# ================================== Valid Data ==================================
# F1 = 83.16%, Precision = 83.83%, Recall = 83.49%
# ================================== Test  Data ==================================
# F1 = 79.43%, Precision = 80.93%, Recall = 80.17%
# Time: 12.90s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.08s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.33%, Precision = 83.70%, Recall = 83.01%
# ================================== Valid Data ==================================
# F1 = 83.51%, Precision = 84.21%, Recall = 83.86%
# ================================== Test  Data ==================================
# F1 = 79.66%, Precision = 81.00%, Recall = 80.33%
# Time: 13.20s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.77s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.11%, Precision = 84.99%, Recall = 83.53%
# ================================== Valid Data ==================================
# F1 = 83.63%, Precision = 85.83%, Recall = 84.72%
# ================================== Test  Data ==================================
# F1 = 79.53%, Precision = 82.83%, Recall = 81.14%
# Time: 13.14s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.54%, Precision = 85.83%, Recall = 84.67%
# ================================== Valid Data ==================================
# F1 = 84.40%, Precision = 86.32%, Recall = 85.35%
# ================================== Test  Data ==================================
# F1 = 80.79%, Precision = 83.48%, Recall = 82.11%
# Time: 12.87s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.33%, Precision = 85.80%, Recall = 84.54%
# ================================== Valid Data ==================================
# F1 = 83.93%, Precision = 85.98%, Recall = 84.94%
# ================================== Test  Data ==================================
# F1 = 80.88%, Precision = 83.29%, Recall = 82.07%
# Time: 13.58s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.65%, Precision = 86.62%, Recall = 85.63%
# ================================== Valid Data ==================================
# F1 = 85.31%, Precision = 86.49%, Recall = 85.89%
# ================================== Test  Data ==================================
# F1 = 81.41%, Precision = 83.13%, Recall = 82.26%
# Time: 12.87s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.71%, Precision = 87.68%, Recall = 86.69%
# ================================== Valid Data ==================================
# F1 = 85.62%, Precision = 87.01%, Recall = 86.31%
# ================================== Test  Data ==================================
# F1 = 82.34%, Precision = 84.22%, Recall = 83.27%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.35s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.32%, Precision = 87.48%, Recall = 86.90%
# ================================== Valid Data ==================================
# F1 = 86.36%, Precision = 87.34%, Recall = 86.85%
# ================================== Test  Data ==================================
# F1 = 83.39%, Precision = 84.42%, Recall = 83.90%
# Time: 14.19s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.02%, Precision = 87.75%, Recall = 87.38%
# ================================== Valid Data ==================================
# F1 = 87.05%, Precision = 87.02%, Recall = 87.04%
# ================================== Test  Data ==================================
# F1 = 83.82%, Precision = 84.03%, Recall = 83.93%
# Time: 13.85s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.72s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.45%, Precision = 88.37%, Recall = 87.91%
# ================================== Valid Data ==================================
# F1 = 87.20%, Precision = 87.70%, Recall = 87.45%
# ================================== Test  Data ==================================
# F1 = 84.18%, Precision = 84.86%, Recall = 84.52%
# Time: 13.03s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.18%, Precision = 89.32%, Recall = 87.72%
# ================================== Valid Data ==================================
# F1 = 86.02%, Precision = 88.62%, Recall = 87.30%
# ================================== Test  Data ==================================
# F1 = 82.10%, Precision = 86.10%, Recall = 84.05%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.76s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.81%, Precision = 88.81%, Recall = 88.81%
# ================================== Valid Data ==================================
# F1 = 88.43%, Precision = 87.83%, Recall = 88.13%
# ================================== Test  Data ==================================
# F1 = 85.12%, Precision = 84.76%, Recall = 84.94%
# Time: 12.93s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.13s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.87%, Precision = 88.76%, Recall = 88.81%
# ================================== Valid Data ==================================
# F1 = 88.20%, Precision = 87.82%, Recall = 88.01%
# ================================== Test  Data ==================================
# F1 = 85.75%, Precision = 85.36%, Recall = 85.55%
# Time: 13.23s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 24.06s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.69%, Precision = 90.19%, Recall = 88.92%
# ================================== Valid Data ==================================
# F1 = 87.48%, Precision = 89.45%, Recall = 88.45%
# ================================== Test  Data ==================================
# F1 = 83.18%, Precision = 86.42%, Recall = 84.77%
# Time: 13.15s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.94s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.13%, Precision = 89.97%, Recall = 89.55%
# ================================== Valid Data ==================================
# F1 = 88.29%, Precision = 88.61%, Recall = 88.45%
# ================================== Test  Data ==================================
# F1 = 84.62%, Precision = 86.10%, Recall = 85.35%
# Time: 12.83s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.07%, Precision = 90.29%, Recall = 89.68%
# ================================== Valid Data ==================================
# F1 = 88.50%, Precision = 89.35%, Recall = 88.92%
# ================================== Test  Data ==================================
# F1 = 84.55%, Precision = 86.21%, Recall = 85.37%
# Time: 12.83s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.64%, Precision = 90.39%, Recall = 89.51%
# ================================== Valid Data ==================================
# F1 = 88.22%, Precision = 89.60%, Recall = 88.90%
# ================================== Test  Data ==================================
# F1 = 83.51%, Precision = 86.37%, Recall = 84.92%
# Time: 12.84s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.16s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.60%, Precision = 90.18%, Recall = 89.89%
# ================================== Valid Data ==================================
# F1 = 88.80%, Precision = 89.03%, Recall = 88.92%
# ================================== Test  Data ==================================
# F1 = 84.88%, Precision = 86.21%, Recall = 85.54%
# Time: 13.26s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.79s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.03%, Precision = 91.15%, Recall = 90.59%
# ================================== Valid Data ==================================
# F1 = 89.10%, Precision = 89.82%, Recall = 89.46%
# ================================== Test  Data ==================================
# F1 = 85.10%, Precision = 86.88%, Recall = 85.98%
# Time: 12.88s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.76s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.72%, Precision = 90.24%, Recall = 90.48%
# ================================== Valid Data ==================================
# F1 = 90.02%, Precision = 89.09%, Recall = 89.55%
# ================================== Test  Data ==================================
# F1 = 85.95%, Precision = 85.59%, Recall = 85.77%
# Time: 14.12s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.24%, Precision = 90.10%, Recall = 90.67%
# ================================== Valid Data ==================================
# F1 = 90.25%, Precision = 88.77%, Recall = 89.51%
# ================================== Test  Data ==================================
# F1 = 86.82%, Precision = 85.73%, Recall = 86.27%
# Time: 13.24s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.44s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.50%, Precision = 90.88%, Recall = 91.19%
# ================================== Valid Data ==================================
# F1 = 90.62%, Precision = 89.62%, Recall = 90.12%
# ================================== Test  Data ==================================
# F1 = 86.79%, Precision = 86.42%, Recall = 86.60%
# Time: 14.50s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.71s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.17%, Precision = 91.56%, Recall = 90.86%
# ================================== Valid Data ==================================
# F1 = 89.11%, Precision = 90.31%, Recall = 89.70%
# ================================== Test  Data ==================================
# F1 = 85.10%, Precision = 87.50%, Recall = 86.29%
# Time: 13.43s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.94%, Precision = 91.39%, Recall = 91.16%
# ================================== Valid Data ==================================
# F1 = 90.10%, Precision = 90.22%, Recall = 90.16%
# ================================== Test  Data ==================================
# F1 = 86.00%, Precision = 87.11%, Recall = 86.55%
# Time: 13.35s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.59%, Precision = 91.65%, Recall = 91.62%
# ================================== Valid Data ==================================
# F1 = 90.77%, Precision = 90.24%, Recall = 90.51%
# ================================== Test  Data ==================================
# F1 = 86.59%, Precision = 87.25%, Recall = 86.92%
# Time: 14.74s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.70s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.62%, Precision = 91.74%, Recall = 91.18%
# ================================== Valid Data ==================================
# F1 = 89.87%, Precision = 90.53%, Recall = 90.20%
# ================================== Test  Data ==================================
# F1 = 86.03%, Precision = 88.10%, Recall = 87.05%
# Time: 13.17s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.42s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.87%, Precision = 91.94%, Recall = 91.41%
# ================================== Valid Data ==================================
# F1 = 90.07%, Precision = 90.66%, Recall = 90.36%
# ================================== Test  Data ==================================
# F1 = 85.97%, Precision = 88.08%, Recall = 87.01%
# Time: 12.85s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.69s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.08%, Precision = 91.56%, Recall = 91.82%
# ================================== Valid Data ==================================
# F1 = 91.11%, Precision = 90.17%, Recall = 90.64%
# ================================== Test  Data ==================================
# F1 = 87.45%, Precision = 87.23%, Recall = 87.34%
# Time: 12.81s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.88%, Precision = 91.72%, Recall = 91.80%
# ================================== Valid Data ==================================
# F1 = 90.86%, Precision = 90.37%, Recall = 90.62%
# ================================== Test  Data ==================================
# F1 = 86.78%, Precision = 87.18%, Recall = 86.98%
# Time: 13.12s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.04s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.34%, Precision = 92.19%, Recall = 91.77%
# ================================== Valid Data ==================================
# F1 = 90.27%, Precision = 90.68%, Recall = 90.47%
# ================================== Test  Data ==================================
# F1 = 86.34%, Precision = 88.26%, Recall = 87.29%
# Time: 13.72s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.42s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.56%, Precision = 92.10%, Recall = 92.33%
# ================================== Valid Data ==================================
# F1 = 91.60%, Precision = 90.68%, Recall = 91.14%
# ================================== Test  Data ==================================
# F1 = 87.52%, Precision = 87.50%, Recall = 87.51%
# Time: 14.05s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.03%, Precision = 92.57%, Recall = 92.30%
# ================================== Valid Data ==================================
# F1 = 91.00%, Precision = 91.03%, Recall = 91.01%
# ================================== Test  Data ==================================
# F1 = 86.60%, Precision = 88.10%, Recall = 87.34%
# Time: 13.03s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.75s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.52%, Precision = 92.26%, Recall = 92.39%
# ================================== Valid Data ==================================
# F1 = 91.42%, Precision = 90.71%, Recall = 91.06%
# ================================== Test  Data ==================================
# F1 = 87.52%, Precision = 87.69%, Recall = 87.61%
# Time: 13.98s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.66s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.93%, Precision = 92.55%, Recall = 92.24%
# ================================== Valid Data ==================================
# F1 = 90.89%, Precision = 91.15%, Recall = 91.02%
# ================================== Test  Data ==================================
# F1 = 86.47%, Precision = 87.92%, Recall = 87.19%
# Time: 12.88s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.45%, Precision = 91.87%, Recall = 92.16%
# ================================== Valid Data ==================================
# F1 = 91.26%, Precision = 90.31%, Recall = 90.78%
# ================================== Test  Data ==================================
# F1 = 87.44%, Precision = 87.00%, Recall = 87.22%
# Time: 13.04s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.27%, Precision = 93.20%, Recall = 92.74%
# ================================== Valid Data ==================================
# F1 = 91.07%, Precision = 91.69%, Recall = 91.38%
# ================================== Test  Data ==================================
# F1 = 86.75%, Precision = 88.76%, Recall = 87.74%
# Time: 12.84s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.76s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.12%, Precision = 92.31%, Recall = 92.72%
# ================================== Valid Data ==================================
# F1 = 91.86%, Precision = 90.59%, Recall = 91.22%
# ================================== Test  Data ==================================
# F1 = 87.82%, Precision = 87.34%, Recall = 87.58%
# Time: 12.88s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.66%, Precision = 93.12%, Recall = 92.89%
# ================================== Valid Data ==================================
# F1 = 91.44%, Precision = 91.47%, Recall = 91.45%
# ================================== Test  Data ==================================
# F1 = 87.12%, Precision = 88.65%, Recall = 87.88%
# Time: 12.87s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.78%, Precision = 93.06%, Recall = 92.92%
# ================================== Valid Data ==================================
# F1 = 91.54%, Precision = 91.45%, Recall = 91.50%
# ================================== Test  Data ==================================
# F1 = 87.17%, Precision = 88.26%, Recall = 87.71%
# Time: 12.94s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.31%, Precision = 92.77%, Recall = 93.04%
# ================================== Valid Data ==================================
# F1 = 92.03%, Precision = 91.15%, Recall = 91.59%
# ================================== Test  Data ==================================
# F1 = 88.10%, Precision = 88.00%, Recall = 88.05%
# Time: 13.53s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.46s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.85%, Precision = 93.33%, Recall = 93.09%
# ================================== Valid Data ==================================
# F1 = 91.74%, Precision = 91.80%, Recall = 91.77%
# ================================== Test  Data ==================================
# F1 = 87.39%, Precision = 88.97%, Recall = 88.17%
# Time: 13.33s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.56s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.28%, Precision = 93.03%, Recall = 93.16%
# ================================== Valid Data ==================================
# F1 = 92.04%, Precision = 91.27%, Recall = 91.65%
# ================================== Test  Data ==================================
# F1 = 87.81%, Precision = 88.10%, Recall = 87.95%
# Time: 15.47s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.49s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.33%, Precision = 92.85%, Recall = 93.09%
# ================================== Valid Data ==================================
# F1 = 92.00%, Precision = 91.16%, Recall = 91.58%
# ================================== Test  Data ==================================
# F1 = 87.85%, Precision = 87.92%, Recall = 87.89%
# Time: 13.33s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.31s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.31%, Precision = 93.16%, Recall = 93.23%
# ================================== Valid Data ==================================
# F1 = 92.06%, Precision = 91.57%, Recall = 91.82%
# ================================== Test  Data ==================================
# F1 = 87.65%, Precision = 88.05%, Recall = 87.85%
# Time: 14.53s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.56s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.76%, Precision = 93.41%, Recall = 93.59%
# ================================== Valid Data ==================================
# F1 = 92.29%, Precision = 91.62%, Recall = 91.95%
# ================================== Test  Data ==================================
# F1 = 88.11%, Precision = 88.54%, Recall = 88.33%
# Time: 13.56s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.22%, Precision = 93.43%, Recall = 93.33%
# ================================== Valid Data ==================================
# F1 = 92.00%, Precision = 91.89%, Recall = 91.94%
# ================================== Test  Data ==================================
# F1 = 87.64%, Precision = 88.97%, Recall = 88.30%
# Time: 13.26s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.66s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.07%, Precision = 93.81%, Recall = 93.44%
# ================================== Valid Data ==================================
# F1 = 91.47%, Precision = 92.04%, Recall = 91.75%
# ================================== Test  Data ==================================
# F1 = 86.88%, Precision = 89.08%, Recall = 87.96%
# Time: 13.15s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.15s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.68%, Precision = 93.81%, Recall = 93.75%
# ================================== Valid Data ==================================
# F1 = 92.30%, Precision = 92.02%, Recall = 92.16%
# ================================== Test  Data ==================================
# F1 = 87.59%, Precision = 88.56%, Recall = 88.07%
# Time: 13.32s
#
# ----------------------------------- EPOCH: 55 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.98s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.42%, Precision = 93.51%, Recall = 93.46%
# ================================== Valid Data ==================================
# F1 = 91.84%, Precision = 91.64%, Recall = 91.74%
# ================================== Test  Data ==================================
# F1 = 87.18%, Precision = 88.28%, Recall = 87.73%
# Time: 13.02s
#
# ----------------------------------- EPOCH: 56 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.65s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.47%, Precision = 93.82%, Recall = 93.64%
# ================================== Valid Data ==================================
# F1 = 91.85%, Precision = 91.99%, Recall = 91.92%
# ================================== Test  Data ==================================
# F1 = 87.43%, Precision = 88.76%, Recall = 88.09%
# Time: 12.92s
#
# ----------------------------------- EPOCH: 57 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 24.01s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.04%, Precision = 93.65%, Recall = 93.84%
# ================================== Valid Data ==================================
# F1 = 92.75%, Precision = 91.92%, Recall = 92.33%
# ================================== Test  Data ==================================
# F1 = 88.47%, Precision = 88.74%, Recall = 88.61%
# Time: 13.05s
#
# ----------------------------------- EPOCH: 58 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.88s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.37%, Precision = 93.27%, Recall = 93.82%
# ================================== Valid Data ==================================
# F1 = 92.93%, Precision = 91.13%, Recall = 92.02%
# ================================== Test  Data ==================================
# F1 = 88.83%, Precision = 87.61%, Recall = 88.22%
# Time: 12.91s
#
# ----------------------------------- EPOCH: 59 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.92s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.44%, Precision = 94.06%, Recall = 94.25%
# ================================== Valid Data ==================================
# F1 = 93.00%, Precision = 92.09%, Recall = 92.54%
# ================================== Test  Data ==================================
# F1 = 88.66%, Precision = 88.72%, Recall = 88.69%
# Time: 13.87s
#
# ----------------------------------- EPOCH: 60 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.82s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.07%, Precision = 94.03%, Recall = 94.05%
# ================================== Valid Data ==================================
# F1 = 92.27%, Precision = 92.02%, Recall = 92.15%
# ================================== Test  Data ==================================
# F1 = 88.01%, Precision = 89.02%, Recall = 88.51%
# Time: 12.88s
#
# ----------------------------------- EPOCH: 61 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.03s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.36%, Precision = 93.97%, Recall = 94.16%
# ================================== Valid Data ==================================
# F1 = 92.79%, Precision = 91.89%, Recall = 92.34%
# ================================== Test  Data ==================================
# F1 = 88.26%, Precision = 88.53%, Recall = 88.39%
# Time: 14.19s
#
# ----------------------------------- EPOCH: 62 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.83s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.26%, Precision = 94.14%, Recall = 94.20%
# ================================== Valid Data ==================================
# F1 = 92.61%, Precision = 92.11%, Recall = 92.36%
# ================================== Test  Data ==================================
# F1 = 87.93%, Precision = 88.85%, Recall = 88.38%
# Time: 12.92s
#
# ----------------------------------- EPOCH: 63 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.83s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.66%, Precision = 94.40%, Recall = 94.53%
# ================================== Valid Data ==================================
# F1 = 93.05%, Precision = 92.54%, Recall = 92.79%
# ================================== Test  Data ==================================
# F1 = 88.08%, Precision = 88.81%, Recall = 88.44%
# Time: 13.25s
#
# ----------------------------------- EPOCH: 64 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.36s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.65%, Precision = 94.22%, Recall = 94.43%
# ================================== Valid Data ==================================
# F1 = 93.01%, Precision = 92.01%, Recall = 92.50%
# ================================== Test  Data ==================================
# F1 = 88.94%, Precision = 88.86%, Recall = 88.90%
# Time: 13.12s
#
# ----------------------------------- EPOCH: 65 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.54%, Precision = 94.47%, Recall = 94.50%
# ================================== Valid Data ==================================
# F1 = 92.83%, Precision = 92.54%, Recall = 92.68%
# ================================== Test  Data ==================================
# F1 = 88.40%, Precision = 89.29%, Recall = 88.84%
# Time: 14.43s
#
# ----------------------------------- EPOCH: 66 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.34s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.95%, Precision = 94.15%, Recall = 93.55%
# ================================== Valid Data ==================================
# F1 = 90.99%, Precision = 92.31%, Recall = 91.65%
# ================================== Test  Data ==================================
# F1 = 86.71%, Precision = 89.22%, Recall = 87.95%
# Time: 13.04s
#
# ----------------------------------- EPOCH: 67 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.90s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.47%, Precision = 94.47%, Recall = 94.47%
# ================================== Valid Data ==================================
# F1 = 92.54%, Precision = 92.31%, Recall = 92.43%
# ================================== Test  Data ==================================
# F1 = 88.13%, Precision = 89.13%, Recall = 88.63%
# Time: 13.03s
#
# ----------------------------------- EPOCH: 68 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.63%, Precision = 94.84%, Recall = 94.74%
# ================================== Valid Data ==================================
# F1 = 92.78%, Precision = 92.81%, Recall = 92.80%
# ================================== Test  Data ==================================
# F1 = 88.05%, Precision = 89.34%, Recall = 88.69%
# Time: 13.07s
#
# ----------------------------------- EPOCH: 69 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.83s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.69%, Precision = 95.03%, Recall = 94.86%
# ================================== Valid Data ==================================
# F1 = 92.67%, Precision = 92.93%, Recall = 92.80%
# ================================== Test  Data ==================================
# F1 = 87.75%, Precision = 89.39%, Recall = 88.56%
# Time: 12.99s
#
# ----------------------------------- EPOCH: 70 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.79%, Precision = 94.96%, Recall = 94.87%
# ================================== Valid Data ==================================
# F1 = 92.58%, Precision = 92.66%, Recall = 92.62%
# ================================== Test  Data ==================================
# F1 = 87.98%, Precision = 89.27%, Recall = 88.62%
# Time: 14.11s
#
# ----------------------------------- EPOCH: 71 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 95.47%, Precision = 94.26%, Recall = 94.86%
# ================================== Valid Data ==================================
# F1 = 93.54%, Precision = 91.89%, Recall = 92.71%
# ================================== Test  Data ==================================
# F1 = 89.83%, Precision = 88.39%, Recall = 89.10%
# Time: 13.09s
#
# ----------------------------------- EPOCH: 72 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.77s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.79%, Precision = 94.68%, Recall = 94.73%
# ================================== Valid Data ==================================
# F1 = 93.16%, Precision = 92.85%, Recall = 93.00%
# ...
# F1 = 90.09%, Precision = 90.47%, Recall = 90.28%
# Time: 12.71s
#
# ----------------------------------- EPOCH: 680 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.59s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.88%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.62%, Precision = 94.33%, Recall = 94.47%
# ================================== Test  Data ==================================
# F1 = 90.07%, Precision = 90.39%, Recall = 90.23%
# Time: 13.90s
#
# ----------------------------------- EPOCH: 681 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.55s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.91%, Precision = 99.89%, Recall = 99.90%
# ================================== Valid Data ==================================
# F1 = 94.90%, Precision = 94.21%, Recall = 94.55%
# ================================== Test  Data ==================================
# F1 = 90.57%, Precision = 90.10%, Recall = 90.33%
# Time: 12.81s
#
# ----------------------------------- EPOCH: 682 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.58s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.81%, Precision = 99.89%, Recall = 99.85%
# ================================== Valid Data ==================================
# F1 = 94.23%, Precision = 94.75%, Recall = 94.49%
# ================================== Test  Data ==================================
# F1 = 88.92%, Precision = 90.53%, Recall = 89.72%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 683 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.86%, Precision = 99.87%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 94.26%, Recall = 94.44%
# ================================== Test  Data ==================================
# F1 = 90.09%, Precision = 90.17%, Recall = 90.13%
# Time: 12.76s
#
# ----------------------------------- EPOCH: 684 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.84%, Precision = 99.91%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.22%, Precision = 94.67%, Recall = 94.44%
# ================================== Test  Data ==================================
# F1 = 88.99%, Precision = 90.56%, Recall = 89.77%
# Time: 12.69s
#
# ----------------------------------- EPOCH: 685 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.89%, Precision = 99.89%, Recall = 99.89%
# ================================== Valid Data ==================================
# F1 = 94.75%, Precision = 94.41%, Recall = 94.58%
# ================================== Test  Data ==================================
# F1 = 90.32%, Precision = 90.21%, Recall = 90.26%
# Time: 12.70s
#
# ----------------------------------- EPOCH: 686 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.88%, Precision = 99.89%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 94.63%, Recall = 94.63%
# ================================== Test  Data ==================================
# F1 = 90.02%, Precision = 90.53%, Recall = 90.27%
# Time: 12.77s
#
# ----------------------------------- EPOCH: 687 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.53s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.87%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.69%, Precision = 94.23%, Recall = 94.46%
# ================================== Test  Data ==================================
# F1 = 90.47%, Precision = 90.23%, Recall = 90.35%
# Time: 12.71s
#
# ----------------------------------- EPOCH: 688 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.49s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.86%, Precision = 99.89%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.37%, Precision = 94.48%, Recall = 94.42%
# ================================== Test  Data ==================================
# F1 = 89.68%, Precision = 90.47%, Recall = 90.08%
# Time: 12.68s
#
# ----------------------------------- EPOCH: 689 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.60s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.89%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.60%, Precision = 94.68%, Recall = 94.64%
# ================================== Test  Data ==================================
# F1 = 89.83%, Precision = 90.56%, Recall = 90.20%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 690 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.47s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.87%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.78%, Precision = 94.36%, Recall = 94.57%
# ================================== Test  Data ==================================
# F1 = 89.89%, Precision = 89.91%, Recall = 89.90%
# Time: 12.74s
#
# ----------------------------------- EPOCH: 691 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.49s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.88%, Precision = 99.89%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.60%, Precision = 94.41%, Recall = 94.51%
# ================================== Test  Data ==================================
# F1 = 89.96%, Precision = 90.28%, Recall = 90.12%
# Time: 13.59s
#
# ----------------------------------- EPOCH: 692 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.85s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.87%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.87%, Precision = 94.36%, Recall = 94.62%
# ================================== Test  Data ==================================
# F1 = 90.61%, Precision = 90.23%, Recall = 90.42%
# Time: 12.80s
#
# ----------------------------------- EPOCH: 693 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.86%, Precision = 99.86%, Recall = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.63%, Precision = 94.23%, Recall = 94.43%
# ================================== Test  Data ==================================
# F1 = 90.52%, Precision = 89.96%, Recall = 90.24%
# Time: 12.77s
#
# ----------------------------------- EPOCH: 694 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.14s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.88%, Recall = 99.87%
# ================================== Valid Data ==================================
# F1 = 94.61%, Precision = 94.19%, Recall = 94.40%
# ================================== Test  Data ==================================
# F1 = 90.19%, Precision = 90.14%, Recall = 90.16%
# Time: 12.74s
#
# ----------------------------------- EPOCH: 695 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.87%, Precision = 99.89%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.41%, Precision = 94.41%, Recall = 94.41%
# ================================== Test  Data ==================================
# F1 = 89.87%, Precision = 90.37%, Recall = 90.12%
# Time: 13.43s
#
# ----------------------------------- EPOCH: 696 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 23.12s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.89%, Precision = 99.89%, Recall = 99.89%
# ================================== Valid Data ==================================
# F1 = 94.88%, Precision = 94.16%, Recall = 94.52%
# ================================== Test  Data ==================================
# F1 = 90.44%, Precision = 89.98%, Recall = 90.21%
# Time: 12.73s
#
# ----------------------------------- EPOCH: 697 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.86%, Precision = 99.86%, Recall = 99.86%
# ================================== Valid Data ==================================
# F1 = 94.74%, Precision = 94.61%, Recall = 94.68%
# ================================== Test  Data ==================================
# F1 = 90.28%, Precision = 90.40%, Recall = 90.34%
# Time: 12.74s
#
# ----------------------------------- EPOCH: 698 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.70s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.88%, Precision = 99.88%, Recall = 99.88%
# ================================== Valid Data ==================================
# F1 = 94.72%, Precision = 94.55%, Recall = 94.63%
# ================================== Test  Data ==================================
# F1 = 90.14%, Precision = 90.28%, Recall = 90.21%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 699 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.89%, Precision = 99.90%, Recall = 99.90%
# ================================== Valid Data ==================================
# F1 = 94.73%, Precision = 94.63%, Recall = 94.68%
# ================================== Test  Data ==================================
# F1 = 90.28%, Precision = 90.32%, Recall = 90.30%
# Time: 12.79s
#
# ----------------------------------- EPOCH: 700 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 22.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.89%, Precision = 99.89%, Recall = 99.89%
# ================================== Valid Data ==================================
# F1 = 94.88%, Precision = 94.50%, Recall = 94.69%
# ================================== Test  Data ==================================
# F1 = 90.52%, Precision = 90.14%, Recall = 90.33%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 701 -----------------------------------
# ----------------------------------- Training -----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-26a4934affb7> in <module>()
#       8
#       9     for batch in train_batches:
# ---> 10         model.train_on_batch([batch['word'], batch['case'], batch['char'], batch['gaze']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
#      11
#      12     finish_time = time.time()
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# 90.96 -- эпоха 571
