# %%
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/conlleval.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/utils.py
# !wget -qq https://raw.githubusercontent.com/svinkapeppa/trash/master/install
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %%
# !chmod 777 install
# !./install

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, Flatten, concatenate
from keras.initializers import RandomUniform
from keras.optimizers import SGD
from keras.losses import sparse_categorical_crossentropy
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss

import utils
import random
import time
import math
import pickle
# Out:
# Using TensorFlow backend.

# %%
NUM_EPOCHS = 10000
BATCH_SIZE = 32
LSTM_DIM = 300
CHAR_EMB_DIM = 25
KERNEL_SIZE = 3
CHAR_FILTERS = 25
DROPOUT = 0.5
RECURRENT_DROPOUT = 0.5

# %%
with open('features/all_onehot.train', 'rb') as f:
    features_train = pickle.load(f)
with open('features/all_onehot.testa', 'rb') as f:
    features_dev = pickle.load(f)
with open('features/all_onehot.testb', 'rb') as f:
    features_test = pickle.load(f)

# %%
with open('features/gazetteer_PERLOC.train', 'rb') as f:
    gaze_train = pickle.load(f)
with open('features/gazetteer_PERLOC.testa', 'rb') as f:
    gaze_dev = pickle.load(f)
with open('features/gazetteer_PERLOC.testb', 'rb') as f:
    gaze_test = pickle.load(f)

# %%
train_sentences = utils.read_sentences('data/train')
valid_sentences = utils.read_sentences('data/valid')
test_sentences = utils.read_sentences('data/test')

print('Number of TRAIN sentences: {}'.format(len(train_sentences)))
print('Number of VALID sentences: {}'.format(len(valid_sentences)))
print('Number of TEST sentences: {}'.format(len(test_sentences)))
# Out:
# Number of TRAIN sentences: 14041
# Number of VALID sentences: 3250
# Number of TEST sentences: 3453

# %%
utils.convert_tags(train_sentences)
utils.convert_tags(valid_sentences)
utils.convert_tags(test_sentences)

# %%
tag_idx, idx_tag = utils.create_tag_mapping([train_sentences, valid_sentences, test_sentences])

# %%
word_idx, idx_word, word_embeddings = utils.create_word_mapping('glove/glove.6B.300d.txt')

# %%
char_idx, idx_char = utils.create_char_mapping([train_sentences, valid_sentences, test_sentences])

# %%
case_idx, case_embeddings = utils.create_case_mapping()

# %%
max_word_length = utils.get_max_word_length([train_sentences, valid_sentences, test_sentences])

# %%
utils.add_auxiliary_information(train_sentences)
utils.add_auxiliary_information(valid_sentences)
utils.add_auxiliary_information(test_sentences)

# %%
train_batches = utils.create_batches(train_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_train, gaze_train)
valid_batches = utils.create_batches(valid_sentences, BATCH_SIZE, max_word_length, word_idx,
                                     char_idx, tag_idx, features_dev, gaze_dev)
test_batches = utils.create_batches(test_sentences, BATCH_SIZE, max_word_length, word_idx,
                                    char_idx, tag_idx, features_test, gaze_test)

# %%
def CharCNNBiLSTM(word_vocab_size, case_vocab_size, char_vocab_size,
                  word_embeddings_dim, case_embeddings_dim, max_word_length,
                  word_embeddings, case_embeddings, tag_set_size):
    word_input = Input(shape=(None,))
    word_embeddings = Embedding(
        word_vocab_size, word_embeddings_dim, weights=[word_embeddings], trainable=True
    )(word_input)

    case_input = Input(shape=(None,))
    case_embeddings = Embedding(
        case_vocab_size, case_embeddings_dim, weights=[case_embeddings], trainable=True
    )(case_input)
    
    char_input = Input(shape=(None, max_word_length))
    char_embeddings = TimeDistributed(Embedding(
        char_vocab_size, CHAR_EMB_DIM, embeddings_initializer=RandomUniform(minval=-math.sqrt(0.1), maxval=math.sqrt(0.1))
    ))(char_input)
    char_embeddings = Dropout(DROPOUT)(char_embeddings)
    char_embeddings = TimeDistributed(Conv1D(
        kernel_size=KERNEL_SIZE, filters=CHAR_FILTERS, padding='same', activation='tanh', strides=1
    ))(char_embeddings)
    char_embeddings = TimeDistributed(MaxPooling1D(max_word_length))(char_embeddings)
    char_embeddings = TimeDistributed(Flatten())(char_embeddings)

    embeddings = concatenate([word_embeddings, case_embeddings, char_embeddings])
    embeddings = Dropout(DROPOUT)(embeddings)
    
    output = Bidirectional(LSTM(
        LSTM_DIM, return_sequences=True, dropout=DROPOUT, recurrent_dropout=RECURRENT_DROPOUT
    ))(embeddings)

    lstm = TimeDistributed(Dense(LSTM_DIM, activation='elu'))(output)
    lstm = CRF(tag_set_size, sparse_target=True)(lstm)
    gaze = TimeDistributed(Dense(3, activation='elu'))(output)
    shape = TimeDistributed(Dense(151, activation='elu'))(output)
    position = TimeDistributed(Dense(45, activation='elu'))(output)
    
    return Model(inputs=[word_input, case_input, char_input], outputs=[lstm, gaze, shape, position])

# %%
model = CharCNNBiLSTM(len(word_idx), len(case_idx), len(char_idx),
              len(word_embeddings[0]), len(case_idx), max_word_length,
              word_embeddings, case_embeddings, len(tag_idx))
model.compile(loss=[crf_loss, utils.weighted_sparse_categorical_crossentropy, sparse_categorical_crossentropy, sparse_categorical_crossentropy], optimizer=SGD(lr=0.015, decay=1e-6, momentum=0.9, clipnorm=5))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
from conlleval import evaluate


def evaluate_model(model, batches, idx_tag):
    true_seqs, pred_seqs = [], []

    for batch in batches:
        target = batch['tag']
        target = target.reshape((target.shape[0], target.shape[1]))
        logits = model.predict([batch['word'], batch['case'], batch['char']], verbose=False)[0].argmax(axis=-1)

        for seq_ind, seq_len in enumerate(batch['lengths']):
            true_seqs.append(' '.join([idx_tag[ind.item()] for ind in target[seq_ind, 1: seq_len + 1]]))
            pred_seqs.append(' '.join([idx_tag[ind.item()] for ind in logits[seq_ind, 1: seq_len + 1]]))

    return evaluate(true_seqs, pred_seqs, verbose=False)

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    random.shuffle(train_batches)
    
    print('----------------------------------- EPOCH: {} -----------------------------------'.format(epoch))
    print('----------------------------------- Training -----------------------------------')
    
    start_time = time.time()

    for batch in train_batches:
        model.train_on_batch([batch['word'], batch['case'], batch['char']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
    
    finish_time = time.time()
    
    print('Time: {:.2f}s'.format(finish_time - start_time))
    
    print('---------------------------------- Evaluating ----------------------------------')
    
    start_time = time.time()
    
    f, precision, recall = evaluate_model(model, train_batches, idx_tag)
    
    print('================================== Train Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, valid_batches, idx_tag)
    
    print('================================== Valid Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    f, precision, recall = evaluate_model(model, test_batches, idx_tag)
    
    print('================================== Test  Data ==================================')
    print('F1 = {:.2f}%, Precision = {:.2f}%, Recall = {:.2f}%'.format(f, precision, recall))
    
    finish_time = time.time()
    
    print('Time: {:.2f}s\n'.format(finish_time - start_time))
# Out:
# ----------------------------------- EPOCH: 1 -----------------------------------
# ----------------------------------- Training -----------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:107: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 120000600 elements. This may consume a large amount of memory.
#   num_elements)
# Time: 61.88s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 53.30%, Precision = 36.72%, Recall = 43.48%
# ================================== Valid Data ==================================
# F1 = 60.86%, Precision = 39.28%, Recall = 47.74%
# ================================== Test  Data ==================================
# F1 = 55.19%, Precision = 39.43%, Recall = 46.00%
# Time: 14.53s
#
# ----------------------------------- EPOCH: 2 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 63.53%, Precision = 64.37%, Recall = 63.94%
# ================================== Valid Data ==================================
# F1 = 67.34%, Precision = 66.31%, Recall = 66.82%
# ================================== Test  Data ==================================
# F1 = 63.34%, Precision = 64.73%, Recall = 64.03%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 3 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.11s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 65.35%, Precision = 71.56%, Recall = 68.31%
# ================================== Valid Data ==================================
# F1 = 69.05%, Precision = 74.03%, Recall = 71.45%
# ================================== Test  Data ==================================
# F1 = 64.76%, Precision = 70.98%, Recall = 67.73%
# Time: 13.63s
#
# ----------------------------------- EPOCH: 4 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.79s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 71.64%, Precision = 75.71%, Recall = 73.61%
# ================================== Valid Data ==================================
# F1 = 74.90%, Precision = 77.38%, Recall = 76.12%
# ================================== Test  Data ==================================
# F1 = 69.77%, Precision = 73.64%, Recall = 71.65%
# Time: 14.12s
#
# ----------------------------------- EPOCH: 5 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 75.10%, Precision = 79.70%, Recall = 77.33%
# ================================== Valid Data ==================================
# F1 = 77.02%, Precision = 80.53%, Recall = 78.73%
# ================================== Test  Data ==================================
# F1 = 71.62%, Precision = 76.75%, Recall = 74.10%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 6 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 78.23%, Precision = 81.71%, Recall = 79.93%
# ================================== Valid Data ==================================
# F1 = 79.49%, Precision = 82.38%, Recall = 80.91%
# ================================== Test  Data ==================================
# F1 = 75.67%, Precision = 79.50%, Recall = 77.53%
# Time: 13.68s
#
# ----------------------------------- EPOCH: 7 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.12s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 78.67%, Precision = 82.74%, Recall = 80.65%
# ================================== Valid Data ==================================
# F1 = 79.06%, Precision = 83.00%, Recall = 80.99%
# ================================== Test  Data ==================================
# F1 = 74.72%, Precision = 78.97%, Recall = 76.78%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 8 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.75s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.41%, Precision = 83.18%, Recall = 82.79%
# ================================== Valid Data ==================================
# F1 = 82.63%, Precision = 83.34%, Recall = 82.98%
# ================================== Test  Data ==================================
# F1 = 79.24%, Precision = 80.51%, Recall = 79.87%
# Time: 14.02s
#
# ----------------------------------- EPOCH: 9 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.76s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.89%, Precision = 83.67%, Recall = 83.78%
# ================================== Valid Data ==================================
# F1 = 84.56%, Precision = 83.76%, Recall = 84.16%
# ================================== Test  Data ==================================
# F1 = 80.75%, Precision = 80.45%, Recall = 80.60%
# Time: 13.60s
#
# ----------------------------------- EPOCH: 10 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.10s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 82.99%, Precision = 86.15%, Recall = 84.54%
# ================================== Valid Data ==================================
# F1 = 83.24%, Precision = 86.17%, Recall = 84.68%
# ================================== Test  Data ==================================
# F1 = 79.90%, Precision = 83.36%, Recall = 81.59%
# Time: 13.61s
#
# ----------------------------------- EPOCH: 11 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.85s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.36%, Precision = 85.94%, Recall = 85.14%
# ================================== Valid Data ==================================
# F1 = 84.47%, Precision = 85.88%, Recall = 85.17%
# ================================== Test  Data ==================================
# F1 = 81.69%, Precision = 82.93%, Recall = 82.31%
# Time: 13.89s
#
# ----------------------------------- EPOCH: 12 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.48s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 84.42%, Precision = 87.11%, Recall = 85.75%
# ================================== Valid Data ==================================
# F1 = 84.89%, Precision = 86.60%, Recall = 85.74%
# ================================== Test  Data ==================================
# F1 = 80.82%, Precision = 83.66%, Recall = 82.22%
# Time: 13.64s
#
# ----------------------------------- EPOCH: 13 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.73s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 83.65%, Precision = 86.96%, Recall = 85.27%
# ================================== Valid Data ==================================
# F1 = 84.14%, Precision = 87.02%, Recall = 85.56%
# ================================== Test  Data ==================================
# F1 = 79.91%, Precision = 83.53%, Recall = 81.68%
# Time: 13.52s
#
# ----------------------------------- EPOCH: 14 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.29s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.23%, Precision = 86.74%, Recall = 85.98%
# ================================== Valid Data ==================================
# F1 = 85.47%, Precision = 86.59%, Recall = 86.02%
# ================================== Test  Data ==================================
# F1 = 81.77%, Precision = 83.30%, Recall = 82.53%
# Time: 14.35s
#
# ----------------------------------- EPOCH: 15 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.39%, Precision = 85.71%, Recall = 85.55%
# ================================== Valid Data ==================================
# F1 = 85.27%, Precision = 85.36%, Recall = 85.32%
# ================================== Test  Data ==================================
# F1 = 83.03%, Precision = 82.79%, Recall = 82.91%
# Time: 14.17s
#
# ----------------------------------- EPOCH: 16 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.48s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.01%, Precision = 88.29%, Recall = 87.13%
# ================================== Valid Data ==================================
# F1 = 86.08%, Precision = 87.82%, Recall = 86.94%
# ================================== Test  Data ==================================
# F1 = 82.05%, Precision = 84.88%, Recall = 83.44%
# Time: 13.55s
#
# ----------------------------------- EPOCH: 17 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.95s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.43%, Precision = 88.35%, Recall = 87.89%
# ================================== Valid Data ==================================
# F1 = 87.23%, Precision = 87.82%, Recall = 87.52%
# ================================== Test  Data ==================================
# F1 = 83.74%, Precision = 84.83%, Recall = 84.28%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 18 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 86.62%, Precision = 88.31%, Recall = 87.46%
# ================================== Valid Data ==================================
# F1 = 86.57%, Precision = 87.90%, Recall = 87.23%
# ================================== Test  Data ==================================
# F1 = 82.58%, Precision = 84.37%, Recall = 83.46%
# Time: 13.78s
#
# ----------------------------------- EPOCH: 19 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.18%, Precision = 89.02%, Recall = 88.60%
# ================================== Valid Data ==================================
# F1 = 87.76%, Precision = 88.35%, Recall = 88.06%
# ================================== Test  Data ==================================
# F1 = 84.33%, Precision = 85.48%, Recall = 84.90%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 20 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.68s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 85.82%, Precision = 88.29%, Recall = 87.04%
# ================================== Valid Data ==================================
# F1 = 85.76%, Precision = 87.87%, Recall = 86.80%
# ================================== Test  Data ==================================
# F1 = 82.02%, Precision = 84.92%, Recall = 83.44%
# Time: 13.52s
#
# ----------------------------------- EPOCH: 21 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.43%, Precision = 89.28%, Recall = 88.85%
# ================================== Valid Data ==================================
# F1 = 87.78%, Precision = 88.64%, Recall = 88.21%
# ================================== Test  Data ==================================
# F1 = 84.59%, Precision = 85.52%, Recall = 85.05%
# Time: 13.53s
#
# ----------------------------------- EPOCH: 22 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.33s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 87.86%, Precision = 89.55%, Recall = 88.70%
# ================================== Valid Data ==================================
# F1 = 87.78%, Precision = 89.01%, Recall = 88.39%
# ================================== Test  Data ==================================
# F1 = 83.18%, Precision = 85.43%, Recall = 84.29%
# Time: 14.14s
#
# ----------------------------------- EPOCH: 23 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.32s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.03%, Precision = 89.40%, Recall = 88.71%
# ================================== Valid Data ==================================
# F1 = 87.92%, Precision = 89.08%, Recall = 88.50%
# ================================== Test  Data ==================================
# F1 = 83.56%, Precision = 85.46%, Recall = 84.50%
# Time: 13.96s
#
# ----------------------------------- EPOCH: 24 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.89s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.92%, Precision = 89.17%, Recall = 89.54%
# ================================== Valid Data ==================================
# F1 = 89.58%, Precision = 88.42%, Recall = 89.00%
# ================================== Test  Data ==================================
# F1 = 85.08%, Precision = 84.42%, Recall = 84.75%
# Time: 13.53s
#
# ----------------------------------- EPOCH: 25 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.32%, Precision = 90.23%, Recall = 89.77%
# ================================== Valid Data ==================================
# F1 = 88.81%, Precision = 89.40%, Recall = 89.11%
# ================================== Test  Data ==================================
# F1 = 85.14%, Precision = 86.70%, Recall = 85.91%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 26 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.26s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.08%, Precision = 89.92%, Recall = 89.50%
# ================================== Valid Data ==================================
# F1 = 88.38%, Precision = 89.13%, Recall = 88.75%
# ================================== Test  Data ==================================
# F1 = 84.56%, Precision = 85.80%, Recall = 85.17%
# Time: 13.58s
#
# ----------------------------------- EPOCH: 27 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.99s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.31%, Precision = 90.39%, Recall = 89.84%
# ================================== Valid Data ==================================
# F1 = 88.92%, Precision = 89.55%, Recall = 89.23%
# ================================== Test  Data ==================================
# F1 = 84.63%, Precision = 85.80%, Recall = 85.21%
# Time: 13.51s
#
# ----------------------------------- EPOCH: 28 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.75s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.33%, Precision = 90.06%, Recall = 89.19%
# ================================== Valid Data ==================================
# F1 = 87.85%, Precision = 89.35%, Recall = 88.59%
# ================================== Test  Data ==================================
# F1 = 83.99%, Precision = 86.10%, Recall = 85.03%
# Time: 13.61s
#
# ----------------------------------- EPOCH: 29 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.54s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.26%, Precision = 90.96%, Recall = 90.61%
# ================================== Valid Data ==================================
# F1 = 89.78%, Precision = 90.02%, Recall = 89.90%
# ================================== Test  Data ==================================
# F1 = 85.23%, Precision = 86.61%, Recall = 85.91%
# Time: 14.15s
#
# ----------------------------------- EPOCH: 30 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.08%, Precision = 90.46%, Recall = 89.76%
# ================================== Valid Data ==================================
# F1 = 88.53%, Precision = 89.62%, Recall = 89.07%
# ================================== Test  Data ==================================
# F1 = 84.42%, Precision = 86.44%, Recall = 85.42%
# Time: 13.57s
#
# ----------------------------------- EPOCH: 31 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.38%, Precision = 90.43%, Recall = 89.39%
# ================================== Valid Data ==================================
# F1 = 88.10%, Precision = 89.84%, Recall = 88.96%
# ================================== Test  Data ==================================
# F1 = 84.00%, Precision = 86.76%, Recall = 85.36%
# Time: 13.51s
#
# ----------------------------------- EPOCH: 32 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.60%, Precision = 90.75%, Recall = 90.17%
# ================================== Valid Data ==================================
# F1 = 89.11%, Precision = 89.80%, Recall = 89.46%
# ================================== Test  Data ==================================
# F1 = 84.73%, Precision = 86.35%, Recall = 85.53%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 33 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.18s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.08%, Precision = 90.19%, Recall = 89.63%
# ================================== Valid Data ==================================
# F1 = 88.69%, Precision = 89.48%, Recall = 89.08%
# ================================== Test  Data ==================================
# F1 = 84.13%, Precision = 85.89%, Recall = 85.00%
# Time: 13.54s
#
# ----------------------------------- EPOCH: 34 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.13s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 88.86%, Precision = 89.89%, Recall = 89.37%
# ================================== Valid Data ==================================
# F1 = 88.44%, Precision = 89.09%, Recall = 88.77%
# ================================== Test  Data ==================================
# F1 = 83.65%, Precision = 85.25%, Recall = 84.44%
# Time: 13.55s
#
# ----------------------------------- EPOCH: 35 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.82s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.16%, Precision = 91.34%, Recall = 90.75%
# ================================== Valid Data ==================================
# F1 = 89.58%, Precision = 90.26%, Recall = 89.92%
# ================================== Test  Data ==================================
# F1 = 85.26%, Precision = 86.97%, Recall = 86.11%
# Time: 13.53s
#
# ----------------------------------- EPOCH: 36 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.99s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.68%, Precision = 91.68%, Recall = 90.67%
# ================================== Valid Data ==================================
# F1 = 88.95%, Precision = 90.46%, Recall = 89.70%
# ================================== Test  Data ==================================
# F1 = 84.33%, Precision = 87.18%, Recall = 85.73%
# Time: 14.17s
#
# ----------------------------------- EPOCH: 37 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.27s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.35%, Precision = 90.41%, Recall = 90.38%
# ================================== Valid Data ==================================
# F1 = 89.88%, Precision = 89.53%, Recall = 89.71%
# ================================== Test  Data ==================================
# F1 = 84.58%, Precision = 85.20%, Recall = 84.89%
# Time: 13.51s
#
# ----------------------------------- EPOCH: 38 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.09%, Precision = 91.52%, Recall = 91.31%
# ================================== Valid Data ==================================
# F1 = 90.63%, Precision = 90.54%, Recall = 90.59%
# ================================== Test  Data ==================================
# F1 = 86.35%, Precision = 87.34%, Recall = 86.84%
# Time: 13.54s
#
# ----------------------------------- EPOCH: 39 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.82s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 89.97%, Precision = 91.26%, Recall = 90.61%
# ================================== Valid Data ==================================
# F1 = 89.20%, Precision = 90.21%, Recall = 89.70%
# ================================== Test  Data ==================================
# F1 = 84.50%, Precision = 86.47%, Recall = 85.47%
# Time: 14.04s
#
# ----------------------------------- EPOCH: 40 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.37%, Precision = 90.91%, Recall = 91.14%
# ================================== Valid Data ==================================
# F1 = 90.72%, Precision = 89.87%, Recall = 90.29%
# ================================== Test  Data ==================================
# F1 = 86.42%, Precision = 86.17%, Recall = 86.29%
# Time: 13.52s
#
# ----------------------------------- EPOCH: 41 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.09s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.05%, Precision = 90.31%, Recall = 90.18%
# ================================== Valid Data ==================================
# F1 = 89.59%, Precision = 89.63%, Recall = 89.61%
# ================================== Test  Data ==================================
# F1 = 85.42%, Precision = 86.30%, Recall = 85.86%
# Time: 14.38s
#
# ----------------------------------- EPOCH: 42 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.03s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.87%, Precision = 92.53%, Recall = 92.20%
# ================================== Valid Data ==================================
# F1 = 90.81%, Precision = 91.27%, Recall = 91.04%
# ================================== Test  Data ==================================
# F1 = 86.52%, Precision = 87.69%, Recall = 87.10%
# Time: 13.50s
#
# ----------------------------------- EPOCH: 43 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.41%, Precision = 91.09%, Recall = 91.25%
# ================================== Valid Data ==================================
# F1 = 90.73%, Precision = 89.82%, Recall = 90.27%
# ================================== Test  Data ==================================
# F1 = 85.82%, Precision = 86.15%, Recall = 85.99%
# Time: 14.21s
#
# ----------------------------------- EPOCH: 44 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 90.93%, Precision = 91.02%, Recall = 90.97%
# ================================== Valid Data ==================================
# F1 = 89.90%, Precision = 89.89%, Recall = 89.89%
# ================================== Test  Data ==================================
# F1 = 85.72%, Precision = 85.87%, Recall = 85.80%
# Time: 13.50s
#
# ----------------------------------- EPOCH: 45 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.48%, Precision = 91.57%, Recall = 91.53%
# ================================== Valid Data ==================================
# F1 = 90.79%, Precision = 90.29%, Recall = 90.54%
# ================================== Test  Data ==================================
# F1 = 86.65%, Precision = 86.90%, Recall = 86.78%
# Time: 13.50s
#
# ----------------------------------- EPOCH: 46 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.51s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.30%, Precision = 92.52%, Recall = 92.41%
# ================================== Valid Data ==================================
# F1 = 91.24%, Precision = 91.03%, Recall = 91.14%
# ================================== Test  Data ==================================
# F1 = 87.20%, Precision = 88.14%, Recall = 87.66%
# Time: 13.66s
#
# ----------------------------------- EPOCH: 47 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.89s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.24%, Precision = 92.36%, Recall = 92.30%
# ================================== Valid Data ==================================
# F1 = 91.10%, Precision = 91.11%, Recall = 91.11%
# ================================== Test  Data ==================================
# F1 = 86.64%, Precision = 87.48%, Recall = 87.06%
# Time: 13.49s
#
# ----------------------------------- EPOCH: 48 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.89%, Precision = 92.67%, Recall = 92.28%
# ================================== Valid Data ==================================
# F1 = 90.99%, Precision = 91.48%, Recall = 91.24%
# ================================== Test  Data ==================================
# F1 = 86.07%, Precision = 87.62%, Recall = 86.84%
# Time: 13.49s
#
# ----------------------------------- EPOCH: 49 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.46%, Precision = 92.47%, Recall = 92.46%
# ================================== Valid Data ==================================
# F1 = 91.20%, Precision = 90.91%, Recall = 91.06%
# ================================== Test  Data ==================================
# F1 = 87.21%, Precision = 87.78%, Recall = 87.50%
# Time: 13.49s
#
# ----------------------------------- EPOCH: 50 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.57%, Precision = 93.00%, Recall = 92.79%
# ================================== Valid Data ==================================
# F1 = 91.29%, Precision = 91.52%, Recall = 91.40%
# ================================== Test  Data ==================================
# F1 = 86.76%, Precision = 87.85%, Recall = 87.31%
# Time: 14.11s
#
# ----------------------------------- EPOCH: 51 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.04%, Precision = 92.52%, Recall = 92.28%
# ================================== Valid Data ==================================
# F1 = 90.87%, Precision = 90.96%, Recall = 90.92%
# ================================== Test  Data ==================================
# F1 = 86.60%, Precision = 87.41%, Recall = 87.00%
# Time: 13.53s
#
# ----------------------------------- EPOCH: 52 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.90%, Precision = 92.64%, Recall = 92.27%
# ================================== Valid Data ==================================
# F1 = 90.60%, Precision = 91.11%, Recall = 90.85%
# ================================== Test  Data ==================================
# F1 = 86.60%, Precision = 88.08%, Recall = 87.33%
# Time: 13.62s
#
# ----------------------------------- EPOCH: 53 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.38s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.26%, Precision = 92.69%, Recall = 92.48%
# ================================== Valid Data ==================================
# F1 = 91.08%, Precision = 91.25%, Recall = 91.16%
# ================================== Test  Data ==================================
# F1 = 86.76%, Precision = 87.73%, Recall = 87.24%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 54 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.05%, Precision = 91.91%, Recall = 92.48%
# ================================== Valid Data ==================================
# F1 = 91.81%, Precision = 90.39%, Recall = 91.10%
# ================================== Test  Data ==================================
# F1 = 87.46%, Precision = 86.84%, Recall = 87.15%
# Time: 13.48s
#
# ----------------------------------- EPOCH: 55 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.55s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.07%, Precision = 92.64%, Recall = 92.36%
# ================================== Valid Data ==================================
# F1 = 90.94%, Precision = 91.40%, Recall = 91.17%
# ================================== Test  Data ==================================
# F1 = 86.18%, Precision = 87.45%, Recall = 86.81%
# Time: 13.80s
#
# ----------------------------------- EPOCH: 56 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.61s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.99%, Precision = 92.40%, Recall = 92.19%
# ================================== Valid Data ==================================
# F1 = 90.48%, Precision = 90.68%, Recall = 90.58%
# ================================== Test  Data ==================================
# F1 = 86.92%, Precision = 87.85%, Recall = 87.38%
# Time: 13.50s
#
# ----------------------------------- EPOCH: 57 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 42.84s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.66%, Precision = 92.79%, Recall = 92.22%
# ================================== Valid Data ==================================
# F1 = 90.41%, Precision = 91.06%, Recall = 90.74%
# ================================== Test  Data ==================================
# F1 = 85.18%, Precision = 87.34%, Recall = 86.25%
# Time: 13.95s
#
# ----------------------------------- EPOCH: 58 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.97s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.26%, Precision = 92.70%, Recall = 92.48%
# ================================== Valid Data ==================================
# F1 = 91.05%, Precision = 91.08%, Recall = 91.07%
# ================================== Test  Data ==================================
# F1 = 86.69%, Precision = 87.68%, Recall = 87.18%
# Time: 13.47s
#
# ----------------------------------- EPOCH: 59 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.64s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.17%, Precision = 92.68%, Recall = 92.43%
# ================================== Valid Data ==================================
# F1 = 90.71%, Precision = 90.83%, Recall = 90.77%
# ================================== Test  Data ==================================
# F1 = 86.21%, Precision = 87.57%, Recall = 86.89%
# Time: 13.46s
#
# ----------------------------------- EPOCH: 60 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.05s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.56%, Precision = 93.02%, Recall = 92.79%
# ================================== Valid Data ==================================
# F1 = 91.12%, Precision = 91.23%, Recall = 91.18%
# ================================== Test  Data ==================================
# F1 = 86.37%, Precision = 87.54%, Recall = 86.95%
# Time: 13.88s
#
# ----------------------------------- EPOCH: 61 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.22s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.20%, Precision = 93.32%, Recall = 93.26%
# ================================== Valid Data ==================================
# F1 = 91.67%, Precision = 91.52%, Recall = 91.60%
# ================================== Test  Data ==================================
# F1 = 87.07%, Precision = 87.91%, Recall = 87.49%
# Time: 13.46s
#
# ----------------------------------- EPOCH: 62 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.62s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.61%, Precision = 93.39%, Recall = 93.00%
# ================================== Valid Data ==================================
# F1 = 91.44%, Precision = 91.91%, Recall = 91.67%
# ================================== Test  Data ==================================
# F1 = 86.49%, Precision = 88.08%, Recall = 87.28%
# Time: 13.48s
#
# ----------------------------------- EPOCH: 63 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.87s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.10%, Precision = 93.01%, Recall = 93.06%
# ================================== Valid Data ==================================
# F1 = 91.81%, Precision = 91.27%, Recall = 91.54%
# ================================== Test  Data ==================================
# F1 = 87.12%, Precision = 87.34%, Recall = 87.23%
# Time: 13.48s
#
# ----------------------------------- EPOCH: 64 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 42.84s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 91.63%, Precision = 93.59%, Recall = 92.60%
# ================================== Valid Data ==================================
# F1 = 90.35%, Precision = 92.02%, Recall = 91.18%
# ================================== Test  Data ==================================
# F1 = 85.04%, Precision = 88.37%, Recall = 86.67%
# Time: 13.71s
#
# ----------------------------------- EPOCH: 65 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.30s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.79%, Precision = 93.59%, Recall = 93.69%
# ================================== Valid Data ==================================
# F1 = 92.36%, Precision = 91.72%, Recall = 92.04%
# ================================== Test  Data ==================================
# F1 = 87.67%, Precision = 87.98%, Recall = 87.82%
# Time: 13.46s
#
# ----------------------------------- EPOCH: 66 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.84s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.52%, Precision = 93.20%, Recall = 93.36%
# ================================== Valid Data ==================================
# F1 = 92.01%, Precision = 91.33%, Recall = 91.67%
# ================================== Test  Data ==================================
# F1 = 87.34%, Precision = 87.34%, Recall = 87.34%
# Time: 13.46s
#
# ----------------------------------- EPOCH: 67 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 42.88s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.95%, Precision = 93.57%, Recall = 93.26%
# ================================== Valid Data ==================================
# F1 = 91.04%, Precision = 91.52%, Recall = 91.28%
# ================================== Test  Data ==================================
# F1 = 86.86%, Precision = 88.24%, Recall = 87.55%
# Time: 14.13s
#
# ----------------------------------- EPOCH: 68 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 42.77s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 94.12%, Precision = 92.87%, Recall = 93.49%
# ================================== Valid Data ==================================
# F1 = 92.62%, Precision = 91.10%, Recall = 91.85%
# ================================== Test  Data ==================================
# F1 = 88.40%, Precision = 87.27%, Recall = 87.83%
# Time: 13.70s
#
# ----------------------------------- EPOCH: 69 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.18s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.67%, Precision = 93.68%, Recall = 93.18%
# ================================== Valid Data ==================================
# F1 = 90.91%, Precision = 91.70%, Recall = 91.30%
# ================================== Test  Data ==================================
# F1 = 85.76%, Precision = 87.84%, Recall = 86.78%
# Time: 13.48s
#
# ----------------------------------- EPOCH: 70 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.52s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.98%, Precision = 93.48%, Recall = 93.23%
# ================================== Valid Data ==================================
# F1 = 91.46%, Precision = 91.69%, Recall = 91.57%
# ================================== Test  Data ==================================
# F1 = 87.02%, Precision = 88.28%, Recall = 87.64%
# Time: 13.52s
#
# ----------------------------------- EPOCH: 71 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 42.81s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 92.86%, Precision = 93.54%, Recall = 93.20%
# ================================== Valid Data ==================================
# F1 = 91.38%, Precision = 91.85%, Recall = 91.62%
# ================================== Test  Data ==================================
# F1 = 86.56%, Precision = 88.12%, Recall = 87.33%
# Time: 13.91s
#
# ----------------------------------- EPOCH: 72 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.39s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 93.76%, Precision = 94.22%, Recall = 93.99%
# ================================== Valid Data ==================================
# F1 = 92.02%, Precision = 92.41%, Recall = 92.22%
# ...
# F1 = 88.62%, Precision = 89.77%, Recall = 89.19%
# Time: 13.73s
#
# ----------------------------------- EPOCH: 457 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.48s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.90%, Precision = 99.11%, Recall = 99.00%
# ================================== Valid Data ==================================
# F1 = 93.55%, Precision = 93.99%, Recall = 93.77%
# ================================== Test  Data ==================================
# F1 = 88.83%, Precision = 89.85%, Recall = 89.34%
# Time: 13.98s
#
# ----------------------------------- EPOCH: 458 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.03s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.87%, Precision = 98.93%, Recall = 98.90%
# ================================== Valid Data ==================================
# F1 = 93.67%, Precision = 93.67%, Recall = 93.67%
# ================================== Test  Data ==================================
# F1 = 89.41%, Precision = 89.71%, Recall = 89.56%
# Time: 14.53s
#
# ----------------------------------- EPOCH: 459 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.78s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.89%, Precision = 99.04%, Recall = 98.97%
# ================================== Valid Data ==================================
# F1 = 93.80%, Precision = 93.72%, Recall = 93.76%
# ================================== Test  Data ==================================
# F1 = 89.28%, Precision = 89.77%, Recall = 89.52%
# Time: 13.81s
#
# ----------------------------------- EPOCH: 460 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.96s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.98%, Precision = 99.06%, Recall = 99.02%
# ================================== Valid Data ==================================
# F1 = 93.98%, Precision = 93.84%, Recall = 93.91%
# ================================== Test  Data ==================================
# F1 = 89.37%, Precision = 89.64%, Recall = 89.51%
# Time: 13.88s
#
# ----------------------------------- EPOCH: 461 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.37s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.96%, Precision = 98.80%, Recall = 98.88%
# ================================== Valid Data ==================================
# F1 = 94.24%, Precision = 93.27%, Recall = 93.75%
# ================================== Test  Data ==================================
# F1 = 89.96%, Precision = 89.04%, Recall = 89.50%
# Time: 14.30s
#
# ----------------------------------- EPOCH: 462 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.19s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 99.05%, Recall = 98.96%
# ================================== Valid Data ==================================
# F1 = 93.45%, Precision = 93.69%, Recall = 93.57%
# ================================== Test  Data ==================================
# F1 = 89.18%, Precision = 89.85%, Recall = 89.51%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 463 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 45.02s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 98.97%, Recall = 98.92%
# ================================== Valid Data ==================================
# F1 = 93.67%, Precision = 93.84%, Recall = 93.75%
# ================================== Test  Data ==================================
# F1 = 88.99%, Precision = 89.55%, Recall = 89.27%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 464 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 45.74s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.90%, Precision = 98.98%, Recall = 98.94%
# ================================== Valid Data ==================================
# F1 = 93.33%, Precision = 93.52%, Recall = 93.43%
# ================================== Test  Data ==================================
# F1 = 89.62%, Precision = 89.89%, Recall = 89.76%
# Time: 13.81s
#
# ----------------------------------- EPOCH: 465 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.43s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 98.77%, Recall = 98.83%
# ================================== Valid Data ==================================
# F1 = 94.02%, Precision = 93.45%, Recall = 93.74%
# ================================== Test  Data ==================================
# F1 = 89.64%, Precision = 89.31%, Recall = 89.47%
# Time: 14.22s
#
# ----------------------------------- EPOCH: 466 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.23s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.87%, Precision = 98.96%, Recall = 98.92%
# ================================== Valid Data ==================================
# F1 = 93.80%, Precision = 93.52%, Recall = 93.66%
# ================================== Test  Data ==================================
# F1 = 89.49%, Precision = 89.59%, Recall = 89.54%
# Time: 13.79s
#
# ----------------------------------- EPOCH: 467 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.78s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.83%, Precision = 98.87%, Recall = 98.85%
# ================================== Valid Data ==================================
# F1 = 93.56%, Precision = 93.60%, Recall = 93.58%
# ================================== Test  Data ==================================
# F1 = 89.06%, Precision = 89.77%, Recall = 89.41%
# Time: 13.85s
#
# ----------------------------------- EPOCH: 468 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.50s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.85%, Precision = 99.00%, Recall = 98.93%
# ================================== Valid Data ==================================
# F1 = 93.46%, Precision = 93.62%, Recall = 93.54%
# ================================== Test  Data ==================================
# F1 = 88.93%, Precision = 89.64%, Recall = 89.29%
# Time: 13.82s
#
# ----------------------------------- EPOCH: 469 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.77s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 99.02%, Precision = 99.14%, Recall = 99.08%
# ================================== Valid Data ==================================
# F1 = 93.75%, Precision = 93.92%, Recall = 93.84%
# ================================== Test  Data ==================================
# F1 = 89.44%, Precision = 89.96%, Recall = 89.70%
# Time: 13.76s
#
# ----------------------------------- EPOCH: 470 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.57s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.88%, Precision = 98.97%, Recall = 98.93%
# ================================== Valid Data ==================================
# F1 = 93.47%, Precision = 93.44%, Recall = 93.45%
# ================================== Test  Data ==================================
# F1 = 89.42%, Precision = 89.64%, Recall = 89.53%
# Time: 14.06s
#
# ----------------------------------- EPOCH: 471 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.66s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.90%, Precision = 99.00%, Recall = 98.95%
# ================================== Valid Data ==================================
# F1 = 93.73%, Precision = 93.91%, Recall = 93.82%
# ================================== Test  Data ==================================
# F1 = 88.90%, Precision = 89.47%, Recall = 89.18%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 472 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.83s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.96%, Precision = 99.11%, Recall = 99.03%
# ================================== Valid Data ==================================
# F1 = 93.32%, Precision = 93.76%, Recall = 93.54%
# ================================== Test  Data ==================================
# F1 = 88.63%, Precision = 89.55%, Recall = 89.09%
# Time: 14.30s
#
# ----------------------------------- EPOCH: 473 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 43.98s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.97%, Precision = 99.16%, Recall = 99.06%
# ================================== Valid Data ==================================
# F1 = 93.60%, Precision = 94.04%, Recall = 93.82%
# ================================== Test  Data ==================================
# F1 = 89.05%, Precision = 90.12%, Recall = 89.58%
# Time: 13.66s
#
# ----------------------------------- EPOCH: 474 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.99s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.98%, Precision = 99.07%, Recall = 99.03%
# ================================== Valid Data ==================================
# F1 = 93.78%, Precision = 93.81%, Recall = 93.79%
# ================================== Test  Data ==================================
# F1 = 89.02%, Precision = 89.75%, Recall = 89.38%
# Time: 14.10s
#
# ----------------------------------- EPOCH: 475 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.41s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.92%, Precision = 98.99%, Recall = 98.95%
# ================================== Valid Data ==================================
# F1 = 93.64%, Precision = 93.42%, Recall = 93.53%
# ================================== Test  Data ==================================
# F1 = 89.43%, Precision = 89.61%, Recall = 89.52%
# Time: 13.77s
#
# ----------------------------------- EPOCH: 476 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.63s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.93%, Precision = 99.08%, Recall = 99.01%
# ================================== Valid Data ==================================
# F1 = 93.38%, Precision = 93.72%, Recall = 93.55%
# ================================== Test  Data ==================================
# F1 = 88.75%, Precision = 89.64%, Recall = 89.19%
# Time: 14.08s
#
# ----------------------------------- EPOCH: 477 -----------------------------------
# ----------------------------------- Training -----------------------------------
# Time: 44.21s
# ---------------------------------- Evaluating ----------------------------------
# ================================== Train Data ==================================
# F1 = 98.94%, Precision = 99.13%, Recall = 99.03%
# ================================== Valid Data ==================================
# F1 = 93.55%, Precision = 93.77%, Recall = 93.66%
# ================================== Test  Data ==================================
# F1 = 89.25%, Precision = 89.78%, Recall = 89.51%
# Time: 13.75s
#
# ----------------------------------- EPOCH: 478 -----------------------------------
# ----------------------------------- Training -----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-68f59c8463d8> in <module>()
#       8
#       9     for batch in train_batches:
# ---> 10         model.train_on_batch([batch['word'], batch['case'], batch['char']], [batch['tag'], batch['gazetteers'], batch['shape'], batch['position']])
#      11
#      12     finish_time = time.time()
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
